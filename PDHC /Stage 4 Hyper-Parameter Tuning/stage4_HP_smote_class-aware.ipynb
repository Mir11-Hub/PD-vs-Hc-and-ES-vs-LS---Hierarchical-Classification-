# %%
"""
Stage 4 (PD vs HC, class-aware) - Multi-panel nested CV with SMOTE inside inner folds
======================================================================================

Variant of stage4_HP_PDHC.py with SMOTE applied inside each INNER CV
fold via a custom SMOTEWeightedPipeline wrapper. Two SMOTE strategies
run sequentially against the matching Stage-3 SMOTE output (panel
sourced from the same SMOTE variant for end-to-end methodological
consistency):

  (a) BALANCED   - minority -> majority             (sampling_strategy='auto')
  (b) IMBALANCED - both classes 2x, ratio preserved (dict strategy)

Class encoding: NEG=HC=0 (minority), POS=PD=1 (majority).

LEAKAGE GUARDS:
  * SMOTE is invoked INSIDE the SMOTEWeightedPipeline wrapper, which is
    fitted by GridSearchCV per INNER training fold only. Inner validation
    folds are never touched by SMOTE.
  * Outer-test fold is held aside and never SMOTE-touched.

SAMPLE WEIGHTING:
  * Composite (sex x cell_type) x class weights are computed on
    OUTER-TRAIN real samples and passed to GridSearchCV via
    `gs.fit(..., sample_weight=sw)`.
  * GridSearchCV slices the weight vector to each inner-train fold
    automatically.
  * Inside SMOTEWeightedPipeline.fit, the inner-train weight vector is
    EXTENDED across SMOTE-synthetic samples:
        - real samples     -> retain composite weight (subset of sw)
        - synthetic samples-> uniform 1.0  (no metadata available)
      and re-normalised to mean 1.

Pipeline per inner fold (inside the wrapper):
    SMOTE -> RobustScaler -> classifier(sample_weight=ext_w)

Panel sizes (PANEL_SIZES = [5, 7, 10, 12, 16]) iterate independently;
each (panel_size x variant) produces its own output folder.
"""

from __future__ import annotations

import json
import warnings
from collections import Counter
from pathlib import Path
from typing import Dict, List

import numpy as np
import pandas as pd
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt

from imblearn.over_sampling import SMOTE
from sklearn.base import BaseEstimator, ClassifierMixin, clone
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    average_precision_score, balanced_accuracy_score, brier_score_loss,
    cohen_kappa_score, confusion_matrix, f1_score, matthews_corrcoef,
    precision_recall_curve, roc_auc_score, roc_curve,
)
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import RobustScaler
from sklearn.svm import SVC

warnings.filterwarnings("ignore")

# ----------------------------- Configuration --------------------------------
PIPELINE_DIR    = Path(r"C:\Users\hafsa\Python PD Project\MI_BaggedLASSO Pipeline")
PDHC_DIR        = PIPELINE_DIR / "PDHC new"
CLASS_AWARE_DIR = PDHC_DIR / "PDHC-class-aware"
SPLIT_DIR       = CLASS_AWARE_DIR / "Outputs" / "stage2_split_class_aware_PDHC"
OUTPUT_BASE     = CLASS_AWARE_DIR / "Outputs" 

TRAIN_PATH = SPLIT_DIR / "train.csv"
TEST_PATH  = SPLIT_DIR / "test.csv"
META_PATH  = PDHC_DIR / "Meta_data_PDHC.csv"

CONDITION_COL = "condition"
PANEL_SIZES   = [5, 10, 15, 25, 41]
SEEDS         = [42, 123, 256]
N_OUTER       = 9
N_INNER       = 4
N_JOBS        = -1

NEG_LABEL = "HC"   # 0  (minority)
POS_LABEL = "PD"   # 1  (majority)

SMOTE_VARIANTS    = ["balanced", "imbalanced"]
SMOTE_K_NEIGHBORS = 5


# ============================ Data helpers =================================
def load_meta(sample_ids):
    meta = pd.read_csv(META_PATH)
    if "sample_id" in meta.columns:
        meta = meta.set_index("sample_id")
    return meta.loc[sample_ids]


def to_binary_labels(y_str):
    return np.where(np.asarray(y_str) == NEG_LABEL, NEG_LABEL, POS_LABEL)


def encode_binary(y_str_binary):
    return np.where(y_str_binary == POS_LABEL, 1, 0).astype(int)


def load_features_x_samples(path: Path, top_genes: List[str]) -> pd.DataFrame:
    df = pd.read_csv(path, index_col=0)
    if len(set(top_genes) & set(df.index.astype(str))) == 0:
        df = df.T
    present = [g for g in top_genes if g in df.index]
    missing = [g for g in top_genes if g not in df.index]
    if missing:
        print(f"  WARN: {len(missing)} genes missing in {path.name}")
    return df.loc[present]


def composite_sample_weights(meta: pd.DataFrame, y_int: np.ndarray) -> np.ndarray:
    strata = meta["sex"].astype(str) + "_" + meta["cell_type"].astype(str)
    s_counts = strata.value_counts()
    n, k = len(strata), len(s_counts)
    w_conf = strata.map(lambda s: (n / k) / s_counts[s]).values.astype(float)

    classes, c_counts = np.unique(y_int, return_counts=True)
    n_cls = len(classes)
    class_w = {c: n / (n_cls * cnt) for c, cnt in zip(classes, c_counts)}
    w_class = np.array([class_w[y] for y in y_int], dtype=float)

    w = w_conf * w_class
    return w / w.mean()


# ============================ SMOTE strategy ================================
def smote_sampling_strategy(y_int, variant):
    if variant == "balanced":
        return "auto"
    if variant == "imbalanced":
        counts = pd.Series(y_int).value_counts().to_dict()
        return {int(c): int(2 * n) for c, n in counts.items()}
    raise ValueError(f"Unknown SMOTE variant: {variant}")


def make_smote(variant, y_int_for_strategy, seed):
    minority = int(min(pd.Series(y_int_for_strategy).value_counts()))
    k = min(SMOTE_K_NEIGHBORS, max(1, minority - 1))
    strat = smote_sampling_strategy(y_int_for_strategy, variant)
    return SMOTE(sampling_strategy=strat, random_state=seed, k_neighbors=k)


# ============================ SMOTE-weighted wrapper ========================
class SMOTEWeightedPipeline(BaseEstimator, ClassifierMixin):
    """SMOTE -> RobustScaler -> classifier wrapper that PROPAGATES
    sample_weight through SMOTE."""

    def __init__(self, clf=None, smote_variant="balanced",
                 random_state=42, k_neighbors=5, supports_sw=True):
        self.clf            = clf
        self.smote_variant  = smote_variant
        self.random_state   = random_state
        self.k_neighbors    = k_neighbors
        self.supports_sw    = supports_sw

    def _smote_strategy(self, y):
        if self.smote_variant == "balanced":
            return "auto"
        if self.smote_variant == "imbalanced":
            counts = pd.Series(y).value_counts().to_dict()
            return {int(c): int(2 * n) for c, n in counts.items()}
        raise ValueError(f"Unknown SMOTE variant: {self.smote_variant}")

    def fit(self, X, y, sample_weight=None):
        n_orig   = X.shape[0]
        minority = int(min(pd.Series(y).value_counts()))
        k        = min(self.k_neighbors, max(1, minority - 1))
        sm = SMOTE(sampling_strategy=self._smote_strategy(y),
                   random_state=self.random_state, k_neighbors=k)
        X_aug, y_aug = sm.fit_resample(X, y)
        n_synth = X_aug.shape[0] - n_orig

        self.scaler_ = RobustScaler()
        X_aug_scaled = self.scaler_.fit_transform(X_aug)

        self.clf_ = clone(self.clf)
        self.fitted_with_weights_ = False
        if sample_weight is not None and self.supports_sw:
            ext = np.concatenate([
                np.asarray(sample_weight, dtype=float),
                np.ones(n_synth, dtype=float),
            ])
            ext = ext / ext.mean()
            try:
                self.clf_.fit(X_aug_scaled, y_aug, sample_weight=ext)
                self.fitted_with_weights_ = True
            except TypeError:
                self.clf_.fit(X_aug_scaled, y_aug)
        else:
            self.clf_.fit(X_aug_scaled, y_aug)

        self.classes_       = self.clf_.classes_
        self.n_smote_orig_  = n_orig
        self.n_smote_synth_ = n_synth
        return self

    def predict(self, X):
        return self.clf_.predict(self.scaler_.transform(X))

    def predict_proba(self, X):
        return self.clf_.predict_proba(self.scaler_.transform(X))

    def decision_function(self, X):
        if hasattr(self.clf_, "decision_function"):
            return self.clf_.decision_function(self.scaler_.transform(X))
        raise AttributeError("Inner clf has no decision_function")


# ============================ Classifiers ==================================
def get_classifiers_with_smote(seed: int, variant: str) -> Dict[str, Dict]:
    return {
        "mSVM-RBF": {
            "pipe": SMOTEWeightedPipeline(
                clf=SVC(kernel="rbf", probability=True, random_state=seed),
                smote_variant=variant, random_state=seed,
                k_neighbors=SMOTE_K_NEIGHBORS, supports_sw=True),
            "grid": {"clf__C":     [0.1, 1, 10],
                     "clf__gamma": ["scale", 0.01, 0.1, 1.0]},
        },
        "mSVM-Linear": {
            "pipe": SMOTEWeightedPipeline(
                clf=SVC(kernel="linear", probability=True, random_state=seed),
                smote_variant=variant, random_state=seed,
                k_neighbors=SMOTE_K_NEIGHBORS, supports_sw=True),
            "grid": {"clf__C": [0.01, 0.1, 1, 10]},
        },
        "mSVM-RFE": {
            "pipe": SMOTEWeightedPipeline(
                clf=RFE(SVC(kernel="linear", probability=True,
                            random_state=seed)),
                smote_variant=variant, random_state=seed,
                k_neighbors=SMOTE_K_NEIGHBORS, supports_sw=True),
            "grid": {"clf__n_features_to_select": None,
                     "clf__estimator__C":         [0.1, 1, 10]},
        },
        "kNN": {
            "pipe": SMOTEWeightedPipeline(
                clf=KNeighborsClassifier(),
                smote_variant=variant, random_state=seed,
                k_neighbors=SMOTE_K_NEIGHBORS, supports_sw=False),
            "grid": {"clf__n_neighbors": [3, 5, 7, 11, 15],
                     "clf__weights":     ["uniform", "distance"]},
        },
        "GaussianNB": {
            "pipe": SMOTEWeightedPipeline(
                clf=GaussianNB(),
                smote_variant=variant, random_state=seed,
                k_neighbors=SMOTE_K_NEIGHBORS, supports_sw=True),
            "grid": {"clf__var_smoothing": np.logspace(-11, -7, 5)},
        },
        "ElasticNet": {
            "pipe": SMOTEWeightedPipeline(
                clf=LogisticRegression(penalty="elasticnet", solver="saga",
                                       max_iter=5000, tol=1e-3,
                                       random_state=seed),
                smote_variant=variant, random_state=seed,
                k_neighbors=SMOTE_K_NEIGHBORS, supports_sw=True),
            "grid": {"clf__C":        [0.01, 0.1, 1, 10],
                     "clf__l1_ratio": [0.1, 0.3, 0.5, 0.7, 0.9]},
        },
    }


def rfe_grid_for_panel(k_top):
    base = sorted({max(2, k_top // 4), max(3, k_top // 2), k_top - 1, k_top})
    return [b for b in base if 2 <= b <= k_top]


# ============================ Metrics =======================================
def evaluate_binary(y_true, y_pred, y_proba_pos):
    cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
    tn, fp, fn, tp = cm.ravel()
    sens = tp / (tp + fn) if (tp + fn) > 0 else np.nan
    spec = tn / (tn + fp) if (tn + fp) > 0 else np.nan
    return {
        "balanced_accuracy": balanced_accuracy_score(y_true, y_pred),
        "macro_f1":          f1_score(y_true, y_pred, average="macro"),
        "auroc":             roc_auc_score(y_true, y_proba_pos),
        "pr_auc":            average_precision_score(y_true, y_proba_pos),
        "sensitivity":       sens,
        "specificity":       spec,
        "mcc":               matthews_corrcoef(y_true, y_pred),
        "brier":             brier_score_loss(y_true, y_proba_pos),
        "cohen_kappa":       cohen_kappa_score(y_true, y_pred),
    }


def selected_genes_from_estimator(name: str, gs_result, gene_names):
    best = gs_result.best_estimator_
    if name == "ElasticNet":
        coef = best.clf_.coef_
        mask = (np.abs(coef) > 1e-10).any(axis=0)
        return [g for g, m in zip(gene_names, mask) if m]
    if name == "mSVM-RFE":
        return [g for g, m in zip(gene_names, best.clf_.support_) if m]
    return []


# ============================ Aggregation ===================================
def aggregate_metrics(df):
    metric_cols = ["balanced_accuracy", "macro_f1", "auroc", "pr_auc",
                   "sensitivity", "specificity", "mcc", "brier", "cohen_kappa"]
    rows = []
    for clf, sub in df.groupby("classifier"):
        row = {"classifier": clf, "n_folds": len(sub)}
        for m in metric_cols:
            row[f"{m}_mean"] = sub[m].mean()
            row[f"{m}_std"]  = sub[m].std()
        rows.append(row)
    return pd.DataFrame(rows)


def consensus_hyperparams(df):
    rows = []
    for clf, sub in df.groupby("classifier"):
        params_list = [json.loads(p) for p in sub["best_params"]]
        keys = sorted({k for p in params_list for k in p.keys()})
        row = {"classifier": clf}
        for k in keys:
            vals = [p.get(k) for p in params_list]
            counter = Counter([str(v) for v in vals])
            mode_str, mode_count = counter.most_common(1)[0]
            row[k] = mode_str
            row[f"{k}__support_pct"] = round(100 * mode_count / len(vals), 1)
        rows.append(row)
    return pd.DataFrame(rows)


def fold_inclusion_table(sel_records, top_genes, n_folds_total):
    df = pd.DataFrame(sel_records)
    out = {}
    if df.empty:
        return out
    for clf in df["classifier"].unique():
        sub = df[df["classifier"] == clf]
        n_seen = sub.groupby("gene").size()
        full = pd.Series(0, index=top_genes, dtype=int)
        full.update(n_seen)
        out[clf] = pd.DataFrame({
            "gene": full.index,
            "n_folds_included": full.values,
            "fold_inclusion_pct":
                np.round(100 * full.values / n_folds_total, 1),
        }).sort_values("n_folds_included", ascending=False)
    return out


# ============================ Plot helpers =================================
def plot_roc_per_classifier(fold_df, out_path, title_suffix):
    fig, ax = plt.subplots(figsize=(8, 6))
    for clf, sub in fold_df.groupby("classifier"):
        y_true_all = np.concatenate([np.asarray(t) for t in sub["y_true"]])
        y_proba_all = np.concatenate([np.asarray(p) for p in sub["y_proba_pos"]])
        fpr, tpr, _ = roc_curve(y_true_all, y_proba_all)
        auc = roc_auc_score(y_true_all, y_proba_all)
        ax.plot(fpr, tpr, label=f"{clf} (AUC={auc:.3f})", linewidth=1.7)
    ax.plot([0, 1], [0, 1], "k--", alpha=0.4, linewidth=1)
    ax.set_xlabel("False positive rate"); ax.set_ylabel("True positive rate")
    ax.set_title(f"ROC across 27 outer folds (concatenated) - {title_suffix}")
    ax.legend(loc="lower right", fontsize=9); ax.grid(alpha=0.25)
    fig.tight_layout(); fig.savefig(out_path, dpi=200); plt.close(fig)


def plot_pr_per_classifier(fold_df, out_path, title_suffix):
    fig, ax = plt.subplots(figsize=(8, 6))
    for clf, sub in fold_df.groupby("classifier"):
        y_true_all = np.concatenate([np.asarray(t) for t in sub["y_true"]])
        y_proba_all = np.concatenate([np.asarray(p) for p in sub["y_proba_pos"]])
        prec, rec, _ = precision_recall_curve(y_true_all, y_proba_all)
        ap = average_precision_score(y_true_all, y_proba_all)
        ax.plot(rec, prec, label=f"{clf} (AP={ap:.3f})", linewidth=1.7)
    ax.set_xlabel("Recall"); ax.set_ylabel("Precision")
    ax.set_title(f"PR across 27 outer folds (concatenated) - {title_suffix}")
    ax.legend(loc="lower left", fontsize=9); ax.grid(alpha=0.25)
    fig.tight_layout(); fig.savefig(out_path, dpi=200); plt.close(fig)


# ============================ Per-classifier CV ============================
def run_classifier_cv(name, cfg, X, y_int, gene_names, meta,
                      fold_records, sel_records, smote_count_records,
                      variant):
    print(f"\n--- {name} ---")
    supports_sw = cfg["pipe"].supports_sw

    for seed in SEEDS:
        skf_outer = StratifiedKFold(n_splits=N_OUTER, shuffle=True,
                                     random_state=seed)
        for fold_i, (tr_idx, te_idx) in enumerate(skf_outer.split(X, y_int)):
            X_tr, X_te = X[tr_idx], X[te_idx]
            y_tr, y_te = y_int[tr_idx], y_int[te_idx]

            sw_tr = composite_sample_weights(meta.iloc[tr_idx], y_tr)

            n_pre = pd.Series(y_tr).value_counts().to_dict()
            sm_target = smote_sampling_strategy(y_tr, variant)
            n_post = (n_pre.copy() if isinstance(sm_target, str)
                      else sm_target)
            if isinstance(sm_target, str):
                maj = max(n_pre.values())
                n_post = {c: maj for c in n_pre.keys()}
            smote_count_records.append({
                "classifier": name, "seed": seed, "fold": fold_i + 1,
                "variant":    variant,
                "n_pre_HC":   int(n_pre.get(0, 0)),
                "n_pre_PD":   int(n_pre.get(1, 0)),
                "n_post_HC":  int(n_post.get(0, 0)),
                "n_post_PD":  int(n_post.get(1, 0)),
                "sw_supported": supports_sw,
            })

            inner = StratifiedKFold(n_splits=N_INNER, shuffle=True,
                                     random_state=seed * 1000 + fold_i)
            gs = GridSearchCV(
                estimator=cfg["pipe"], param_grid=cfg["grid"],
                scoring="balanced_accuracy", cv=inner,
                n_jobs=N_JOBS, refit=True,
            )
            if supports_sw:
                gs.fit(X_tr, y_tr, sample_weight=sw_tr)
            else:
                gs.fit(X_tr, y_tr)

            y_pred = gs.predict(X_te)
            y_proba_pos = gs.predict_proba(X_te)[:, 1]
            metrics = evaluate_binary(y_te, y_pred, y_proba_pos)

            fold_records.append({
                "classifier":   name,
                "seed":         seed,
                "fold":         fold_i + 1,
                "best_params":  json.dumps(gs.best_params_),
                "sw_used":      bool(supports_sw),
                **metrics,
                "y_true":       y_te.tolist(),
                "y_proba_pos":  y_proba_pos.tolist(),
            })
            print(f"  seed={seed} fold={fold_i+1}  "
                  f"BA={metrics['balanced_accuracy']:.3f}  "
                  f"AUROC={metrics['auroc']:.3f}  "
                  f"PR-AUC={metrics['pr_auc']:.3f}  "
                  f"sw={'on' if supports_sw else 'off'}", flush=True)

            if name in ("ElasticNet", "mSVM-RFE"):
                sel = selected_genes_from_estimator(name, gs, gene_names)
                for g in sel:
                    sel_records.append({"classifier": name, "seed": seed,
                                        "fold": fold_i + 1, "gene": g})


# ============================ Per-(variant, panel) run ======================
def run_for_variant(variant: str, panel_size: int):
    out_dir = OUTPUT_BASE / f"stage4_HP_PDHC_top{panel_size}_smote_{variant}"
    out_dir.mkdir(parents=True, exist_ok=True)
    s3_dir = OUTPUT_BASE / f"stage3_FS_smote" / f"stage3_FS_PDHC_smote_{variant}"
    consensus_path = s3_dir / "consensus_panel.csv"

    print("\n" + "=" * 72)
    print(f"VARIANT: SMOTE = {variant.upper()}  (top {panel_size})")
    print(f"Stage-3 source: {s3_dir.name}")
    print(f"Output dir    : {out_dir.name}")
    print("=" * 72)

    if not consensus_path.exists():
        raise FileNotFoundError(
            f"{consensus_path} not found. Run stage3_FS_PDHC_smote.py first.")

    consensus = pd.read_csv(consensus_path, index_col=0)
    if "fold_inclusion" not in consensus.columns:
        consensus.columns = ["fold_inclusion"]
    top_genes = (consensus.sort_values("fold_inclusion", ascending=False)
                          .head(panel_size).index.tolist())
    if len(top_genes) < panel_size:
        print(f"  WARN: consensus has only {len(top_genes)} genes "
              f"(< requested {panel_size}); proceeding with available set.")
    print(f"Top-{len(top_genes)} consensus genes loaded from {variant} Stage 3")

    train_df = load_features_x_samples(TRAIN_PATH, top_genes).round(4)
    test_df  = load_features_x_samples(TEST_PATH,  top_genes).round(4)
    train_df.to_csv(out_dir / "train_postfeature.csv")
    test_df.to_csv(out_dir / "test_postfeature.csv")
    print(f"Pre-SMOTE post-feature CSVs saved (train: {train_df.shape}, "
          f"test: {test_df.shape})")

    meta_train = load_meta(train_df.columns)
    y_train_str = meta_train[CONDITION_COL].values
    y_train_bin = to_binary_labels(y_train_str)
    y_train_int = encode_binary(y_train_bin)
    print(f"Class balance (PD=1, HC=0): {dict(Counter(y_train_bin))}")

    X_train = train_df.T.values.astype(np.float64)
    gene_names = train_df.index.tolist()

    sm_full = make_smote(variant, y_train_int, seed=42)
    X_train_smote, y_train_smote = sm_full.fit_resample(X_train, y_train_int)
    n_orig = X_train.shape[0]
    n_synth = X_train_smote.shape[0] - n_orig
    synth_ids = [f"SYNTH_{variant}_{i:03d}" for i in range(n_synth)]
    sample_ids_smote = list(train_df.columns) + synth_ids
    train_smote_df = pd.DataFrame(
        X_train_smote.T,
        index=gene_names,
        columns=sample_ids_smote
    ).round(4)
    train_smote_df.to_csv(out_dir / "train_postfeature_smote.csv")
    smote_meta = pd.DataFrame({
        "sample_id": sample_ids_smote,
        "condition": np.where(y_train_smote == 1, POS_LABEL, NEG_LABEL),
        "synthetic": [False] * n_orig + [True] * n_synth,
    })
    smote_meta.to_csv(out_dir / "train_postfeature_smote_meta.csv", index=False)
    print(f"Full-train SMOTE applied: {n_orig} real + {n_synth} synthetic = "
          f"{X_train_smote.shape[0]} samples")
    print(f"Synthetic class breakdown: HC={(y_train_smote[n_orig:]==0).sum()}, "
          f"PD={(y_train_smote[n_orig:]==1).sum()}")

    classifiers = get_classifiers_with_smote(seed=42, variant=variant)
    classifiers["mSVM-RFE"]["grid"]["clf__n_features_to_select"] = \
        rfe_grid_for_panel(len(top_genes))
    print(f"RFE n_features_to_select grid: "
          f"{classifiers['mSVM-RFE']['grid']['clf__n_features_to_select']}")

    fold_records, sel_records, smote_count_records = [], [], []
    for name, cfg in classifiers.items():
        run_classifier_cv(name, cfg, X_train, y_train_int, gene_names,
                          meta_train,
                          fold_records, sel_records, smote_count_records,
                          variant)

    fold_df = pd.DataFrame(fold_records)
    csv_cols = [c for c in fold_df.columns
                if c not in ("y_true", "y_proba_pos")]
    fold_df[csv_cols].to_csv(out_dir / "fold_results.csv", index=False)

    pd.DataFrame(smote_count_records).to_csv(
        out_dir / "smote_fold_summary.csv", index=False)

    agg = aggregate_metrics(fold_df)
    agg.to_csv(out_dir / "final_metrics.csv", index=False)
    print(f"\n[{variant}] Final metrics (mean across 27 folds):")
    print(agg.set_index("classifier")
          [["balanced_accuracy_mean", "macro_f1_mean",
            "auroc_mean", "pr_auc_mean"]].round(3).to_string())

    cons = consensus_hyperparams(fold_df)
    cons.to_csv(out_dir / "consensus_hyperparams.csv", index=False)

    plot_roc_per_classifier(fold_df, out_dir / "roc_curves.png",
                             f"top {len(top_genes)}, SMOTE {variant} (class-aware)")
    plot_pr_per_classifier(fold_df,  out_dir / "pr_curves.png",
                            f"top {len(top_genes)}, SMOTE {variant} (class-aware)")

    n_folds_total = N_OUTER * len(SEEDS)
    inc_tables = fold_inclusion_table(sel_records, top_genes, n_folds_total)
    if "ElasticNet" in inc_tables:
        inc_tables["ElasticNet"].to_csv(
            out_dir / "enet_fold_inclusion.csv", index=False)
    if "mSVM-RFE" in inc_tables:
        inc_tables["mSVM-RFE"].to_csv(
            out_dir / "rfe_fold_inclusion.csv", index=False)

    print(f"\n[{variant}] Outputs in: {out_dir}")
    return out_dir


def main():
    print("=" * 72)
    print("STAGE 4 (PD vs HC, class-aware) SMOTE - Multi-panel nested CV")
    print(f"Panel sizes  : {PANEL_SIZES}")
    print(f"SMOTE variants: {SMOTE_VARIANTS}")
    print(f"Outer folds={N_OUTER} x seeds={SEEDS} = {N_OUTER * len(SEEDS)}; "
          f"inner={N_INNER}")
    print(f"Total runs   : {len(PANEL_SIZES)} panels x {len(SMOTE_VARIANTS)} "
          f"variants = {len(PANEL_SIZES) * len(SMOTE_VARIANTS)}")
    print("=" * 72)
    for panel_size in PANEL_SIZES:
        for variant in SMOTE_VARIANTS:
            run_for_variant(variant, panel_size)


if __name__ == "__main__":
    main()
# Out:
# ========================================================================
# STAGE 4 (PD vs HC, class-aware) SMOTE - Multi-panel nested CV
# Panel sizes  : [5, 10, 15, 25, 41]
# SMOTE variants: ['balanced', 'imbalanced']
# Outer folds=9 x seeds=[42, 123, 256] = 27; inner=4
# Total runs   : 5 panels x 2 variants = 10
# ========================================================================
#
# ========================================================================
# VARIANT: SMOTE = BALANCED  (top 5)
# Stage-3 source: stage3_FS_PDHC_smote_balanced
# Output dir    : stage4_HP_PDHC_top5_smote_balanced
# ========================================================================
# Top-5 consensus genes loaded from balanced Stage 3
# Pre-SMOTE post-feature CSVs saved (train: (5, 108), test: (5, 47))
# Class balance (PD=1, HC=0): {np.str_('HC'): 36, np.str_('PD'): 72}
# Full-train SMOTE applied: 108 real + 36 synthetic = 144 samples
# Synthetic class breakdown: HC=36, PD=0
# RFE n_features_to_select grid: [2, 3, 4, 5]
#
# --- mSVM-RBF ---
#   seed=42 fold=1  BA=0.375  AUROC=0.250  PR-AUC=0.641  sw=on
#   seed=42 fold=2  BA=0.500  AUROC=0.219  PR-AUC=0.616  sw=on
#   seed=42 fold=3  BA=0.500  AUROC=0.250  PR-AUC=0.558  sw=on
#   seed=42 fold=4  BA=0.250  AUROC=0.188  PR-AUC=0.542  sw=on
#   seed=42 fold=5  BA=0.500  AUROC=0.562  PR-AUC=0.760  sw=on
#   seed=42 fold=6  BA=0.500  AUROC=0.281  PR-AUC=0.583  sw=on
#   seed=42 fold=7  BA=0.312  AUROC=0.125  PR-AUC=0.528  sw=on
#   seed=42 fold=8  BA=0.500  AUROC=0.625  PR-AUC=0.781  sw=on
#   seed=42 fold=9  BA=0.500  AUROC=0.328  PR-AUC=0.640  sw=on
#   seed=123 fold=1  BA=0.500  AUROC=0.562  PR-AUC=0.712  sw=on
#   seed=123 fold=2  BA=0.500  AUROC=0.438  PR-AUC=0.644  sw=on
#   seed=123 fold=3  BA=0.562  AUROC=0.500  PR-AUC=0.731  sw=on
#   seed=123 fold=4  BA=0.500  AUROC=0.578  PR-AUC=0.720  sw=on
#   seed=123 fold=5  BA=0.500  AUROC=0.438  PR-AUC=0.686  sw=on
#   seed=123 fold=6  BA=0.500  AUROC=0.031  PR-AUC=0.496  sw=on
#   seed=123 fold=7  BA=0.312  AUROC=0.406  PR-AUC=0.734  sw=on
#   seed=123 fold=8  BA=0.500  AUROC=0.594  PR-AUC=0.818  sw=on
#   seed=123 fold=9  BA=0.500  AUROC=0.672  PR-AUC=0.761  sw=on
#   seed=256 fold=1  BA=0.500  AUROC=0.500  PR-AUC=0.690  sw=on
#   seed=256 fold=2  BA=0.500  AUROC=0.344  PR-AUC=0.630  sw=on
#   seed=256 fold=3  BA=0.500  AUROC=0.531  PR-AUC=0.742  sw=on
#   seed=256 fold=4  BA=0.500  AUROC=0.234  PR-AUC=0.616  sw=on
#   seed=256 fold=5  BA=0.500  AUROC=0.312  PR-AUC=0.695  sw=on
#   seed=256 fold=6  BA=0.562  AUROC=0.594  PR-AUC=0.780  sw=on
#   seed=256 fold=7  BA=0.500  AUROC=0.312  PR-AUC=0.637  sw=on
#   seed=256 fold=8  BA=0.500  AUROC=0.562  PR-AUC=0.708  sw=on
#   seed=256 fold=9  BA=0.562  AUROC=0.562  PR-AUC=0.772  sw=on
#
# --- mSVM-Linear ---
#   seed=42 fold=1  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=42 fold=2  BA=0.500  AUROC=0.188  PR-AUC=0.613  sw=on
#   seed=42 fold=3  BA=0.500  AUROC=0.219  PR-AUC=0.570  sw=on
#   seed=42 fold=4  BA=0.500  AUROC=0.266  PR-AUC=0.641  sw=on
#   seed=42 fold=5  BA=0.500  AUROC=0.219  PR-AUC=0.616  sw=on
#   seed=42 fold=6  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=42 fold=7  BA=0.500  AUROC=0.562  PR-AUC=0.747  sw=on
#   seed=42 fold=8  BA=0.500  AUROC=0.562  PR-AUC=0.708  sw=on
#   seed=42 fold=9  BA=0.500  AUROC=0.562  PR-AUC=0.760  sw=on
#   seed=123 fold=1  BA=0.500  AUROC=0.312  PR-AUC=0.611  sw=on
#   seed=123 fold=2  BA=0.500  AUROC=0.500  PR-AUC=0.686  sw=on
#   seed=123 fold=3  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=123 fold=4  BA=0.500  AUROC=0.469  PR-AUC=0.774  sw=on
#   seed=123 fold=5  BA=0.500  AUROC=0.375  PR-AUC=0.679  sw=on
#   seed=123 fold=6  BA=0.500  AUROC=0.312  PR-AUC=0.590  sw=on
#   seed=123 fold=7  BA=0.500  AUROC=0.469  PR-AUC=0.666  sw=on
#   seed=123 fold=8  BA=0.500  AUROC=0.609  PR-AUC=0.797  sw=on
#   seed=123 fold=9  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=256 fold=1  BA=0.500  AUROC=0.422  PR-AUC=0.652  sw=on
#   seed=256 fold=2  BA=0.500  AUROC=0.438  PR-AUC=0.626  sw=on
#   seed=256 fold=3  BA=0.500  AUROC=0.562  PR-AUC=0.708  sw=on
#   seed=256 fold=4  BA=0.500  AUROC=0.469  PR-AUC=0.658  sw=on
#   seed=256 fold=5  BA=0.500  AUROC=0.188  PR-AUC=0.613  sw=on
#   seed=256 fold=6  BA=0.500  AUROC=0.562  PR-AUC=0.749  sw=on
#   seed=256 fold=7  BA=0.500  AUROC=0.375  PR-AUC=0.606  sw=on
#   seed=256 fold=8  BA=0.500  AUROC=0.656  PR-AUC=0.814  sw=on
#   seed=256 fold=9  BA=0.500  AUROC=0.438  PR-AUC=0.699  sw=on
#
# --- mSVM-RFE ---
#   seed=42 fold=1  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=42 fold=2  BA=0.500  AUROC=0.438  PR-AUC=0.640  sw=on
#   seed=42 fold=3  BA=0.500  AUROC=0.469  PR-AUC=0.740  sw=on
#   seed=42 fold=4  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=42 fold=5  BA=0.500  AUROC=0.219  PR-AUC=0.616  sw=on
#   seed=42 fold=6  BA=0.500  AUROC=0.500  PR-AUC=0.709  sw=on
#   seed=42 fold=7  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=42 fold=8  BA=0.500  AUROC=0.672  PR-AUC=0.819  sw=on
#   seed=42 fold=9  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=123 fold=1  BA=0.500  AUROC=0.375  PR-AUC=0.726  sw=on
#   seed=123 fold=2  BA=0.500  AUROC=0.312  PR-AUC=0.583  sw=on
#   seed=123 fold=3  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=123 fold=4  BA=0.500  AUROC=0.469  PR-AUC=0.663  sw=on
#   seed=123 fold=5  BA=0.500  AUROC=0.734  PR-AUC=0.824  sw=on
#   seed=123 fold=6  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=123 fold=7  BA=0.500  AUROC=0.375  PR-AUC=0.632  sw=on
#   seed=123 fold=8  BA=0.500  AUROC=0.609  PR-AUC=0.797  sw=on
#   seed=123 fold=9  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=256 fold=1  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=256 fold=2  BA=0.500  AUROC=0.375  PR-AUC=0.613  sw=on
#   seed=256 fold=3  BA=0.500  AUROC=0.438  PR-AUC=0.640  sw=on
#   seed=256 fold=4  BA=0.500  AUROC=0.594  PR-AUC=0.718  sw=on
#   seed=256 fold=5  BA=0.500  AUROC=0.469  PR-AUC=0.663  sw=on
#   seed=256 fold=6  BA=0.500  AUROC=0.438  PR-AUC=0.713  sw=on
#   seed=256 fold=7  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=256 fold=8  BA=0.500  AUROC=0.781  PR-AUC=0.913  sw=on
#   seed=256 fold=9  BA=0.500  AUROC=0.312  PR-AUC=0.641  sw=on
#
# --- kNN ---
#   seed=42 fold=1  BA=0.250  AUROC=0.156  PR-AUC=0.536  sw=off
#   seed=42 fold=2  BA=0.375  AUROC=0.266  PR-AUC=0.567  sw=off
#   seed=42 fold=3  BA=0.562  AUROC=0.578  PR-AUC=0.762  sw=off
#   seed=42 fold=4  BA=0.438  AUROC=0.281  PR-AUC=0.659  sw=off
#   seed=42 fold=5  BA=0.375  AUROC=0.406  PR-AUC=0.704  sw=off
#   seed=42 fold=6  BA=0.625  AUROC=0.531  PR-AUC=0.741  sw=off
#   seed=42 fold=7  BA=0.312  AUROC=0.375  PR-AUC=0.616  sw=off
#   seed=42 fold=8  BA=0.688  AUROC=0.719  PR-AUC=0.808  sw=off
#   seed=42 fold=9  BA=0.500  AUROC=0.500  PR-AUC=0.679  sw=off
#   seed=123 fold=1  BA=0.500  AUROC=0.281  PR-AUC=0.603  sw=off
#   seed=123 fold=2  BA=0.438  AUROC=0.453  PR-AUC=0.657  sw=off
#   seed=123 fold=3  BA=0.125  AUROC=0.203  PR-AUC=0.573  sw=off
#   seed=123 fold=4  BA=0.438  AUROC=0.312  PR-AUC=0.570  sw=off
#   seed=123 fold=5  BA=0.438  AUROC=0.625  PR-AUC=0.796  sw=off
#   seed=123 fold=6  BA=0.375  AUROC=0.531  PR-AUC=0.719  sw=off
#   seed=123 fold=7  BA=0.250  AUROC=0.344  PR-AUC=0.687  sw=off
#   seed=123 fold=8  BA=0.562  AUROC=0.562  PR-AUC=0.733  sw=off
#   seed=123 fold=9  BA=0.375  AUROC=0.500  PR-AUC=0.683  sw=off
#   seed=256 fold=1  BA=0.438  AUROC=0.469  PR-AUC=0.724  sw=off
#   seed=256 fold=2  BA=0.500  AUROC=0.406  PR-AUC=0.625  sw=off
#   seed=256 fold=3  BA=0.438  AUROC=0.516  PR-AUC=0.727  sw=off
#   seed=256 fold=4  BA=0.312  AUROC=0.281  PR-AUC=0.579  sw=off
#   seed=256 fold=5  BA=0.312  AUROC=0.375  PR-AUC=0.669  sw=off
#   seed=256 fold=6  BA=0.438  AUROC=0.453  PR-AUC=0.646  sw=off
#   seed=256 fold=7  BA=0.688  AUROC=0.719  PR-AUC=0.895  sw=off
#   seed=256 fold=8  BA=0.500  AUROC=0.375  PR-AUC=0.642  sw=off
#   seed=256 fold=9  BA=0.438  AUROC=0.562  PR-AUC=0.758  sw=off
#
# --- GaussianNB ---
#   seed=42 fold=1  BA=0.438  AUROC=0.281  PR-AUC=0.579  sw=on
#   seed=42 fold=2  BA=0.500  AUROC=0.781  PR-AUC=0.921  sw=on
#   seed=42 fold=3  BA=0.375  AUROC=0.344  PR-AUC=0.608  sw=on
#   seed=42 fold=4  BA=0.188  AUROC=0.188  PR-AUC=0.542  sw=on
#   seed=42 fold=5  BA=0.562  AUROC=0.562  PR-AUC=0.784  sw=on
#   seed=42 fold=6  BA=0.438  AUROC=0.344  PR-AUC=0.630  sw=on
#   seed=42 fold=7  BA=0.375  AUROC=0.312  PR-AUC=0.583  sw=on
#   seed=42 fold=8  BA=0.625  AUROC=0.656  PR-AUC=0.830  sw=on
#   seed=42 fold=9  BA=0.625  AUROC=0.625  PR-AUC=0.846  sw=on
#   seed=123 fold=1  BA=0.562  AUROC=0.438  PR-AUC=0.667  sw=on
#   seed=123 fold=2  BA=0.438  AUROC=0.469  PR-AUC=0.669  sw=on
#   seed=123 fold=3  BA=0.438  AUROC=0.438  PR-AUC=0.740  sw=on
#   seed=123 fold=4  BA=0.625  AUROC=0.562  PR-AUC=0.781  sw=on
#   seed=123 fold=5  BA=0.250  AUROC=0.219  PR-AUC=0.547  sw=on
#   seed=123 fold=6  BA=0.438  AUROC=0.406  PR-AUC=0.709  sw=on
#   seed=123 fold=7  BA=0.625  AUROC=0.406  PR-AUC=0.734  sw=on
#   seed=123 fold=8  BA=0.500  AUROC=0.625  PR-AUC=0.773  sw=on
#   seed=123 fold=9  BA=0.625  AUROC=0.562  PR-AUC=0.810  sw=on
#   seed=256 fold=1  BA=0.562  AUROC=0.781  PR-AUC=0.911  sw=on
#   seed=256 fold=2  BA=0.438  AUROC=0.625  PR-AUC=0.773  sw=on
#   seed=256 fold=3  BA=0.438  AUROC=0.500  PR-AUC=0.718  sw=on
#   seed=256 fold=4  BA=0.688  AUROC=0.562  PR-AUC=0.714  sw=on
#   seed=256 fold=5  BA=0.688  AUROC=0.562  PR-AUC=0.824  sw=on
#   seed=256 fold=6  BA=0.500  AUROC=0.406  PR-AUC=0.643  sw=on
#   seed=256 fold=7  BA=0.438  AUROC=0.125  PR-AUC=0.590  sw=on
#   seed=256 fold=8  BA=0.500  AUROC=0.656  PR-AUC=0.844  sw=on
#   seed=256 fold=9  BA=0.625  AUROC=0.625  PR-AUC=0.810  sw=on
#
# --- ElasticNet ---
#   seed=42 fold=1  BA=0.375  AUROC=0.344  PR-AUC=0.598  sw=on
#   seed=42 fold=2  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=42 fold=3  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=42 fold=4  BA=0.188  AUROC=0.250  PR-AUC=0.558  sw=on
#   seed=42 fold=5  BA=0.500  AUROC=0.656  PR-AUC=0.815  sw=on
#   seed=42 fold=6  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=42 fold=7  BA=0.375  AUROC=0.219  PR-AUC=0.547  sw=on
#   seed=42 fold=8  BA=0.562  AUROC=0.562  PR-AUC=0.738  sw=on
#   seed=42 fold=9  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=123 fold=1  BA=0.500  AUROC=0.406  PR-AUC=0.656  sw=on
#   seed=123 fold=2  BA=0.500  AUROC=0.562  PR-AUC=0.781  sw=on
#   seed=123 fold=3  BA=0.438  AUROC=0.500  PR-AUC=0.779  sw=on
#   seed=123 fold=4  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=123 fold=5  BA=0.125  AUROC=0.219  PR-AUC=0.547  sw=on
#   seed=123 fold=6  BA=0.500  AUROC=0.781  PR-AUC=0.834  sw=on
#   seed=123 fold=7  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=123 fold=8  BA=0.438  AUROC=0.562  PR-AUC=0.749  sw=on
#   seed=123 fold=9  BA=0.562  AUROC=0.438  PR-AUC=0.692  sw=on
#   seed=256 fold=1  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=256 fold=2  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=256 fold=3  BA=0.438  AUROC=0.406  PR-AUC=0.627  sw=on
#   seed=256 fold=4  BA=0.500  AUROC=0.641  PR-AUC=0.760  sw=on
#   seed=256 fold=5  BA=0.500  AUROC=0.719  PR-AUC=0.895  sw=on
#   seed=256 fold=6  BA=0.375  AUROC=0.438  PR-AUC=0.648  sw=on
#   seed=256 fold=7  BA=0.562  AUROC=0.281  PR-AUC=0.637  sw=on
#   seed=256 fold=8  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=256 fold=9  BA=0.375  AUROC=0.531  PR-AUC=0.693  sw=on
#
# [balanced] Final metrics (mean across 27 folds):
#              balanced_accuracy_mean  macro_f1_mean  auroc_mean  pr_auc_mean
# classifier
# ElasticNet                    0.456          0.268       0.482        0.687
# GaussianNB                    0.500          0.391       0.484        0.725
# kNN                           0.433          0.399       0.436        0.680
# mSVM-Linear                   0.500          0.250       0.435        0.676
# mSVM-RBF                      0.479          0.292       0.407        0.675
# mSVM-RFE                      0.500          0.250       0.484        0.691
#
# [balanced] Outputs in: C:\Users\hafsa\Python PD Project\MI_BaggedLASSO Pipeline\PDHC new\PDHC-class-aware\Outputs\stage4_HP_PDHC_top5_smote_balanced
#
# ========================================================================
# VARIANT: SMOTE = IMBALANCED  (top 5)
# Stage-3 source: stage3_FS_PDHC_smote_imbalanced
# Output dir    : stage4_HP_PDHC_top5_smote_imbalanced
# ========================================================================
# Top-5 consensus genes loaded from imbalanced Stage 3
# Pre-SMOTE post-feature CSVs saved (train: (5, 108), test: (5, 47))
# Class balance (PD=1, HC=0): {np.str_('HC'): 36, np.str_('PD'): 72}
# Full-train SMOTE applied: 108 real + 108 synthetic = 216 samples
# Synthetic class breakdown: HC=36, PD=72
# RFE n_features_to_select grid: [2, 3, 4, 5]
#
# --- mSVM-RBF ---
#   seed=42 fold=1  BA=0.688  AUROC=0.469  PR-AUC=0.634  sw=on
#   seed=42 fold=2  BA=0.625  AUROC=0.375  PR-AUC=0.608  sw=on
#   seed=42 fold=3  BA=0.625  AUROC=0.594  PR-AUC=0.815  sw=on
#   seed=42 fold=4  BA=0.250  AUROC=0.188  PR-AUC=0.545  sw=on
#   seed=42 fold=5  BA=0.438  AUROC=0.531  PR-AUC=0.771  sw=on
#   seed=42 fold=6  BA=0.500  AUROC=0.688  PR-AUC=0.857  sw=on
#   seed=42 fold=7  BA=0.500  AUROC=0.594  PR-AUC=0.835  sw=on
#   seed=42 fold=8  BA=0.500  AUROC=0.531  PR-AUC=0.791  sw=on
#   seed=42 fold=9  BA=0.688  AUROC=0.531  PR-AUC=0.664  sw=on
#   seed=123 fold=1  BA=0.562  AUROC=0.812  PR-AUC=0.931  sw=on
#   seed=123 fold=2  BA=0.688  AUROC=0.625  PR-AUC=0.731  sw=on
#   seed=123 fold=3  BA=0.438  AUROC=0.375  PR-AUC=0.679  sw=on
#   seed=123 fold=4  BA=0.688  AUROC=0.469  PR-AUC=0.634  sw=on
#   seed=123 fold=5  BA=0.625  AUROC=0.562  PR-AUC=0.726  sw=on
#   seed=123 fold=6  BA=0.750  AUROC=0.812  PR-AUC=0.928  sw=on
#   seed=123 fold=7  BA=0.438  AUROC=0.562  PR-AUC=0.760  sw=on
#   seed=123 fold=8  BA=0.688  AUROC=0.812  PR-AUC=0.909  sw=on
#   seed=123 fold=9  BA=0.562  AUROC=0.656  PR-AUC=0.820  sw=on
#   seed=256 fold=1  BA=0.750  AUROC=0.781  PR-AUC=0.884  sw=on
#   seed=256 fold=2  BA=0.312  AUROC=0.188  PR-AUC=0.557  sw=on
#   seed=256 fold=3  BA=0.688  AUROC=0.812  PR-AUC=0.920  sw=on
#   seed=256 fold=4  BA=0.312  AUROC=0.281  PR-AUC=0.587  sw=on
#   seed=256 fold=5  BA=0.875  AUROC=0.750  PR-AUC=0.771  sw=on
#   seed=256 fold=6  BA=0.688  AUROC=0.781  PR-AUC=0.895  sw=on
#   seed=256 fold=7  BA=0.562  AUROC=0.531  PR-AUC=0.687  sw=on
#   seed=256 fold=8  BA=0.750  AUROC=0.625  PR-AUC=0.731  sw=on
#   seed=256 fold=9  BA=0.500  AUROC=0.562  PR-AUC=0.708  sw=on
#
# --- mSVM-Linear ---
#   seed=42 fold=1  BA=0.562  AUROC=0.656  PR-AUC=0.739  sw=on
#   seed=42 fold=2  BA=0.500  AUROC=0.438  PR-AUC=0.689  sw=on
#   seed=42 fold=3  BA=0.625  AUROC=0.562  PR-AUC=0.701  sw=on
#   seed=42 fold=4  BA=0.375  AUROC=0.281  PR-AUC=0.650  sw=on
#   seed=42 fold=5  BA=0.812  AUROC=0.750  PR-AUC=0.823  sw=on
#   seed=42 fold=6  BA=0.625  AUROC=0.594  PR-AUC=0.703  sw=on
#   seed=42 fold=7  BA=0.625  AUROC=0.688  PR-AUC=0.802  sw=on
#   seed=42 fold=8  BA=0.438  AUROC=0.438  PR-AUC=0.667  sw=on
#   seed=42 fold=9  BA=0.688  AUROC=0.625  PR-AUC=0.789  sw=on
#   seed=123 fold=1  BA=0.625  AUROC=0.844  PR-AUC=0.938  sw=on
#   seed=123 fold=2  BA=0.625  AUROC=0.656  PR-AUC=0.822  sw=on
#   seed=123 fold=3  BA=0.312  AUROC=0.312  PR-AUC=0.596  sw=on
#   seed=123 fold=4  BA=0.688  AUROC=0.594  PR-AUC=0.703  sw=on
#   seed=123 fold=5  BA=0.688  AUROC=0.594  PR-AUC=0.757  sw=on
#   seed=123 fold=6  BA=0.812  AUROC=0.875  PR-AUC=0.950  sw=on
#   seed=123 fold=7  BA=0.750  AUROC=0.812  PR-AUC=0.896  sw=on
#   seed=123 fold=8  BA=0.375  AUROC=0.438  PR-AUC=0.702  sw=on
#   seed=123 fold=9  BA=0.688  AUROC=0.688  PR-AUC=0.751  sw=on
#   seed=256 fold=1  BA=0.688  AUROC=0.781  PR-AUC=0.884  sw=on
#   seed=256 fold=2  BA=0.500  AUROC=0.625  PR-AUC=0.729  sw=on
#   seed=256 fold=3  BA=0.625  AUROC=0.656  PR-AUC=0.839  sw=on
#   seed=256 fold=4  BA=0.375  AUROC=0.344  PR-AUC=0.598  sw=on
#   seed=256 fold=5  BA=0.750  AUROC=0.719  PR-AUC=0.811  sw=on
#   seed=256 fold=6  BA=0.562  AUROC=0.594  PR-AUC=0.795  sw=on
#   seed=256 fold=7  BA=0.500  AUROC=0.531  PR-AUC=0.693  sw=on
#   seed=256 fold=8  BA=0.688  AUROC=0.594  PR-AUC=0.842  sw=on
#   seed=256 fold=9  BA=0.750  AUROC=0.719  PR-AUC=0.760  sw=on
#
# --- mSVM-RFE ---
#   seed=42 fold=1  BA=0.688  AUROC=0.656  PR-AUC=0.788  sw=on
#   seed=42 fold=2  BA=0.438  AUROC=0.531  PR-AUC=0.762  sw=on
#   seed=42 fold=3  BA=0.500  AUROC=0.578  PR-AUC=0.701  sw=on
#   seed=42 fold=4  BA=0.250  AUROC=0.172  PR-AUC=0.523  sw=on
#   seed=42 fold=5  BA=0.750  AUROC=0.734  PR-AUC=0.760  sw=on
#   seed=42 fold=6  BA=0.625  AUROC=0.625  PR-AUC=0.773  sw=on
#   seed=42 fold=7  BA=0.688  AUROC=0.875  PR-AUC=0.947  sw=on
#   seed=42 fold=8  BA=0.562  AUROC=0.438  PR-AUC=0.667  sw=on
#   seed=42 fold=9  BA=0.688  AUROC=0.562  PR-AUC=0.726  sw=on
#   seed=123 fold=1  BA=0.750  AUROC=0.938  PR-AUC=0.975  sw=on
#   seed=123 fold=2  BA=0.625  AUROC=0.594  PR-AUC=0.771  sw=on
#   seed=123 fold=3  BA=0.375  AUROC=0.188  PR-AUC=0.545  sw=on
#   seed=123 fold=4  BA=0.688  AUROC=0.594  PR-AUC=0.703  sw=on
#   seed=123 fold=5  BA=0.625  AUROC=0.594  PR-AUC=0.747  sw=on
#   seed=123 fold=6  BA=0.812  AUROC=0.875  PR-AUC=0.950  sw=on
#   seed=123 fold=7  BA=0.688  AUROC=0.844  PR-AUC=0.907  sw=on
#   seed=123 fold=8  BA=0.375  AUROC=0.469  PR-AUC=0.713  sw=on
#   seed=123 fold=9  BA=0.688  AUROC=0.688  PR-AUC=0.751  sw=on
#   seed=256 fold=1  BA=0.750  AUROC=0.906  PR-AUC=0.959  sw=on
#   seed=256 fold=2  BA=0.625  AUROC=0.625  PR-AUC=0.726  sw=on
#   seed=256 fold=3  BA=0.625  AUROC=0.656  PR-AUC=0.771  sw=on
#   seed=256 fold=4  BA=0.375  AUROC=0.312  PR-AUC=0.590  sw=on
#   seed=256 fold=5  BA=0.750  AUROC=0.656  PR-AUC=0.735  sw=on
#   seed=256 fold=6  BA=0.562  AUROC=0.562  PR-AUC=0.753  sw=on
#   seed=256 fold=7  BA=0.562  AUROC=0.500  PR-AUC=0.668  sw=on
#   seed=256 fold=8  BA=0.688  AUROC=0.594  PR-AUC=0.842  sw=on
#   seed=256 fold=9  BA=0.688  AUROC=0.719  PR-AUC=0.814  sw=on
#
# --- kNN ---
#   seed=42 fold=1  BA=0.625  AUROC=0.656  PR-AUC=0.743  sw=off
#   seed=42 fold=2  BA=0.500  AUROC=0.469  PR-AUC=0.637  sw=off
#   seed=42 fold=3  BA=0.500  AUROC=0.625  PR-AUC=0.814  sw=off
#   seed=42 fold=4  BA=0.438  AUROC=0.406  PR-AUC=0.640  sw=off
#   seed=42 fold=5  BA=0.375  AUROC=0.562  PR-AUC=0.725  sw=off
#   seed=42 fold=6  BA=0.500  AUROC=0.625  PR-AUC=0.812  sw=off
#   seed=42 fold=7  BA=0.438  AUROC=0.672  PR-AUC=0.791  sw=off
#   seed=42 fold=8  BA=0.562  AUROC=0.719  PR-AUC=0.816  sw=off
#   seed=42 fold=9  BA=0.688  AUROC=0.562  PR-AUC=0.680  sw=off
#   seed=123 fold=1  BA=0.562  AUROC=0.750  PR-AUC=0.869  sw=off
#   seed=123 fold=2  BA=0.625  AUROC=0.719  PR-AUC=0.864  sw=off
#   seed=123 fold=3  BA=0.500  AUROC=0.375  PR-AUC=0.642  sw=off
#   seed=123 fold=4  BA=0.438  AUROC=0.297  PR-AUC=0.589  sw=off
#   seed=123 fold=5  BA=0.625  AUROC=0.609  PR-AUC=0.730  sw=off
#   seed=123 fold=6  BA=0.688  AUROC=0.719  PR-AUC=0.799  sw=off
#   seed=123 fold=7  BA=0.625  AUROC=0.625  PR-AUC=0.733  sw=off
#   seed=123 fold=8  BA=0.750  AUROC=0.750  PR-AUC=0.781  sw=off
#   seed=123 fold=9  BA=0.688  AUROC=0.750  PR-AUC=0.806  sw=off
#   seed=256 fold=1  BA=0.500  AUROC=0.422  PR-AUC=0.681  sw=off
#   seed=256 fold=2  BA=0.375  AUROC=0.344  PR-AUC=0.597  sw=off
#   seed=256 fold=3  BA=0.812  AUROC=0.797  PR-AUC=0.837  sw=off
#   seed=256 fold=4  BA=0.312  AUROC=0.281  PR-AUC=0.576  sw=off
#   seed=256 fold=5  BA=0.438  AUROC=0.594  PR-AUC=0.725  sw=off
#   seed=256 fold=6  BA=0.625  AUROC=0.672  PR-AUC=0.767  sw=off
#   seed=256 fold=7  BA=0.562  AUROC=0.578  PR-AUC=0.718  sw=off
#   seed=256 fold=8  BA=0.688  AUROC=0.656  PR-AUC=0.744  sw=off
#   seed=256 fold=9  BA=0.562  AUROC=0.781  PR-AUC=0.899  sw=off
#
# --- GaussianNB ---
#   seed=42 fold=1  BA=0.625  AUROC=0.531  PR-AUC=0.728  sw=on
#   seed=42 fold=2  BA=0.500  AUROC=0.469  PR-AUC=0.700  sw=on
#   seed=42 fold=3  BA=0.625  AUROC=0.625  PR-AUC=0.807  sw=on
#   seed=42 fold=4  BA=0.250  AUROC=0.250  PR-AUC=0.587  sw=on
#   seed=42 fold=5  BA=0.750  AUROC=0.719  PR-AUC=0.811  sw=on
#   seed=42 fold=6  BA=0.562  AUROC=0.469  PR-AUC=0.655  sw=on
#   seed=42 fold=7  BA=0.625  AUROC=0.625  PR-AUC=0.729  sw=on
#   seed=42 fold=8  BA=0.688  AUROC=0.656  PR-AUC=0.744  sw=on
#   seed=42 fold=9  BA=0.625  AUROC=0.594  PR-AUC=0.747  sw=on
#   seed=123 fold=1  BA=0.625  AUROC=0.812  PR-AUC=0.909  sw=on
#   seed=123 fold=2  BA=0.625  AUROC=0.688  PR-AUC=0.864  sw=on
#   seed=123 fold=3  BA=0.375  AUROC=0.312  PR-AUC=0.653  sw=on
#   seed=123 fold=4  BA=0.500  AUROC=0.531  PR-AUC=0.691  sw=on
#   seed=123 fold=5  BA=0.688  AUROC=0.500  PR-AUC=0.709  sw=on
#   seed=123 fold=6  BA=0.562  AUROC=0.719  PR-AUC=0.890  sw=on
#   seed=123 fold=7  BA=0.812  AUROC=0.688  PR-AUC=0.806  sw=on
#   seed=123 fold=8  BA=0.688  AUROC=0.594  PR-AUC=0.771  sw=on
#   seed=123 fold=9  BA=0.625  AUROC=0.688  PR-AUC=0.802  sw=on
#   seed=256 fold=1  BA=0.750  AUROC=0.844  PR-AUC=0.929  sw=on
#   seed=256 fold=2  BA=0.438  AUROC=0.469  PR-AUC=0.655  sw=on
#   seed=256 fold=3  BA=0.688  AUROC=0.688  PR-AUC=0.853  sw=on
#   seed=256 fold=4  BA=0.500  AUROC=0.312  PR-AUC=0.611  sw=on
#   seed=256 fold=5  BA=0.750  AUROC=0.531  PR-AUC=0.664  sw=on
#   seed=256 fold=6  BA=0.625  AUROC=0.562  PR-AUC=0.787  sw=on
#   seed=256 fold=7  BA=0.500  AUROC=0.344  PR-AUC=0.598  sw=on
#   seed=256 fold=8  BA=0.688  AUROC=0.625  PR-AUC=0.784  sw=on
#   seed=256 fold=9  BA=0.625  AUROC=0.688  PR-AUC=0.748  sw=on
#
# --- ElasticNet ---
#   seed=42 fold=1  BA=0.625  AUROC=0.750  PR-AUC=0.771  sw=on
#   seed=42 fold=2  BA=0.562  AUROC=0.406  PR-AUC=0.681  sw=on
#   seed=42 fold=3  BA=0.688  AUROC=0.625  PR-AUC=0.726  sw=on
#   seed=42 fold=4  BA=0.375  AUROC=0.281  PR-AUC=0.650  sw=on
#   seed=42 fold=5  BA=0.688  AUROC=0.719  PR-AUC=0.760  sw=on
#   seed=42 fold=6  BA=0.625  AUROC=0.625  PR-AUC=0.766  sw=on
#   seed=42 fold=7  BA=0.562  AUROC=0.688  PR-AUC=0.751  sw=on
#   seed=42 fold=8  BA=0.562  AUROC=0.438  PR-AUC=0.667  sw=on
#   seed=42 fold=9  BA=0.688  AUROC=0.625  PR-AUC=0.789  sw=on
#   seed=123 fold=1  BA=0.562  AUROC=0.812  PR-AUC=0.928  sw=on
#   seed=123 fold=2  BA=0.750  AUROC=0.625  PR-AUC=0.784  sw=on
#   seed=123 fold=3  BA=0.375  AUROC=0.188  PR-AUC=0.545  sw=on
#   seed=123 fold=4  BA=0.625  AUROC=0.500  PR-AUC=0.655  sw=on
#   seed=123 fold=5  BA=0.625  AUROC=0.625  PR-AUC=0.766  sw=on
#   seed=123 fold=6  BA=0.812  AUROC=0.906  PR-AUC=0.966  sw=on
#   seed=123 fold=7  BA=0.750  AUROC=0.781  PR-AUC=0.887  sw=on
#   seed=123 fold=8  BA=0.438  AUROC=0.438  PR-AUC=0.702  sw=on
#   seed=123 fold=9  BA=0.625  AUROC=0.625  PR-AUC=0.720  sw=on
#   seed=256 fold=1  BA=0.625  AUROC=0.781  PR-AUC=0.884  sw=on
#   seed=256 fold=2  BA=0.438  AUROC=0.562  PR-AUC=0.705  sw=on
#   seed=256 fold=3  BA=0.625  AUROC=0.594  PR-AUC=0.791  sw=on
#   seed=256 fold=4  BA=0.500  AUROC=0.344  PR-AUC=0.598  sw=on
#   seed=256 fold=5  BA=0.688  AUROC=0.781  PR-AUC=0.864  sw=on
#   seed=256 fold=6  BA=0.562  AUROC=0.516  PR-AUC=0.674  sw=on
#   seed=256 fold=7  BA=0.500  AUROC=0.531  PR-AUC=0.687  sw=on
#   seed=256 fold=8  BA=0.625  AUROC=0.594  PR-AUC=0.842  sw=on
#   seed=256 fold=9  BA=0.688  AUROC=0.719  PR-AUC=0.760  sw=on
#
# [imbalanced] Final metrics (mean across 27 folds):
#              balanced_accuracy_mean  macro_f1_mean  auroc_mean  pr_auc_mean
# classifier
# ElasticNet                    0.600          0.596       0.595        0.753
# GaussianNB                    0.604          0.601       0.575        0.749
# kNN                           0.556          0.546       0.593        0.741
# mSVM-Linear                   0.602          0.599       0.608        0.764
# mSVM-RBF                      0.581          0.569       0.574        0.755
# mSVM-RFE                      0.609          0.606       0.611        0.762
#
# [imbalanced] Outputs in: C:\Users\hafsa\Python PD Project\MI_BaggedLASSO Pipeline\PDHC new\PDHC-class-aware\Outputs\stage4_HP_PDHC_top5_smote_imbalanced
#
# ========================================================================
# VARIANT: SMOTE = BALANCED  (top 10)
# Stage-3 source: stage3_FS_PDHC_smote_balanced
# Output dir    : stage4_HP_PDHC_top10_smote_balanced
# ========================================================================
# Top-10 consensus genes loaded from balanced Stage 3
# Pre-SMOTE post-feature CSVs saved (train: (10, 108), test: (10, 47))
# Class balance (PD=1, HC=0): {np.str_('HC'): 36, np.str_('PD'): 72}
# Full-train SMOTE applied: 108 real + 36 synthetic = 144 samples
# Synthetic class breakdown: HC=36, PD=0
# RFE n_features_to_select grid: [2, 5, 9, 10]
#
# --- mSVM-RBF ---
#   seed=42 fold=1  BA=0.312  AUROC=0.469  PR-AUC=0.774  sw=on
#   seed=42 fold=2  BA=0.625  AUROC=0.406  PR-AUC=0.734  sw=on
#   seed=42 fold=3  BA=0.500  AUROC=0.688  PR-AUC=0.853  sw=on
#   seed=42 fold=4  BA=0.500  AUROC=0.344  PR-AUC=0.667  sw=on
#   seed=42 fold=5  BA=0.500  AUROC=0.469  PR-AUC=0.663  sw=on
#   seed=42 fold=6  BA=0.750  AUROC=0.656  PR-AUC=0.858  sw=on
#   seed=42 fold=7  BA=0.500  AUROC=0.562  PR-AUC=0.794  sw=on
#   seed=42 fold=8  BA=0.562  AUROC=0.656  PR-AUC=0.788  sw=on
#   seed=42 fold=9  BA=0.500  AUROC=0.594  PR-AUC=0.718  sw=on
#   seed=123 fold=1  BA=0.375  AUROC=0.406  PR-AUC=0.636  sw=on
#   seed=123 fold=2  BA=0.375  AUROC=0.438  PR-AUC=0.637  sw=on
#   seed=123 fold=3  BA=0.375  AUROC=0.375  PR-AUC=0.723  sw=on
#   seed=123 fold=4  BA=0.500  AUROC=0.500  PR-AUC=0.707  sw=on
#   seed=123 fold=5  BA=0.438  AUROC=0.531  PR-AUC=0.776  sw=on
#   seed=123 fold=6  BA=0.625  AUROC=0.688  PR-AUC=0.869  sw=on
#   seed=123 fold=7  BA=0.500  AUROC=0.625  PR-AUC=0.726  sw=on
#   seed=123 fold=8  BA=0.500  AUROC=0.719  PR-AUC=0.878  sw=on
#   seed=123 fold=9  BA=0.500  AUROC=0.875  PR-AUC=0.947  sw=on
#   seed=256 fold=1  BA=0.500  AUROC=0.719  PR-AUC=0.871  sw=on
#   seed=256 fold=2  BA=0.500  AUROC=0.375  PR-AUC=0.625  sw=on
#   seed=256 fold=3  BA=0.500  AUROC=0.406  PR-AUC=0.614  sw=on
#   seed=256 fold=4  BA=0.438  AUROC=0.281  PR-AUC=0.575  sw=on
#   seed=256 fold=5  BA=0.375  AUROC=0.406  PR-AUC=0.721  sw=on
#   seed=256 fold=6  BA=0.438  AUROC=0.281  PR-AUC=0.596  sw=on
#   seed=256 fold=7  BA=0.500  AUROC=0.438  PR-AUC=0.733  sw=on
#   seed=256 fold=8  BA=0.562  AUROC=0.594  PR-AUC=0.776  sw=on
#   seed=256 fold=9  BA=0.500  AUROC=0.531  PR-AUC=0.730  sw=on
#
# --- mSVM-Linear ---
#   seed=42 fold=1  BA=0.438  AUROC=0.469  PR-AUC=0.658  sw=on
#   seed=42 fold=2  BA=0.688  AUROC=0.703  PR-AUC=0.869  sw=on
#   seed=42 fold=3  BA=0.500  AUROC=0.547  PR-AUC=0.696  sw=on
#   seed=42 fold=4  BA=0.500  AUROC=0.406  PR-AUC=0.716  sw=on
#   seed=42 fold=5  BA=0.562  AUROC=0.719  PR-AUC=0.760  sw=on
#   seed=42 fold=6  BA=0.500  AUROC=0.219  PR-AUC=0.578  sw=on
#   seed=42 fold=7  BA=0.438  AUROC=0.531  PR-AUC=0.684  sw=on
#   seed=42 fold=8  BA=0.500  AUROC=0.406  PR-AUC=0.656  sw=on
#   seed=42 fold=9  BA=0.500  AUROC=0.562  PR-AUC=0.807  sw=on
#   seed=123 fold=1  BA=0.438  AUROC=0.438  PR-AUC=0.679  sw=on
#   seed=123 fold=2  BA=0.500  AUROC=0.469  PR-AUC=0.646  sw=on
#   seed=123 fold=3  BA=0.438  AUROC=0.344  PR-AUC=0.627  sw=on
#   seed=123 fold=4  BA=0.500  AUROC=0.531  PR-AUC=0.687  sw=on
#   seed=123 fold=5  BA=0.312  AUROC=0.375  PR-AUC=0.611  sw=on
#   seed=123 fold=6  BA=0.500  AUROC=0.438  PR-AUC=0.640  sw=on
#   seed=123 fold=7  BA=0.500  AUROC=0.281  PR-AUC=0.658  sw=on
#   seed=123 fold=8  BA=0.625  AUROC=0.562  PR-AUC=0.790  sw=on
#   seed=123 fold=9  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=256 fold=1  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=256 fold=2  BA=0.500  AUROC=0.531  PR-AUC=0.739  sw=on
#   seed=256 fold=3  BA=0.500  AUROC=0.375  PR-AUC=0.608  sw=on
#   seed=256 fold=4  BA=0.500  AUROC=0.375  PR-AUC=0.608  sw=on
#   seed=256 fold=5  BA=0.500  AUROC=0.375  PR-AUC=0.635  sw=on
#   seed=256 fold=6  BA=0.500  AUROC=0.344  PR-AUC=0.627  sw=on
#   seed=256 fold=7  BA=0.500  AUROC=0.281  PR-AUC=0.633  sw=on
#   seed=256 fold=8  BA=0.562  AUROC=0.438  PR-AUC=0.651  sw=on
#   seed=256 fold=9  BA=0.438  AUROC=0.469  PR-AUC=0.658  sw=on
#
# --- mSVM-RFE ---
#   seed=42 fold=1  BA=0.500  AUROC=0.438  PR-AUC=0.692  sw=on
#   seed=42 fold=2  BA=0.688  AUROC=0.719  PR-AUC=0.878  sw=on
#   seed=42 fold=3  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=42 fold=4  BA=0.500  AUROC=0.469  PR-AUC=0.720  sw=on
#   seed=42 fold=5  BA=0.562  AUROC=0.719  PR-AUC=0.760  sw=on
#   seed=42 fold=6  BA=0.500  AUROC=0.125  PR-AUC=0.528  sw=on
#   seed=42 fold=7  BA=0.438  AUROC=0.531  PR-AUC=0.684  sw=on
#   seed=42 fold=8  BA=0.500  AUROC=0.406  PR-AUC=0.656  sw=on
#   seed=42 fold=9  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=123 fold=1  BA=0.438  AUROC=0.391  PR-AUC=0.661  sw=on
#   seed=123 fold=2  BA=0.438  AUROC=0.547  PR-AUC=0.700  sw=on
#   seed=123 fold=3  BA=0.438  AUROC=0.438  PR-AUC=0.713  sw=on
#   seed=123 fold=4  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=123 fold=5  BA=0.312  AUROC=0.406  PR-AUC=0.674  sw=on
#   seed=123 fold=6  BA=0.500  AUROC=0.531  PR-AUC=0.777  sw=on
#   seed=123 fold=7  BA=0.500  AUROC=0.219  PR-AUC=0.550  sw=on
#   seed=123 fold=8  BA=0.500  AUROC=0.625  PR-AUC=0.807  sw=on
#   seed=123 fold=9  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=256 fold=1  BA=0.500  AUROC=0.281  PR-AUC=0.600  sw=on
#   seed=256 fold=2  BA=0.500  AUROC=0.781  PR-AUC=0.899  sw=on
#   seed=256 fold=3  BA=0.438  AUROC=0.500  PR-AUC=0.734  sw=on
#   seed=256 fold=4  BA=0.500  AUROC=0.406  PR-AUC=0.616  sw=on
#   seed=256 fold=5  BA=0.500  AUROC=0.828  PR-AUC=0.894  sw=on
#   seed=256 fold=6  BA=0.438  AUROC=0.438  PR-AUC=0.718  sw=on
#   seed=256 fold=7  BA=0.500  AUROC=0.688  PR-AUC=0.797  sw=on
#   seed=256 fold=8  BA=0.562  AUROC=0.438  PR-AUC=0.651  sw=on
#   seed=256 fold=9  BA=0.500  AUROC=0.516  PR-AUC=0.656  sw=on
#
# --- kNN ---
#   seed=42 fold=1  BA=0.562  AUROC=0.578  PR-AUC=0.726  sw=off
#   seed=42 fold=2  BA=0.438  AUROC=0.297  PR-AUC=0.594  sw=off
#   seed=42 fold=3  BA=0.438  AUROC=0.438  PR-AUC=0.694  sw=off
#   seed=42 fold=4  BA=0.438  AUROC=0.375  PR-AUC=0.633  sw=off
#   seed=42 fold=5  BA=0.500  AUROC=0.438  PR-AUC=0.650  sw=off
#   seed=42 fold=6  BA=0.625  AUROC=0.516  PR-AUC=0.740  sw=off
#   seed=42 fold=7  BA=0.625  AUROC=0.688  PR-AUC=0.827  sw=off
#   seed=42 fold=8  BA=0.625  AUROC=0.672  PR-AUC=0.822  sw=off
#   seed=42 fold=9  BA=0.500  AUROC=0.719  PR-AUC=0.804  sw=off
#   seed=123 fold=1  BA=0.562  AUROC=0.422  PR-AUC=0.676  sw=off
#   seed=123 fold=2  BA=0.500  AUROC=0.531  PR-AUC=0.664  sw=off
#   seed=123 fold=3  BA=0.438  AUROC=0.344  PR-AUC=0.606  sw=off
#   seed=123 fold=4  BA=0.625  AUROC=0.656  PR-AUC=0.735  sw=off
#   seed=123 fold=5  BA=0.438  AUROC=0.562  PR-AUC=0.766  sw=off
#   seed=123 fold=6  BA=0.625  AUROC=0.812  PR-AUC=0.913  sw=off
#   seed=123 fold=7  BA=0.562  AUROC=0.625  PR-AUC=0.766  sw=off
#   seed=123 fold=8  BA=0.562  AUROC=0.516  PR-AUC=0.757  sw=off
#   seed=123 fold=9  BA=0.688  AUROC=0.781  PR-AUC=0.848  sw=off
#   seed=256 fold=1  BA=0.562  AUROC=0.734  PR-AUC=0.844  sw=off
#   seed=256 fold=2  BA=0.500  AUROC=0.562  PR-AUC=0.786  sw=off
#   seed=256 fold=3  BA=0.438  AUROC=0.531  PR-AUC=0.676  sw=off
#   seed=256 fold=4  BA=0.250  AUROC=0.125  PR-AUC=0.535  sw=off
#   seed=256 fold=5  BA=0.562  AUROC=0.641  PR-AUC=0.833  sw=off
#   seed=256 fold=6  BA=0.625  AUROC=0.594  PR-AUC=0.767  sw=off
#   seed=256 fold=7  BA=0.562  AUROC=0.406  PR-AUC=0.709  sw=off
#   seed=256 fold=8  BA=0.562  AUROC=0.625  PR-AUC=0.724  sw=off
#   seed=256 fold=9  BA=0.625  AUROC=0.625  PR-AUC=0.727  sw=off
#
# --- GaussianNB ---
#   seed=42 fold=1  BA=0.750  AUROC=0.750  PR-AUC=0.890  sw=on
#   seed=42 fold=2  BA=0.750  AUROC=0.781  PR-AUC=0.904  sw=on
#   seed=42 fold=3  BA=0.375  AUROC=0.531  PR-AUC=0.717  sw=on
#   seed=42 fold=4  BA=0.250  AUROC=0.250  PR-AUC=0.555  sw=on
#   seed=42 fold=5  BA=0.625  AUROC=0.750  PR-AUC=0.771  sw=on
#   seed=42 fold=6  BA=0.562  AUROC=0.375  PR-AUC=0.639  sw=on
#   seed=42 fold=7  BA=0.438  AUROC=0.500  PR-AUC=0.655  sw=on
#   seed=42 fold=8  BA=0.625  AUROC=0.719  PR-AUC=0.814  sw=on
#   seed=42 fold=9  BA=0.562  AUROC=0.594  PR-AUC=0.718  sw=on
#   seed=123 fold=1  BA=0.562  AUROC=0.594  PR-AUC=0.718  sw=on
#   seed=123 fold=2  BA=0.562  AUROC=0.625  PR-AUC=0.731  sw=on
#   seed=123 fold=3  BA=0.500  AUROC=0.375  PR-AUC=0.629  sw=on
#   seed=123 fold=4  BA=0.562  AUROC=0.656  PR-AUC=0.807  sw=on
#   seed=123 fold=5  BA=0.500  AUROC=0.312  PR-AUC=0.586  sw=on
#   seed=123 fold=6  BA=0.688  AUROC=0.719  PR-AUC=0.861  sw=on
#   seed=123 fold=7  BA=0.562  AUROC=0.812  PR-AUC=0.876  sw=on
#   seed=123 fold=8  BA=0.562  AUROC=0.562  PR-AUC=0.714  sw=on
#   seed=123 fold=9  BA=0.625  AUROC=0.656  PR-AUC=0.807  sw=on
#   seed=256 fold=1  BA=0.750  AUROC=0.875  PR-AUC=0.932  sw=on
#   seed=256 fold=2  BA=0.438  AUROC=0.625  PR-AUC=0.766  sw=on
#   seed=256 fold=3  BA=0.438  AUROC=0.562  PR-AUC=0.684  sw=on
#   seed=256 fold=4  BA=0.500  AUROC=0.188  PR-AUC=0.540  sw=on
#   seed=256 fold=5  BA=0.812  AUROC=0.781  PR-AUC=0.907  sw=on
#   seed=256 fold=6  BA=0.375  AUROC=0.469  PR-AUC=0.713  sw=on
#   seed=256 fold=7  BA=0.375  AUROC=0.344  PR-AUC=0.674  sw=on
#   seed=256 fold=8  BA=0.688  AUROC=0.469  PR-AUC=0.682  sw=on
#   seed=256 fold=9  BA=0.750  AUROC=0.781  PR-AUC=0.911  sw=on
#
# --- ElasticNet ---
#   seed=42 fold=1  BA=0.500  AUROC=0.500  PR-AUC=0.707  sw=on
#   seed=42 fold=2  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=42 fold=3  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=42 fold=4  BA=0.375  AUROC=0.406  PR-AUC=0.682  sw=on
#   seed=42 fold=5  BA=0.562  AUROC=0.688  PR-AUC=0.751  sw=on
#   seed=42 fold=6  BA=0.500  AUROC=0.344  PR-AUC=0.617  sw=on
#   seed=42 fold=7  BA=0.375  AUROC=0.531  PR-AUC=0.684  sw=on
#   seed=42 fold=8  BA=0.500  AUROC=0.625  PR-AUC=0.731  sw=on
#   seed=42 fold=9  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=123 fold=1  BA=0.438  AUROC=0.438  PR-AUC=0.710  sw=on
#   seed=123 fold=2  BA=0.500  AUROC=0.531  PR-AUC=0.752  sw=on
#   seed=123 fold=3  BA=0.375  AUROC=0.250  PR-AUC=0.567  sw=on
#   seed=123 fold=4  BA=0.500  AUROC=0.562  PR-AUC=0.701  sw=on
#   seed=123 fold=5  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=123 fold=6  BA=0.625  AUROC=0.594  PR-AUC=0.815  sw=on
#   seed=123 fold=7  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=123 fold=8  BA=0.500  AUROC=0.594  PR-AUC=0.776  sw=on
#   seed=123 fold=9  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=256 fold=1  BA=0.688  AUROC=0.844  PR-AUC=0.907  sw=on
#   seed=256 fold=2  BA=0.500  AUROC=0.656  PR-AUC=0.830  sw=on
#   seed=256 fold=3  BA=0.375  AUROC=0.500  PR-AUC=0.655  sw=on
#   seed=256 fold=4  BA=0.500  AUROC=0.375  PR-AUC=0.608  sw=on
#   seed=256 fold=5  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=256 fold=6  BA=0.438  AUROC=0.438  PR-AUC=0.658  sw=on
#   seed=256 fold=7  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=on
#   seed=256 fold=8  BA=0.500  AUROC=0.562  PR-AUC=0.708  sw=on
#   seed=256 fold=9  BA=0.438  AUROC=0.656  PR-AUC=0.792  sw=on
#
# [balanced] Final metrics (mean across 27 folds):
#              balanced_accuracy_mean  macro_f1_mean  auroc_mean  pr_auc_mean
# classifier
# ElasticNet                    0.488          0.345       0.522        0.703
# GaussianNB                    0.562          0.524       0.580        0.748
# kNN                           0.535          0.491       0.549        0.734
# mSVM-Linear                   0.498          0.336       0.451        0.676
# mSVM-RBF                      0.491          0.358       0.520        0.740
# mSVM-RFE                      0.491          0.334       0.498        0.705
#
# [balanced] Outputs in: C:\Users\hafsa\Python PD Project\MI_BaggedLASSO Pipeline\PDHC new\PDHC-class-aware\Outputs\stage4_HP_PDHC_top10_smote_balanced
#
# ========================================================================
# VARIANT: SMOTE = IMBALANCED  (top 10)
# Stage-3 source: stage3_FS_PDHC_smote_imbalanced
# Output dir    : stage4_HP_PDHC_top10_smote_imbalanced
# ========================================================================
# Top-10 consensus genes loaded from imbalanced Stage 3
# Pre-SMOTE post-feature CSVs saved (train: (10, 108), test: (10, 47))
# Class balance (PD=1, HC=0): {np.str_('HC'): 36, np.str_('PD'): 72}
# Full-train SMOTE applied: 108 real + 108 synthetic = 216 samples
# Synthetic class breakdown: HC=36, PD=72
# RFE n_features_to_select grid: [2, 5, 9, 10]
#
# --- mSVM-RBF ---
#   seed=42 fold=1  BA=0.688  AUROC=0.562  PR-AUC=0.726  sw=on
#   seed=42 fold=2  BA=0.688  AUROC=0.875  PR-AUC=0.932  sw=on
#   seed=42 fold=3  BA=0.500  AUROC=0.625  PR-AUC=0.766  sw=on
#   seed=42 fold=4  BA=0.250  AUROC=0.188  PR-AUC=0.607  sw=on
#   seed=42 fold=5  BA=0.688  AUROC=0.719  PR-AUC=0.814  sw=on
#   seed=42 fold=6  BA=0.562  AUROC=0.688  PR-AUC=0.846  sw=on
#   seed=42 fold=7  BA=0.625  AUROC=0.781  PR-AUC=0.921  sw=on
#   seed=42 fold=8  BA=0.375  AUROC=0.500  PR-AUC=0.685  sw=on
#   seed=42 fold=9  BA=0.688  AUROC=0.500  PR-AUC=0.668  sw=on
#   seed=123 fold=1  BA=0.625  AUROC=0.750  PR-AUC=0.890  sw=on
#   seed=123 fold=2  BA=0.625  AUROC=0.594  PR-AUC=0.791  sw=on
#   seed=123 fold=3  BA=0.312  AUROC=0.312  PR-AUC=0.591  sw=on
#   seed=123 fold=4  BA=0.625  AUROC=0.500  PR-AUC=0.655  sw=on
#   seed=123 fold=5  BA=0.625  AUROC=0.625  PR-AUC=0.720  sw=on
#   seed=123 fold=6  BA=0.562  AUROC=0.562  PR-AUC=0.738  sw=on
#   seed=123 fold=7  BA=0.688  AUROC=0.656  PR-AUC=0.744  sw=on
#   seed=123 fold=8  BA=0.562  AUROC=0.688  PR-AUC=0.797  sw=on
#   seed=123 fold=9  BA=0.500  AUROC=0.594  PR-AUC=0.815  sw=on
#   seed=256 fold=1  BA=0.562  AUROC=0.844  PR-AUC=0.938  sw=on
#   seed=256 fold=2  BA=0.688  AUROC=0.625  PR-AUC=0.798  sw=on
#   seed=256 fold=3  BA=0.688  AUROC=0.719  PR-AUC=0.843  sw=on
#   seed=256 fold=4  BA=0.438  AUROC=0.219  PR-AUC=0.554  sw=on
#   seed=256 fold=5  BA=0.438  AUROC=0.469  PR-AUC=0.655  sw=on
#   seed=256 fold=6  BA=0.812  AUROC=0.781  PR-AUC=0.864  sw=on
#   seed=256 fold=7  BA=0.500  AUROC=0.375  PR-AUC=0.606  sw=on
#   seed=256 fold=8  BA=0.688  AUROC=0.625  PR-AUC=0.720  sw=on
#   seed=256 fold=9  BA=0.438  AUROC=0.594  PR-AUC=0.768  sw=on
#
# --- mSVM-Linear ---
#   seed=42 fold=1  BA=0.562  AUROC=0.719  PR-AUC=0.855  sw=on
#   seed=42 fold=2  BA=0.562  AUROC=0.719  PR-AUC=0.878  sw=on
#   seed=42 fold=3  BA=0.625  AUROC=0.688  PR-AUC=0.802  sw=on
#   seed=42 fold=4  BA=0.312  AUROC=0.250  PR-AUC=0.629  sw=on
#   seed=42 fold=5  BA=0.438  AUROC=0.438  PR-AUC=0.699  sw=on
#   seed=42 fold=6  BA=0.500  AUROC=0.531  PR-AUC=0.664  sw=on
#   seed=42 fold=7  BA=0.625  AUROC=0.625  PR-AUC=0.805  sw=on
#   seed=42 fold=8  BA=0.312  AUROC=0.438  PR-AUC=0.713  sw=on
#   seed=42 fold=9  BA=0.500  AUROC=0.500  PR-AUC=0.721  sw=on
#   seed=123 fold=1  BA=0.562  AUROC=0.812  PR-AUC=0.920  sw=on
#   seed=123 fold=2  BA=0.625  AUROC=0.594  PR-AUC=0.766  sw=on
#   seed=123 fold=3  BA=0.625  AUROC=0.500  PR-AUC=0.655  sw=on
#   seed=123 fold=4  BA=0.625  AUROC=0.469  PR-AUC=0.634  sw=on
#   seed=123 fold=5  BA=0.625  AUROC=0.594  PR-AUC=0.747  sw=on
#   seed=123 fold=6  BA=0.812  AUROC=0.906  PR-AUC=0.959  sw=on
#   seed=123 fold=7  BA=0.438  AUROC=0.656  PR-AUC=0.744  sw=on
#   seed=123 fold=8  BA=0.438  AUROC=0.406  PR-AUC=0.721  sw=on
#   seed=123 fold=9  BA=0.500  AUROC=0.594  PR-AUC=0.815  sw=on
#   seed=256 fold=1  BA=0.875  AUROC=0.906  PR-AUC=0.953  sw=on
#   seed=256 fold=2  BA=0.688  AUROC=0.562  PR-AUC=0.705  sw=on
#   seed=256 fold=3  BA=0.562  AUROC=0.562  PR-AUC=0.753  sw=on
#   seed=256 fold=4  BA=0.375  AUROC=0.281  PR-AUC=0.575  sw=on
#   seed=256 fold=5  BA=0.500  AUROC=0.562  PR-AUC=0.684  sw=on
#   seed=256 fold=6  BA=0.438  AUROC=0.438  PR-AUC=0.686  sw=on
#   seed=256 fold=7  BA=0.625  AUROC=0.531  PR-AUC=0.684  sw=on
#   seed=256 fold=8  BA=0.375  AUROC=0.469  PR-AUC=0.760  sw=on
#   seed=256 fold=9  BA=0.750  AUROC=0.750  PR-AUC=0.823  sw=on
#
# --- mSVM-RFE ---
#   seed=42 fold=1  BA=0.562  AUROC=0.719  PR-AUC=0.861  sw=on
#   seed=42 fold=2  BA=0.562  AUROC=0.656  PR-AUC=0.861  sw=on
#   seed=42 fold=3  BA=0.688  AUROC=0.625  PR-AUC=0.726  sw=on
#   seed=42 fold=4  BA=0.375  AUROC=0.281  PR-AUC=0.650  sw=on
#   seed=42 fold=5  BA=0.562  AUROC=0.531  PR-AUC=0.736  sw=on
#   seed=42 fold=6  BA=0.688  AUROC=0.531  PR-AUC=0.664  sw=on
#   seed=42 fold=7  BA=0.625  AUROC=0.781  PR-AUC=0.907  sw=on
#   seed=42 fold=8  BA=0.312  AUROC=0.438  PR-AUC=0.713  sw=on
#   seed=42 fold=9  BA=0.625  AUROC=0.531  PR-AUC=0.717  sw=on
#   seed=123 fold=1  BA=0.562  AUROC=0.812  PR-AUC=0.920  sw=on
#   seed=123 fold=2  BA=0.625  AUROC=0.594  PR-AUC=0.766  sw=on
#   seed=123 fold=3  BA=0.312  AUROC=0.375  PR-AUC=0.599  sw=on
#   seed=123 fold=4  BA=0.625  AUROC=0.469  PR-AUC=0.634  sw=on
#   seed=123 fold=5  BA=0.625  AUROC=0.594  PR-AUC=0.747  sw=on
#   seed=123 fold=6  BA=0.750  AUROC=0.906  PR-AUC=0.953  sw=on
#   seed=123 fold=7  BA=0.688  AUROC=0.719  PR-AUC=0.760  sw=on
#   seed=123 fold=8  BA=0.438  AUROC=0.406  PR-AUC=0.721  sw=on
#   seed=123 fold=9  BA=0.500  AUROC=0.594  PR-AUC=0.815  sw=on
#   seed=256 fold=1  BA=0.812  AUROC=0.938  PR-AUC=0.970  sw=on
#   seed=256 fold=2  BA=0.500  AUROC=0.562  PR-AUC=0.701  sw=on
#   seed=256 fold=3  BA=0.562  AUROC=0.531  PR-AUC=0.779  sw=on
#   seed=256 fold=4  BA=0.375  AUROC=0.281  PR-AUC=0.575  sw=on
#   seed=256 fold=5  BA=0.750  AUROC=0.500  PR-AUC=0.643  sw=on
#   seed=256 fold=6  BA=0.562  AUROC=0.500  PR-AUC=0.687  sw=on
#   seed=256 fold=7  BA=0.625  AUROC=0.531  PR-AUC=0.684  sw=on
#   seed=256 fold=8  BA=0.562  AUROC=0.531  PR-AUC=0.698  sw=on
#   seed=256 fold=9  BA=0.625  AUROC=0.781  PR-AUC=0.895  sw=on
#
# --- kNN ---
#   seed=42 fold=1  BA=0.625  AUROC=0.547  PR-AUC=0.726  sw=off
#   seed=42 fold=2  BA=0.625  AUROC=0.641  PR-AUC=0.746  sw=off
#   seed=42 fold=3  BA=0.438  AUROC=0.453  PR-AUC=0.633  sw=off
#   seed=42 fold=4  BA=0.188  AUROC=0.156  PR-AUC=0.536  sw=off
#   seed=42 fold=5  BA=0.438  AUROC=0.562  PR-AUC=0.807  sw=off
#   seed=42 fold=6  BA=0.625  AUROC=0.781  PR-AUC=0.895  sw=off
#   seed=42 fold=7  BA=0.688  AUROC=0.781  PR-AUC=0.899  sw=off
#   seed=42 fold=8  BA=0.562  AUROC=0.469  PR-AUC=0.655  sw=off
#   seed=42 fold=9  BA=0.688  AUROC=0.594  PR-AUC=0.705  sw=off
#   seed=123 fold=1  BA=0.438  AUROC=0.453  PR-AUC=0.636  sw=off
#   seed=123 fold=2  BA=0.812  AUROC=0.750  PR-AUC=0.879  sw=off
#   seed=123 fold=3  BA=0.250  AUROC=0.297  PR-AUC=0.600  sw=off
#   seed=123 fold=4  BA=0.375  AUROC=0.344  PR-AUC=0.596  sw=off
#   seed=123 fold=5  BA=0.562  AUROC=0.766  PR-AUC=0.856  sw=off
#   seed=123 fold=6  BA=0.750  AUROC=0.938  PR-AUC=0.970  sw=off
#   seed=123 fold=7  BA=0.500  AUROC=0.500  PR-AUC=0.667  sw=off
#   seed=123 fold=8  BA=0.688  AUROC=0.594  PR-AUC=0.703  sw=off
#   seed=123 fold=9  BA=0.688  AUROC=0.578  PR-AUC=0.708  sw=off
#   seed=256 fold=1  BA=0.438  AUROC=0.469  PR-AUC=0.655  sw=off
#   seed=256 fold=2  BA=0.438  AUROC=0.406  PR-AUC=0.631  sw=off
#   seed=256 fold=3  BA=0.500  AUROC=0.578  PR-AUC=0.707  sw=off
#   seed=256 fold=4  BA=0.375  AUROC=0.125  PR-AUC=0.528  sw=off
#   seed=256 fold=5  BA=0.562  AUROC=0.406  PR-AUC=0.608  sw=off
#   seed=256 fold=6  BA=0.812  AUROC=0.938  PR-AUC=0.975  sw=off
#   seed=256 fold=7  BA=0.500  AUROC=0.547  PR-AUC=0.738  sw=off
#   seed=256 fold=8  BA=0.688  AUROC=0.766  PR-AUC=0.795  sw=off
#   seed=256 fold=9  BA=0.438  AUROC=0.625  PR-AUC=0.810  sw=off
#
# --- GaussianNB ---
#   seed=42 fold=1  BA=0.625  AUROC=0.625  PR-AUC=0.726  sw=on
#   seed=42 fold=2  BA=0.625  AUROC=0.656  PR-AUC=0.854  sw=on
#   seed=42 fold=3  BA=0.562  AUROC=0.594  PR-AUC=0.795  sw=on
#   seed=42 fold=4  BA=0.250  AUROC=0.219  PR-AUC=0.616  sw=on
#   seed=42 fold=5  BA=0.750  AUROC=0.812  PR-AUC=0.876  sw=on
#   seed=42 fold=6  BA=0.375  AUROC=0.438  PR-AUC=0.695  sw=on
#   seed=42 fold=7  BA=0.562  AUROC=0.469  PR-AUC=0.634  sw=on
#   seed=42 fold=8  BA=0.750  AUROC=0.688  PR-AUC=0.806  sw=on
#   seed=42 fold=9  BA=0.688  AUROC=0.625  PR-AUC=0.798  sw=on
#   seed=123 fold=1  BA=0.688  AUROC=0.844  PR-AUC=0.932  sw=on
#   seed=123 fold=2  BA=0.562  AUROC=0.625  PR-AUC=0.822  sw=on
#   seed=123 fold=3  BA=0.312  AUROC=0.344  PR-AUC=0.617  sw=on
#   seed=123 fold=4  BA=0.562  AUROC=0.562  PR-AUC=0.747  sw=on
#   seed=123 fold=5  BA=0.625  AUROC=0.656  PR-AUC=0.820  sw=on
#   seed=123 fold=6  BA=0.750  AUROC=0.844  PR-AUC=0.929  sw=on
#   seed=123 fold=7  BA=0.750  AUROC=0.688  PR-AUC=0.806  sw=on
#   seed=123 fold=8  BA=0.688  AUROC=0.625  PR-AUC=0.781  sw=on
#   seed=123 fold=9  BA=0.625  AUROC=0.719  PR-AUC=0.871  sw=on
#   seed=256 fold=1  BA=0.812  AUROC=0.781  PR-AUC=0.834  sw=on
#   seed=256 fold=2  BA=0.500  AUROC=0.594  PR-AUC=0.780  sw=on
#   seed=256 fold=3  BA=0.688  AUROC=0.812  PR-AUC=0.920  sw=on
#   seed=256 fold=4  BA=0.312  AUROC=0.406  PR-AUC=0.698  sw=on
#   seed=256 fold=5  BA=0.625  AUROC=0.688  PR-AUC=0.824  sw=on
#   seed=256 fold=6  BA=0.500  AUROC=0.594  PR-AUC=0.791  sw=on
#   seed=256 fold=7  BA=0.500  AUROC=0.344  PR-AUC=0.595  sw=on
#   seed=256 fold=8  BA=0.750  AUROC=0.656  PR-AUC=0.794  sw=on
#   seed=256 fold=9  BA=0.812  AUROC=0.750  PR-AUC=0.855  sw=on
#
# --- ElasticNet ---
#   seed=42 fold=1  BA=0.625  AUROC=0.625  PR-AUC=0.773  sw=on
#   seed=42 fold=2  BA=0.562  AUROC=0.531  PR-AUC=0.752  sw=on
#   seed=42 fold=3  BA=0.625  AUROC=0.625  PR-AUC=0.729  sw=on
#   seed=42 fold=4  BA=0.312  AUROC=0.438  PR-AUC=0.695  sw=on
#   seed=42 fold=5  BA=0.562  AUROC=0.531  PR-AUC=0.771  sw=on
#   seed=42 fold=6  BA=0.500  AUROC=0.500  PR-AUC=0.643  sw=on
#   seed=42 fold=7  BA=0.562  AUROC=0.594  PR-AUC=0.809  sw=on
#   seed=42 fold=8  BA=0.438  AUROC=0.438  PR-AUC=0.713  sw=on
#   seed=42 fold=9  BA=0.625  AUROC=0.562  PR-AUC=0.726  sw=on
#   seed=123 fold=1  BA=0.562  AUROC=0.844  PR-AUC=0.932  sw=on
#   seed=123 fold=2  BA=0.625  AUROC=0.656  PR-AUC=0.861  sw=on
#   seed=123 fold=3  BA=0.500  AUROC=0.406  PR-AUC=0.629  sw=on
#   seed=123 fold=4  BA=0.562  AUROC=0.406  PR-AUC=0.614  sw=on
#   seed=123 fold=5  BA=0.562  AUROC=0.562  PR-AUC=0.684  sw=on
#   seed=123 fold=6  BA=0.750  AUROC=0.812  PR-AUC=0.896  sw=on
#   seed=123 fold=7  BA=0.812  AUROC=0.719  PR-AUC=0.848  sw=on
#   seed=123 fold=8  BA=0.625  AUROC=0.438  PR-AUC=0.718  sw=on
#   seed=123 fold=9  BA=0.500  AUROC=0.531  PR-AUC=0.759  sw=on
#   seed=256 fold=1  BA=0.812  AUROC=0.875  PR-AUC=0.932  sw=on
#   seed=256 fold=2  BA=0.750  AUROC=0.625  PR-AUC=0.729  sw=on
#   seed=256 fold=3  BA=0.438  AUROC=0.562  PR-AUC=0.784  sw=on
#   seed=256 fold=4  BA=0.562  AUROC=0.375  PR-AUC=0.619  sw=on
#   seed=256 fold=5  BA=0.625  AUROC=0.531  PR-AUC=0.664  sw=on
#   seed=256 fold=6  BA=0.562  AUROC=0.500  PR-AUC=0.752  sw=on
#   seed=256 fold=7  BA=0.500  AUROC=0.531  PR-AUC=0.675  sw=on
#   seed=256 fold=8  BA=0.438  AUROC=0.469  PR-AUC=0.729  sw=on
#   seed=256 fold=9  BA=0.812  AUROC=0.750  PR-AUC=0.823  sw=on
#
# [imbalanced] Final metrics (mean across 27 folds):
#              balanced_accuracy_mean  macro_f1_mean  auroc_mean  pr_auc_mean
# classifier
# ElasticNet                    0.586          0.579       0.572        0.750
# GaussianNB                    0.602          0.595       0.617        0.786
# kNN                           0.544          0.535       0.558        0.728
# mSVM-Linear                   0.551          0.542       0.574        0.754
# mSVM-RBF                      0.572          0.570       0.591        0.757
# mSVM-RFE                      0.574          0.569       0.582        0.755
#
# [imbalanced] Outputs in: C:\Users\hafsa\Python PD Project\MI_BaggedLASSO Pipeline\PDHC new\PDHC-class-aware\Outputs\stage4_HP_PDHC_top10_smote_imbalanced
#
# ========================================================================
# VARIANT: SMOTE = BALANCED  (top 15)
# Stage-3 source: stage3_FS_PDHC_smote_balanced
# Output dir    : stage4_HP_PDHC_top15_smote_balanced
# ========================================================================
# Top-15 consensus genes loaded from balanced Stage 3
# Pre-SMOTE post-feature CSVs saved (train: (15, 108), test: (15, 47))
# Class balance (PD=1, HC=0): {np.str_('HC'): 36, np.str_('PD'): 72}
# Full-train SMOTE applied: 108 real + 36 synthetic = 144 samples
# Synthetic class breakdown: HC=36, PD=0
# RFE n_features_to_select grid: [3, 7, 14, 15]
#
# --- mSVM-RBF ---
#   seed=42 fold=1  BA=0.625  AUROC=0.500  PR-AUC=0.725  sw=on
#   seed=42 fold=2  BA=0.438  AUROC=0.531  PR-AUC=0.779  sw=on
#   seed=42 fold=3  BA=0.812  AUROC=0.656  PR-AUC=0.744  sw=on
#   seed=42 fold=4  BA=0.500  AUROC=0.344  PR-AUC=0.612  sw=on
#   seed=42 fold=5  BA=0.500  AUROC=0.562  PR-AUC=0.705  sw=on
#   seed=42 fold=6  BA=0.875  AUROC=0.844  PR-AUC=0.938  sw=on
#   seed=42 fold=7  BA=0.500  AUROC=0.688  PR-AUC=0.857  sw=on
#   seed=42 fold=8  BA=0.688  AUROC=0.594  PR-AUC=0.718  sw=on
#   seed=42 fold=9  BA=0.750  AUROC=0.531  PR-AUC=0.664  sw=on
#   seed=123 fold=1  BA=0.312  AUROC=0.312  PR-AUC=0.653  sw=on
#   seed=123 fold=2  BA=0.625  AUROC=0.562  PR-AUC=0.708  sw=on
#   seed=123 fold=3  BA=0.438  AUROC=0.375  PR-AUC=0.639  sw=on
# ...
#   seed=256 fold=8  BA=0.562  AUROC=0.609  PR-AUC=0.719  sw=off
#   seed=256 fold=9  BA=0.812  AUROC=0.734  PR-AUC=0.883  sw=off
#
# --- GaussianNB ---
#   seed=42 fold=1  BA=0.688  AUROC=0.625  PR-AUC=0.833  sw=on
#   seed=42 fold=2  BA=0.750  AUROC=0.906  PR-AUC=0.953  sw=on
#   seed=42 fold=3  BA=0.625  AUROC=0.719  PR-AUC=0.871  sw=on
#   seed=42 fold=4  BA=0.625  AUROC=0.719  PR-AUC=0.867  sw=on
#   seed=42 fold=5  BA=0.812  AUROC=0.875  PR-AUC=0.942  sw=on
#   seed=42 fold=6  BA=0.750  AUROC=0.688  PR-AUC=0.879  sw=on
#   seed=42 fold=7  BA=0.562  AUROC=0.531  PR-AUC=0.739  sw=on
#   seed=42 fold=8  BA=0.625  AUROC=0.844  PR-AUC=0.938  sw=on
#   seed=42 fold=9  BA=0.625  AUROC=0.812  PR-AUC=0.909  sw=on
#   seed=123 fold=1  BA=0.688  AUROC=0.812  PR-AUC=0.909  sw=on
#   seed=123 fold=2  BA=0.562  AUROC=0.750  PR-AUC=0.870  sw=on
#   seed=123 fold=3  BA=0.562  AUROC=0.625  PR-AUC=0.833  sw=on
#   seed=123 fold=4  BA=0.625  AUROC=0.719  PR-AUC=0.871  sw=on
#   seed=123 fold=5  BA=0.688  AUROC=0.781  PR-AUC=0.899  sw=on
#   seed=123 fold=6  BA=0.812  AUROC=0.875  PR-AUC=0.950  sw=on
#   seed=123 fold=7  BA=0.688  AUROC=0.812  PR-AUC=0.920  sw=on
#   seed=123 fold=8  BA=0.750  AUROC=0.750  PR-AUC=0.880  sw=on
#   seed=123 fold=9  BA=0.562  AUROC=0.781  PR-AUC=0.899  sw=on
#   seed=256 fold=1  BA=0.625  AUROC=0.812  PR-AUC=0.916  sw=on
#   seed=256 fold=2  BA=0.625  AUROC=0.688  PR-AUC=0.839  sw=on
#   seed=256 fold=3  BA=0.750  AUROC=0.812  PR-AUC=0.931  sw=on
#   seed=256 fold=4  BA=0.562  AUROC=0.719  PR-AUC=0.878  sw=on
#   seed=256 fold=5  BA=0.750  AUROC=0.781  PR-AUC=0.899  sw=on
#   seed=256 fold=6  BA=0.562  AUROC=0.719  PR-AUC=0.839  sw=on
#   seed=256 fold=7  BA=0.562  AUROC=0.438  PR-AUC=0.706  sw=on
#   seed=256 fold=8  BA=0.688  AUROC=0.656  PR-AUC=0.820  sw=on
#   seed=256 fold=9  BA=0.938  AUROC=0.938  PR-AUC=0.975  sw=on
#
# --- ElasticNet ---
#   seed=42 fold=1  BA=0.438  AUROC=0.625  PR-AUC=0.826  sw=on
#   seed=42 fold=2  BA=0.750  AUROC=0.750  PR-AUC=0.890  sw=on
#   seed=42 fold=3  BA=0.625  AUROC=0.781  PR-AUC=0.895  sw=on
#   seed=42 fold=4  BA=0.688  AUROC=0.750  PR-AUC=0.823  sw=on
#   seed=42 fold=5  BA=0.812  AUROC=0.844  PR-AUC=0.929  sw=on
#   seed=42 fold=6  BA=0.688  AUROC=0.750  PR-AUC=0.913  sw=on
#   seed=42 fold=7  BA=0.188  AUROC=0.250  PR-AUC=0.625  sw=on
#   seed=42 fold=8  BA=0.875  AUROC=0.938  PR-AUC=0.975  sw=on
#   seed=42 fold=9  BA=0.688  AUROC=0.812  PR-AUC=0.916  sw=on
#   seed=123 fold=1  BA=0.625  AUROC=0.688  PR-AUC=0.836  sw=on
#   seed=123 fold=2  BA=0.688  AUROC=0.594  PR-AUC=0.842  sw=on
#   seed=123 fold=3  BA=0.625  AUROC=0.688  PR-AUC=0.861  sw=on
#   seed=123 fold=4  BA=0.688  AUROC=0.844  PR-AUC=0.929  sw=on
#   seed=123 fold=5  BA=0.562  AUROC=0.812  PR-AUC=0.876  sw=on
#   seed=123 fold=6  BA=0.562  AUROC=0.656  PR-AUC=0.836  sw=on
#   seed=123 fold=7  BA=0.812  AUROC=0.812  PR-AUC=0.928  sw=on
#   seed=123 fold=8  BA=0.688  AUROC=0.719  PR-AUC=0.876  sw=on
#   seed=123 fold=9  BA=0.688  AUROC=0.906  PR-AUC=0.953  sw=on
#   seed=256 fold=1  BA=0.688  AUROC=0.844  PR-AUC=0.932  sw=on
#   seed=256 fold=2  BA=0.562  AUROC=0.781  PR-AUC=0.864  sw=on
#   seed=256 fold=3  BA=0.875  AUROC=0.938  PR-AUC=0.970  sw=on
#   seed=256 fold=4  BA=0.438  AUROC=0.406  PR-AUC=0.656  sw=on
#   seed=256 fold=5  BA=0.688  AUROC=0.812  PR-AUC=0.920  sw=on
#   seed=256 fold=6  BA=0.750  AUROC=0.750  PR-AUC=0.890  sw=on
#   seed=256 fold=7  BA=0.625  AUROC=0.750  PR-AUC=0.899  sw=on
#   seed=256 fold=8  BA=0.688  AUROC=0.750  PR-AUC=0.897  sw=on
#   seed=256 fold=9  BA=0.812  AUROC=0.906  PR-AUC=0.966  sw=on
#
# [balanced] Final metrics (mean across 27 folds):
#              balanced_accuracy_mean  macro_f1_mean  auroc_mean  pr_auc_mean
# classifier
# ElasticNet                    0.660          0.603       0.747        0.879
# GaussianNB                    0.669          0.647       0.748        0.880
# kNN                           0.597          0.515       0.646        0.801
# mSVM-Linear                   0.653          0.619       0.727        0.856
# mSVM-RBF                      0.646          0.612       0.751        0.881
# mSVM-RFE                      0.667          0.621       0.750        0.876
#
# [balanced] Outputs in: C:\Users\hafsa\Python PD Project\MI_BaggedLASSO Pipeline\PDHC new\PDHC-class-aware\Outputs\stage4_HP_PDHC_top41_smote_balanced
#
# ========================================================================
# VARIANT: SMOTE = IMBALANCED  (top 41)
# Stage-3 source: stage3_FS_PDHC_smote_imbalanced
# Output dir    : stage4_HP_PDHC_top41_smote_imbalanced
# ========================================================================
#   WARN: consensus has only 33 genes (< requested 41); proceeding with available set.
# Top-33 consensus genes loaded from imbalanced Stage 3
# Pre-SMOTE post-feature CSVs saved (train: (33, 108), test: (33, 47))
# Class balance (PD=1, HC=0): {np.str_('HC'): 36, np.str_('PD'): 72}
# Full-train SMOTE applied: 108 real + 108 synthetic = 216 samples
# Synthetic class breakdown: HC=36, PD=72
# RFE n_features_to_select grid: [8, 16, 32, 33]
#
# --- mSVM-RBF ---
#   seed=42 fold=1  BA=0.562  AUROC=0.500  PR-AUC=0.643  sw=on
#   seed=42 fold=2  BA=0.562  AUROC=0.812  PR-AUC=0.916  sw=on
#   seed=42 fold=3  BA=0.875  AUROC=0.969  PR-AUC=0.986  sw=on
#   seed=42 fold=4  BA=0.562  AUROC=0.562  PR-AUC=0.778  sw=on
#   seed=42 fold=5  BA=0.812  AUROC=0.906  PR-AUC=0.953  sw=on
#   seed=42 fold=6  BA=0.562  AUROC=0.562  PR-AUC=0.778  sw=on
#   seed=42 fold=7  BA=0.562  AUROC=0.594  PR-AUC=0.768  sw=on
#   seed=42 fold=8  BA=0.875  AUROC=0.938  PR-AUC=0.970  sw=on
#   seed=42 fold=9  BA=0.812  AUROC=0.812  PR-AUC=0.925  sw=on
#   seed=123 fold=1  BA=0.812  AUROC=0.875  PR-AUC=0.942  sw=on
#   seed=123 fold=2  BA=0.500  AUROC=0.594  PR-AUC=0.818  sw=on
#   seed=123 fold=3  BA=0.688  AUROC=0.844  PR-AUC=0.938  sw=on
#   seed=123 fold=4  BA=0.750  AUROC=0.562  PR-AUC=0.726  sw=on
#   seed=123 fold=5  BA=0.562  AUROC=0.719  PR-AUC=0.887  sw=on
#   seed=123 fold=6  BA=0.750  AUROC=0.906  PR-AUC=0.953  sw=on
#   seed=123 fold=7  BA=0.688  AUROC=0.688  PR-AUC=0.751  sw=on
#   seed=123 fold=8  BA=0.812  AUROC=0.781  PR-AUC=0.911  sw=on
#   seed=123 fold=9  BA=0.625  AUROC=0.719  PR-AUC=0.871  sw=on
#   seed=256 fold=1  BA=0.875  AUROC=1.000  PR-AUC=1.000  sw=on
#   seed=256 fold=2  BA=0.750  AUROC=0.562  PR-AUC=0.684  sw=on
#   seed=256 fold=3  BA=0.938  AUROC=1.000  PR-AUC=1.000  sw=on
#   seed=256 fold=4  BA=0.312  AUROC=0.344  PR-AUC=0.620  sw=on
#   seed=256 fold=5  BA=0.438  AUROC=0.781  PR-AUC=0.913  sw=on
#   seed=256 fold=6  BA=0.688  AUROC=0.750  PR-AUC=0.823  sw=on
#   seed=256 fold=7  BA=0.750  AUROC=0.750  PR-AUC=0.913  sw=on
#   seed=256 fold=8  BA=0.750  AUROC=0.688  PR-AUC=0.751  sw=on
#   seed=256 fold=9  BA=0.875  AUROC=0.969  PR-AUC=0.986  sw=on
#
# --- mSVM-Linear ---
#   seed=42 fold=1  BA=0.562  AUROC=0.750  PR-AUC=0.880  sw=on
#   seed=42 fold=2  BA=0.812  AUROC=0.781  PR-AUC=0.907  sw=on
#   seed=42 fold=3  BA=0.688  AUROC=0.719  PR-AUC=0.861  sw=on
#   seed=42 fold=4  BA=0.625  AUROC=0.812  PR-AUC=0.928  sw=on
#   seed=42 fold=5  BA=0.438  AUROC=0.406  PR-AUC=0.724  sw=on
#   seed=42 fold=6  BA=0.688  AUROC=0.656  PR-AUC=0.794  sw=on
#   seed=42 fold=7  BA=0.625  AUROC=0.719  PR-AUC=0.855  sw=on
#   seed=42 fold=8  BA=0.438  AUROC=0.625  PR-AUC=0.840  sw=on
#   seed=42 fold=9  BA=0.625  AUROC=0.688  PR-AUC=0.882  sw=on
#   seed=123 fold=1  BA=0.812  AUROC=0.938  PR-AUC=0.970  sw=on
#   seed=123 fold=2  BA=0.312  AUROC=0.469  PR-AUC=0.760  sw=on
#   seed=123 fold=3  BA=0.562  AUROC=0.719  PR-AUC=0.861  sw=on
#   seed=123 fold=4  BA=0.562  AUROC=0.625  PR-AUC=0.773  sw=on
#   seed=123 fold=5  BA=0.750  AUROC=0.781  PR-AUC=0.913  sw=on
#   seed=123 fold=6  BA=0.750  AUROC=0.781  PR-AUC=0.899  sw=on
#   seed=123 fold=7  BA=0.750  AUROC=0.844  PR-AUC=0.929  sw=on
#   seed=123 fold=8  BA=0.625  AUROC=0.625  PR-AUC=0.826  sw=on
#   seed=123 fold=9  BA=0.625  AUROC=0.469  PR-AUC=0.707  sw=on
#   seed=256 fold=1  BA=0.750  AUROC=1.000  PR-AUC=1.000  sw=on
#   seed=256 fold=2  BA=0.688  AUROC=0.688  PR-AUC=0.839  sw=on
#   seed=256 fold=3  BA=0.875  AUROC=1.000  PR-AUC=1.000  sw=on
#   seed=256 fold=4  BA=0.375  AUROC=0.406  PR-AUC=0.694  sw=on
#   seed=256 fold=5  BA=0.750  AUROC=0.812  PR-AUC=0.876  sw=on
#   seed=256 fold=6  BA=0.812  AUROC=0.875  PR-AUC=0.950  sw=on
#   seed=256 fold=7  BA=0.625  AUROC=0.750  PR-AUC=0.886  sw=on
#   seed=256 fold=8  BA=0.375  AUROC=0.594  PR-AUC=0.805  sw=on
#   seed=256 fold=9  BA=0.562  AUROC=0.719  PR-AUC=0.855  sw=on
#
# --- mSVM-RFE ---
#   seed=42 fold=1  BA=0.562  AUROC=0.750  PR-AUC=0.880  sw=on
#   seed=42 fold=2  BA=0.688  AUROC=0.844  PR-AUC=0.929  sw=on
#   seed=42 fold=3  BA=0.688  AUROC=0.719  PR-AUC=0.861  sw=on
#   seed=42 fold=4  BA=0.688  AUROC=0.844  PR-AUC=0.929  sw=on
#   seed=42 fold=5  BA=0.688  AUROC=0.781  PR-AUC=0.895  sw=on
#   seed=42 fold=6  BA=0.688  AUROC=0.750  PR-AUC=0.886  sw=on
#   seed=42 fold=7  BA=0.562  AUROC=0.781  PR-AUC=0.895  sw=on
#   seed=42 fold=8  BA=0.750  AUROC=0.812  PR-AUC=0.920  sw=on
#   seed=42 fold=9  BA=0.625  AUROC=0.688  PR-AUC=0.882  sw=on
#   seed=123 fold=1  BA=0.812  AUROC=0.938  PR-AUC=0.970  sw=on
#   seed=123 fold=2  BA=0.312  AUROC=0.469  PR-AUC=0.760  sw=on
#   seed=123 fold=3  BA=0.500  AUROC=0.406  PR-AUC=0.694  sw=on
#   seed=123 fold=4  BA=0.625  AUROC=0.719  PR-AUC=0.887  sw=on
#   seed=123 fold=5  BA=0.625  AUROC=0.719  PR-AUC=0.871  sw=on
#   seed=123 fold=6  BA=0.688  AUROC=0.906  PR-AUC=0.953  sw=on
#   seed=123 fold=7  BA=0.750  AUROC=0.844  PR-AUC=0.929  sw=on
#   seed=123 fold=8  BA=0.625  AUROC=0.594  PR-AUC=0.795  sw=on
#   seed=123 fold=9  BA=0.562  AUROC=0.531  PR-AUC=0.786  sw=on
#   seed=256 fold=1  BA=0.750  AUROC=0.812  PR-AUC=0.876  sw=on
#   seed=256 fold=2  BA=0.688  AUROC=0.906  PR-AUC=0.953  sw=on
#   seed=256 fold=3  BA=0.875  AUROC=0.906  PR-AUC=0.959  sw=on
#   seed=256 fold=4  BA=0.562  AUROC=0.625  PR-AUC=0.829  sw=on
#   seed=256 fold=5  BA=0.750  AUROC=0.812  PR-AUC=0.876  sw=on
#   seed=256 fold=6  BA=0.750  AUROC=0.719  PR-AUC=0.887  sw=on
#   seed=256 fold=7  BA=0.562  AUROC=0.719  PR-AUC=0.887  sw=on
#   seed=256 fold=8  BA=0.688  AUROC=0.625  PR-AUC=0.850  sw=on
#   seed=256 fold=9  BA=0.562  AUROC=0.719  PR-AUC=0.855  sw=on
#
# --- kNN ---
#   seed=42 fold=1  BA=0.562  AUROC=0.594  PR-AUC=0.697  sw=off
#   seed=42 fold=2  BA=0.750  AUROC=0.844  PR-AUC=0.896  sw=off
#   seed=42 fold=3  BA=0.625  AUROC=0.672  PR-AUC=0.783  sw=off
#   seed=42 fold=4  BA=0.500  AUROC=0.516  PR-AUC=0.671  sw=off
#   seed=42 fold=5  BA=0.875  AUROC=0.984  PR-AUC=0.986  sw=off
#   seed=42 fold=6  BA=0.500  AUROC=0.656  PR-AUC=0.844  sw=off
#   seed=42 fold=7  BA=0.438  AUROC=0.453  PR-AUC=0.654  sw=off
#   seed=42 fold=8  BA=0.562  AUROC=0.516  PR-AUC=0.655  sw=off
#   seed=42 fold=9  BA=0.625  AUROC=0.688  PR-AUC=0.753  sw=off
#   seed=123 fold=1  BA=0.625  AUROC=0.812  PR-AUC=0.899  sw=off
#   seed=123 fold=2  BA=0.438  AUROC=0.672  PR-AUC=0.825  sw=off
#   seed=123 fold=3  BA=0.625  AUROC=0.875  PR-AUC=0.950  sw=off
#   seed=123 fold=4  BA=0.625  AUROC=0.625  PR-AUC=0.744  sw=off
#   seed=123 fold=5  BA=0.688  AUROC=0.719  PR-AUC=0.867  sw=off
#   seed=123 fold=6  BA=0.688  AUROC=0.609  PR-AUC=0.724  sw=off
#   seed=123 fold=7  BA=0.625  AUROC=0.594  PR-AUC=0.698  sw=off
#   seed=123 fold=8  BA=0.625  AUROC=0.688  PR-AUC=0.856  sw=off
#   seed=123 fold=9  BA=0.562  AUROC=0.672  PR-AUC=0.761  sw=off
#   seed=256 fold=1  BA=0.750  AUROC=0.719  PR-AUC=0.788  sw=off
#   seed=256 fold=2  BA=0.438  AUROC=0.531  PR-AUC=0.754  sw=off
#   seed=256 fold=3  BA=0.750  AUROC=0.766  PR-AUC=0.882  sw=off
#   seed=256 fold=4  BA=0.625  AUROC=0.500  PR-AUC=0.688  sw=off
#   seed=256 fold=5  BA=0.500  AUROC=0.406  PR-AUC=0.619  sw=off
#   seed=256 fold=6  BA=0.625  AUROC=0.688  PR-AUC=0.768  sw=off
#   seed=256 fold=7  BA=0.500  AUROC=0.641  PR-AUC=0.755  sw=off
#   seed=256 fold=8  BA=0.688  AUROC=0.641  PR-AUC=0.732  sw=off
#   seed=256 fold=9  BA=0.812  AUROC=0.797  PR-AUC=0.823  sw=off
#
# --- GaussianNB ---
#   seed=42 fold=1  BA=0.625  AUROC=0.594  PR-AUC=0.711  sw=on
#   seed=42 fold=2  BA=0.875  AUROC=0.938  PR-AUC=0.975  sw=on
#   seed=42 fold=3  BA=0.500  AUROC=0.719  PR-AUC=0.871  sw=on
#   seed=42 fold=4  BA=0.375  AUROC=0.312  PR-AUC=0.658  sw=on
#   seed=42 fold=5  BA=0.938  AUROC=1.000  PR-AUC=1.000  sw=on
#   seed=42 fold=6  BA=0.625  AUROC=0.656  PR-AUC=0.792  sw=on
#   seed=42 fold=7  BA=0.688  AUROC=0.562  PR-AUC=0.714  sw=on
#   seed=42 fold=8  BA=0.875  AUROC=0.969  PR-AUC=0.986  sw=on
#   seed=42 fold=9  BA=0.625  AUROC=0.750  PR-AUC=0.897  sw=on
#   seed=123 fold=1  BA=0.625  AUROC=0.844  PR-AUC=0.929  sw=on
#   seed=123 fold=2  BA=0.688  AUROC=0.781  PR-AUC=0.864  sw=on
#   seed=123 fold=3  BA=0.500  AUROC=0.625  PR-AUC=0.820  sw=on
#   seed=123 fold=4  BA=0.438  AUROC=0.656  PR-AUC=0.851  sw=on
#   seed=123 fold=5  BA=0.812  AUROC=0.844  PR-AUC=0.907  sw=on
#   seed=123 fold=6  BA=0.688  AUROC=0.812  PR-AUC=0.912  sw=on
#   seed=123 fold=7  BA=0.812  AUROC=0.875  PR-AUC=0.942  sw=on
#   seed=123 fold=8  BA=0.562  AUROC=0.688  PR-AUC=0.846  sw=on
#   seed=123 fold=9  BA=0.625  AUROC=0.656  PR-AUC=0.792  sw=on
#   seed=256 fold=1  BA=0.688  AUROC=0.719  PR-AUC=0.811  sw=on
#   seed=256 fold=2  BA=0.688  AUROC=0.875  PR-AUC=0.942  sw=on
#   seed=256 fold=3  BA=0.875  AUROC=0.812  PR-AUC=0.928  sw=on
#   seed=256 fold=4  BA=0.438  AUROC=0.469  PR-AUC=0.710  sw=on
#   seed=256 fold=5  BA=0.688  AUROC=0.844  PR-AUC=0.929  sw=on
#   seed=256 fold=6  BA=0.688  AUROC=0.844  PR-AUC=0.929  sw=on
#   seed=256 fold=7  BA=0.562  AUROC=0.750  PR-AUC=0.886  sw=on
#   seed=256 fold=8  BA=0.562  AUROC=0.594  PR-AUC=0.722  sw=on
#   seed=256 fold=9  BA=0.812  AUROC=0.875  PR-AUC=0.942  sw=on
#
# --- ElasticNet ---
#   seed=42 fold=1  BA=0.562  AUROC=0.719  PR-AUC=0.855  sw=on
#   seed=42 fold=2  BA=0.750  AUROC=0.938  PR-AUC=0.970  sw=on
#   seed=42 fold=3  BA=0.875  AUROC=0.938  PR-AUC=0.970  sw=on
#   seed=42 fold=4  BA=0.750  AUROC=0.656  PR-AUC=0.782  sw=on
#   seed=42 fold=5  BA=0.875  AUROC=0.938  PR-AUC=0.970  sw=on
#   seed=42 fold=6  BA=0.688  AUROC=0.688  PR-AUC=0.797  sw=on
#   seed=42 fold=7  BA=0.625  AUROC=0.844  PR-AUC=0.907  sw=on
#   seed=42 fold=8  BA=0.438  AUROC=0.656  PR-AUC=0.851  sw=on
#   seed=42 fold=9  BA=0.688  AUROC=0.719  PR-AUC=0.895  sw=on
#   seed=123 fold=1  BA=0.625  AUROC=0.812  PR-AUC=0.928  sw=on
#   seed=123 fold=2  BA=0.438  AUROC=0.500  PR-AUC=0.791  sw=on
#   seed=123 fold=3  BA=0.812  AUROC=0.875  PR-AUC=0.950  sw=on
#   seed=123 fold=4  BA=0.625  AUROC=0.750  PR-AUC=0.874  sw=on
#   seed=123 fold=5  BA=0.688  AUROC=0.750  PR-AUC=0.899  sw=on
#   seed=123 fold=6  BA=0.750  AUROC=0.781  PR-AUC=0.913  sw=on
#   seed=123 fold=7  BA=0.750  AUROC=0.906  PR-AUC=0.959  sw=on
#   seed=123 fold=8  BA=0.688  AUROC=0.719  PR-AUC=0.865  sw=on
#   seed=123 fold=9  BA=0.625  AUROC=0.781  PR-AUC=0.884  sw=on
#   seed=256 fold=1  BA=0.750  AUROC=0.750  PR-AUC=0.852  sw=on
#   seed=256 fold=2  BA=0.625  AUROC=0.781  PR-AUC=0.884  sw=on
#   seed=256 fold=3  BA=0.938  AUROC=0.938  PR-AUC=0.975  sw=on
#   seed=256 fold=4  BA=0.625  AUROC=0.656  PR-AUC=0.844  sw=on
#   seed=256 fold=5  BA=0.750  AUROC=0.844  PR-AUC=0.921  sw=on
#   seed=256 fold=6  BA=0.750  AUROC=0.812  PR-AUC=0.916  sw=on
#   seed=256 fold=7  BA=0.688  AUROC=0.750  PR-AUC=0.897  sw=on
#   seed=256 fold=8  BA=0.625  AUROC=0.531  PR-AUC=0.773  sw=on
#   seed=256 fold=9  BA=0.500  AUROC=0.750  PR-AUC=0.880  sw=on
#
# [imbalanced] Final metrics (mean across 27 folds):
#              balanced_accuracy_mean  macro_f1_mean  auroc_mean  pr_auc_mean
# classifier
# ElasticNet                    0.685          0.677       0.770        0.889
# GaussianNB                    0.662          0.646       0.743        0.862
# kNN                           0.616          0.608       0.662        0.780
# mSVM-Linear                   0.632          0.614       0.713        0.860
# mSVM-RBF                      0.694          0.691       0.748        0.859
# mSVM-RFE                      0.653          0.638       0.738        0.878
#
# [imbalanced] Outputs in: C:\Users\hafsa\Python PD Project\MI_BaggedLASSO Pipeline\PDHC new\PDHC-class-aware\Outputs\stage4_HP_PDHC_top41_smote_imbalanced
