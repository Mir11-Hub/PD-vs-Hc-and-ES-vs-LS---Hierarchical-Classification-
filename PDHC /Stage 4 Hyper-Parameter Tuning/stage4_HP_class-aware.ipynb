# %%
"""
Stage 4 (PD vs HC, class-aware) - Multi-classifier nested CV at five panel sizes
================================================================================

For each panel size in {5, 10, 15, 25, 41} genes (top-K by fold_inclusion
in consensus_panel.csv from the class-aware Stage-3 no-SMOTE run):

  Phase 0  Subset train/test to top-K consensus genes (saved as
           train_postfeature.csv / test_postfeature.csv inside the
           panel-specific output folder).

  Phase 1  Nested CV on the train half:
              outer = 9 stratified folds x 3 seeds (42, 123, 256) = 27 folds
              inner = 4 stratified folds, GridSearchCV with RobustScaler
                      INSIDE the pipeline (refit per inner fold).
           Inner-CV scoring metric: balanced_accuracy.
           Sample weighting: composite (sex x cell_type) stratum balance
           multiplied by class balance (HC vs PD inverse frequency),
           applied to RBF, Linear, GaussianNB, ElasticNet.

Class encoding: NEG=HC=0 (minority), POS=PD=1 (majority).

Inputs:
    train.csv      Outputs/stage2_split_class_aware_PDHC/train.csv
    test.csv       Outputs/stage2_split_class_aware_PDHC/test.csv
    metadata       Meta_data_PDHC.csv   (filtered to train / test sample IDs)
    consensus      Outputs/stage3_feature_selection_PDHC/consensus_panel.csv

Outputs per panel size (in PDHC new/PDHC-class-aware/Outputs/stage4_classifiers_PDHC_topK/)
"""

from __future__ import annotations

import json
import warnings
from collections import Counter
from pathlib import Path
from typing import Dict, List, Tuple

import numpy as np
import pandas as pd
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt

from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    average_precision_score, balanced_accuracy_score, brier_score_loss,
    cohen_kappa_score, confusion_matrix, f1_score, matthews_corrcoef,
    precision_recall_curve, roc_auc_score, roc_curve,
)
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.svm import SVC

warnings.filterwarnings("ignore")

# ----------------------------- Configuration --------------------------------
PIPELINE_DIR    = Path(r"C:\Users\hafsa\Python PD Project\MI_BaggedLASSO Pipeline")
PDHC_DIR        = PIPELINE_DIR / "PDHC new"
CLASS_AWARE_DIR = PDHC_DIR / "PDHC-class-aware"
SPLIT_DIR       = CLASS_AWARE_DIR / "Outputs" / "stage2_split_class_aware_PDHC"
STAGE3_DIR      = CLASS_AWARE_DIR / "Outputs" / "stage3_feature_selection_PDHC"
STAGE4_BASE     = CLASS_AWARE_DIR / "Outputs" / "stage4_HP_nosmote"

CONSENSUS_PATH = STAGE3_DIR / "consensus_panel.csv"
TRAIN_PATH     = SPLIT_DIR / "train.csv"
TEST_PATH      = SPLIT_DIR / "test.csv"
META_PATH      = PDHC_DIR / "Meta_data_PDHC.csv"

CONDITION_COL = "condition"
PANEL_SIZES   = [5, 10, 15, 25, 41]
SEEDS         = [42, 123, 256]
N_OUTER       = 9
N_INNER       = 4
N_JOBS        = -1

# Class encoding: HC = 0 (negative, minority), PD = 1 (positive, majority)
NEG_LABEL = "HC"
POS_LABEL = "PD"


# ============================ Data helpers =================================
def load_meta(sample_ids) -> pd.DataFrame:
    meta = pd.read_csv(META_PATH)
    if "sample_id" in meta.columns:
        meta = meta.set_index("sample_id")
    return meta.loc[sample_ids]


def to_binary_labels(y_str: np.ndarray) -> np.ndarray:
    return np.where(np.asarray(y_str) == NEG_LABEL, NEG_LABEL, POS_LABEL)


def encode_binary(y_str_binary: np.ndarray) -> np.ndarray:
    return np.where(y_str_binary == POS_LABEL, 1, 0).astype(int)


def load_features_x_samples(path: Path, top_genes: List[str]) -> pd.DataFrame:
    df = pd.read_csv(path, index_col=0)
    if len(set(top_genes) & set(df.index.astype(str))) == 0:
        df = df.T
    present = [g for g in top_genes if g in df.index]
    missing = [g for g in top_genes if g not in df.index]
    if missing:
        print(f"  WARN: {len(missing)} genes missing in {path.name}")
    return df.loc[present]


def composite_sample_weights(meta: pd.DataFrame,
                             y_int: np.ndarray) -> np.ndarray:
    strata = meta["sex"].astype(str) + "_" + meta["cell_type"].astype(str)
    s_counts = strata.value_counts()
    n, k = len(strata), len(s_counts)
    w_conf = strata.map(lambda s: (n / k) / s_counts[s]).values.astype(float)

    classes, c_counts = np.unique(y_int, return_counts=True)
    n_cls = len(classes)
    class_w = {c: n / (n_cls * cnt) for c, cnt in zip(classes, c_counts)}
    w_class = np.array([class_w[y] for y in y_int], dtype=float)

    w = w_conf * w_class
    return w / w.mean()


# ============================ Classifiers ==================================
def get_classifiers(seed: int) -> Dict[str, Dict]:
    return {
        "mSVM-RBF": {
            "pipe": Pipeline([("scale", RobustScaler()),
                              ("clf", SVC(kernel="rbf", probability=True,
                                          random_state=seed))]),
            "grid": {"clf__C":     [0.1, 1, 10],
                     "clf__gamma": ["scale", 0.01, 0.1, 1.0]},
            "supports_sw": True,
        },
        "mSVM-Linear": {
            "pipe": Pipeline([("scale", RobustScaler()),
                              ("clf", SVC(kernel="linear", probability=True,
                                          random_state=seed))]),
            "grid": {"clf__C": [0.01, 0.1, 1, 10]},
            "supports_sw": True,
        },
        "mSVM-RFE": {
            "pipe": Pipeline([("scale", RobustScaler()),
                              ("rfe", RFE(SVC(kernel="linear", probability=True,
                                              random_state=seed)))]),
            "grid": {"rfe__n_features_to_select": None,
                     "rfe__estimator__C":         [0.1, 1, 10]},
            "supports_sw": False,
        },
        "kNN": {
            "pipe": Pipeline([("scale", RobustScaler()),
                              ("clf", KNeighborsClassifier())]),
            "grid": {"clf__n_neighbors": [3, 5, 7, 11, 15],
                     "clf__weights":     ["uniform", "distance"]},
            "supports_sw": False,
        },
        "GaussianNB": {
            "pipe": Pipeline([("scale", RobustScaler()),
                              ("clf", GaussianNB())]),
            "grid": {"clf__var_smoothing": np.logspace(-11, -7, 5)},
            "supports_sw": True,
        },
        "ElasticNet": {
            "pipe": Pipeline([("scale", RobustScaler()),
                              ("clf", LogisticRegression(
                                  penalty="elasticnet", solver="saga",
                                  max_iter=5000, tol=1e-3,
                                  random_state=seed))]),
            "grid": {"clf__C":        [0.01, 0.1, 1, 10],
                     "clf__l1_ratio": [0.1, 0.3, 0.5, 0.7, 0.9]},
            "supports_sw": True,
        },
    }


def rfe_grid_for_panel(k_top: int) -> List[int]:
    base = sorted({max(2, k_top // 4), max(3, k_top // 2), k_top - 1, k_top})
    return [b for b in base if 2 <= b <= k_top]


# ============================ Metrics ======================================
def evaluate_binary(y_true: np.ndarray, y_pred: np.ndarray,
                    y_proba_pos: np.ndarray) -> Dict:
    cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
    tn, fp, fn, tp = cm.ravel()
    sens = tp / (tp + fn) if (tp + fn) > 0 else np.nan
    spec = tn / (tn + fp) if (tn + fp) > 0 else np.nan
    return {
        "balanced_accuracy": balanced_accuracy_score(y_true, y_pred),
        "macro_f1":          f1_score(y_true, y_pred, average="macro"),
        "auroc":             roc_auc_score(y_true, y_proba_pos),
        "pr_auc":            average_precision_score(y_true, y_proba_pos),
        "sensitivity":       sens,
        "specificity":       spec,
        "mcc":               matthews_corrcoef(y_true, y_pred),
        "brier":             brier_score_loss(y_true, y_proba_pos),
        "cohen_kappa":       cohen_kappa_score(y_true, y_pred),
    }


def selected_genes_from_estimator(name: str, gs_result, gene_names: List[str]):
    best = gs_result.best_estimator_
    if name == "ElasticNet":
        coef = best.named_steps["clf"].coef_
        mask = (np.abs(coef) > 1e-10).any(axis=0)
        return [g for g, m in zip(gene_names, mask) if m]
    if name == "mSVM-RFE":
        rfe = best.named_steps["rfe"]
        return [g for g, m in zip(gene_names, rfe.support_) if m]
    return []


# ============================ Aggregation helpers ===========================
def aggregate_metrics(df: pd.DataFrame) -> pd.DataFrame:
    metric_cols = ["balanced_accuracy", "macro_f1", "auroc", "pr_auc",
                   "sensitivity", "specificity", "mcc", "brier", "cohen_kappa"]
    rows = []
    for clf, sub in df.groupby("classifier"):
        row = {"classifier": clf, "n_folds": len(sub)}
        for m in metric_cols:
            row[f"{m}_mean"] = sub[m].mean()
            row[f"{m}_std"]  = sub[m].std()
        rows.append(row)
    return pd.DataFrame(rows)


def consensus_hyperparams(df: pd.DataFrame) -> pd.DataFrame:
    rows = []
    for clf, sub in df.groupby("classifier"):
        params_list = [json.loads(p) for p in sub["best_params"]]
        keys = sorted({k for p in params_list for k in p.keys()})
        row = {"classifier": clf}
        for k in keys:
            vals = [p.get(k) for p in params_list]
            counter = Counter([str(v) for v in vals])
            mode_str, mode_count = counter.most_common(1)[0]
            row[k] = mode_str
            row[f"{k}__support_pct"] = round(100 * mode_count / len(vals), 1)
        rows.append(row)
    return pd.DataFrame(rows)


def fold_inclusion_table(sel_records, top_genes, n_folds_total):
    df = pd.DataFrame(sel_records)
    out = {}
    if df.empty:
        return out
    for clf in df["classifier"].unique():
        sub = df[df["classifier"] == clf]
        n_seen = sub.groupby("gene").size()
        full = pd.Series(0, index=top_genes, dtype=int)
        full.update(n_seen)
        out[clf] = pd.DataFrame({
            "gene": full.index,
            "n_folds_included": full.values,
            "fold_inclusion_pct":
                np.round(100 * full.values / n_folds_total, 1),
        }).sort_values("n_folds_included", ascending=False)
    return out


# ============================ Plot helpers =================================
def plot_roc_per_classifier(fold_df: pd.DataFrame, out_path: Path):
    fig, ax = plt.subplots(figsize=(8, 6))
    for clf, sub in fold_df.groupby("classifier"):
        y_true_all = np.concatenate([np.asarray(t) for t in sub["y_true"]])
        y_proba_all = np.concatenate([np.asarray(p) for p in sub["y_proba_pos"]])
        fpr, tpr, _ = roc_curve(y_true_all, y_proba_all)
        auc = roc_auc_score(y_true_all, y_proba_all)
        ax.plot(fpr, tpr, label=f"{clf} (AUC={auc:.3f})", linewidth=1.7)
    ax.plot([0, 1], [0, 1], "k--", alpha=0.4, linewidth=1)
    ax.set_xlabel("False positive rate")
    ax.set_ylabel("True positive rate")
    ax.set_title("ROC curves across 27 outer folds (concatenated) - PD vs HC (class-aware)")
    ax.legend(loc="lower right", fontsize=9)
    ax.grid(alpha=0.25)
    fig.tight_layout(); fig.savefig(out_path, dpi=200); plt.close(fig)


def plot_pr_per_classifier(fold_df: pd.DataFrame, out_path: Path):
    fig, ax = plt.subplots(figsize=(8, 6))
    for clf, sub in fold_df.groupby("classifier"):
        y_true_all = np.concatenate([np.asarray(t) for t in sub["y_true"]])
        y_proba_all = np.concatenate([np.asarray(p) for p in sub["y_proba_pos"]])
        prec, rec, _ = precision_recall_curve(y_true_all, y_proba_all)
        ap = average_precision_score(y_true_all, y_proba_all)
        ax.plot(rec, prec, label=f"{clf} (AP={ap:.3f})", linewidth=1.7)
    ax.set_xlabel("Recall")
    ax.set_ylabel("Precision")
    ax.set_title("PR curves across 27 outer folds (concatenated) - PD vs HC (class-aware)")
    ax.legend(loc="lower left", fontsize=9)
    ax.grid(alpha=0.25)
    fig.tight_layout(); fig.savefig(out_path, dpi=200); plt.close(fig)


# ============================ Per-classifier CV ============================
def run_classifier_cv(name, cfg, X, y_int, gene_names, meta,
                      fold_records, sel_records):
    print(f"\n--- {name} ---")
    for seed in SEEDS:
        skf = StratifiedKFold(n_splits=N_OUTER, shuffle=True, random_state=seed)
        for fold_i, (tr_idx, te_idx) in enumerate(skf.split(X, y_int)):
            X_tr, X_te = X[tr_idx], X[te_idx]
            y_tr, y_te = y_int[tr_idx], y_int[te_idx]
            sw_tr = composite_sample_weights(meta.iloc[tr_idx], y_int[tr_idx])

            inner = StratifiedKFold(n_splits=N_INNER, shuffle=True,
                                    random_state=seed * 1000 + fold_i)
            gs = GridSearchCV(
                estimator=cfg["pipe"],
                param_grid=cfg["grid"],
                scoring="balanced_accuracy",
                cv=inner, n_jobs=N_JOBS, refit=True,
            )

            fit_kwargs = {}
            if cfg["supports_sw"]:
                fit_kwargs["clf__sample_weight"] = sw_tr

            gs.fit(X_tr, y_tr, **fit_kwargs)

            y_pred  = gs.predict(X_te)
            y_proba = gs.predict_proba(X_te)
            y_proba_pos = y_proba[:, 1]
            metrics = evaluate_binary(y_te, y_pred, y_proba_pos)

            fold_records.append({
                "classifier":   name,
                "seed":         seed,
                "fold":         fold_i + 1,
                "best_params":  json.dumps(gs.best_params_),
                **metrics,
                "y_true":       y_te.tolist(),
                "y_proba_pos":  y_proba_pos.tolist(),
            })
            print(f"  seed={seed} fold={fold_i+1}  "
                  f"BA={metrics['balanced_accuracy']:.3f}  "
                  f"F1={metrics['macro_f1']:.3f}  "
                  f"AUROC={metrics['auroc']:.3f}  "
                  f"PR-AUC={metrics['pr_auc']:.3f}", flush=True)

            if name in ("ElasticNet", "mSVM-RFE"):
                sel = selected_genes_from_estimator(name, gs, gene_names)
                for g in sel:
                    sel_records.append({"classifier": name, "seed": seed,
                                        "fold": fold_i + 1, "gene": g})


# ============================ Per-panel run ================================
def run_for_panel(k_top: int):
    out_dir = STAGE4_BASE / f"stage4_classifiers_PDHC_top{k_top}"
    out_dir.mkdir(parents=True, exist_ok=True)
    print("\n" + "=" * 72)
    print(f"PANEL SIZE: top {k_top} consensus genes - output: {out_dir.name}")
    print("=" * 72)

    consensus = pd.read_csv(CONSENSUS_PATH, index_col=0)
    if "fold_inclusion" not in consensus.columns:
        consensus.columns = ["fold_inclusion"]
    top_genes = (consensus.sort_values("fold_inclusion", ascending=False)
                          .head(k_top).index.tolist())
    print(f"Top genes loaded: {len(top_genes)}")

    train_df = load_features_x_samples(TRAIN_PATH, top_genes).round(4)
    test_df  = load_features_x_samples(TEST_PATH,  top_genes).round(4)
    train_df.to_csv(out_dir / "train_postfeature.csv")
    test_df.to_csv(out_dir / "test_postfeature.csv")
    print(f"Saved postfeature CSVs (train: {train_df.shape}, "
          f"test: {test_df.shape})")

    meta_train = load_meta(train_df.columns)
    y_train_str = meta_train[CONDITION_COL].values
    y_train_bin = to_binary_labels(y_train_str)
    y_train_int = encode_binary(y_train_bin)
    print(f"Class balance (PD=1, HC=0): {dict(Counter(y_train_bin))}")

    X_train = train_df.T.values.astype(np.float64)
    gene_names = train_df.index.tolist()

    classifiers = get_classifiers(seed=42)
    classifiers["mSVM-RFE"]["grid"]["rfe__n_features_to_select"] = \
        rfe_grid_for_panel(k_top)
    print(f"RFE n_features_to_select grid: "
          f"{classifiers['mSVM-RFE']['grid']['rfe__n_features_to_select']}")

    fold_records, sel_records = [], []
    for name, cfg in classifiers.items():
        run_classifier_cv(name, cfg, X_train, y_train_int, gene_names,
                          meta_train, fold_records, sel_records)

    fold_df = pd.DataFrame(fold_records)
    csv_cols = [c for c in fold_df.columns
                if c not in ("y_true", "y_proba_pos")]
    fold_df[csv_cols].to_csv(out_dir / "fold_results.csv", index=False)

    agg = aggregate_metrics(fold_df)
    agg.to_csv(out_dir / "final_metrics.csv", index=False)
    print("\nFinal metrics (mean across 27 folds):")
    print(agg.set_index("classifier")
          [["balanced_accuracy_mean", "macro_f1_mean",
            "auroc_mean", "pr_auc_mean"]].round(3).to_string())

    cons = consensus_hyperparams(fold_df)
    cons.to_csv(out_dir / "consensus_hyperparams.csv", index=False)
    print("\nConsensus hyperparameters (mode across 27 folds):")
    print(cons.set_index("classifier").to_string())

    plot_roc_per_classifier(fold_df, out_dir / "roc_curves.png")
    plot_pr_per_classifier(fold_df,  out_dir / "pr_curves.png")

    n_folds_total = N_OUTER * len(SEEDS)
    inc_tables = fold_inclusion_table(sel_records, top_genes, n_folds_total)
    if "ElasticNet" in inc_tables:
        inc_tables["ElasticNet"].to_csv(
            out_dir / "enet_fold_inclusion.csv", index=False)
    if "mSVM-RFE" in inc_tables:
        inc_tables["mSVM-RFE"].to_csv(
            out_dir / "rfe_fold_inclusion.csv", index=False)

    print(f"\nOutputs in: {out_dir}")


def main():
    print("=" * 72)
    print("STAGE 4 (PD vs HC, class-aware) - Multi-classifier nested CV")
    print(f"Panel sizes: {PANEL_SIZES}")
    print(f"Outer={N_OUTER} x seeds={SEEDS} = {N_OUTER * len(SEEDS)} folds; "
          f"inner={N_INNER}")
    print("=" * 72)
    for k in PANEL_SIZES:
        run_for_panel(k)


if __name__ == "__main__":
    main()
# Out:
# ========================================================================
# STAGE 4 (PD vs HC, class-aware) - Multi-classifier nested CV
# Panel sizes: [5, 10, 15, 25, 41]
# Outer=9 x seeds=[42, 123, 256] = 27 folds; inner=4
# ========================================================================
#
# ========================================================================
# PANEL SIZE: top 5 consensus genes - output: stage4_classifiers_PDHC_top5
# ========================================================================
# Top genes loaded: 5
# Saved postfeature CSVs (train: (5, 108), test: (5, 47))
# Class balance (PD=1, HC=0): {np.str_('HC'): 36, np.str_('PD'): 72}
# RFE n_features_to_select grid: [2, 3, 4, 5]
#
# --- mSVM-RBF ---
#   seed=42 fold=1  BA=0.562  F1=0.556  AUROC=0.375  PR-AUC=0.606
#   seed=42 fold=2  BA=0.312  F1=0.245  AUROC=0.344  PR-AUC=0.610
#   seed=42 fold=3  BA=0.562  F1=0.556  AUROC=0.625  PR-AUC=0.863
#   seed=42 fold=4  BA=0.250  F1=0.250  AUROC=0.250  PR-AUC=0.673
#   seed=42 fold=5  BA=0.688  F1=0.657  AUROC=0.781  PR-AUC=0.834
#   seed=42 fold=6  BA=0.688  F1=0.580  AUROC=0.719  PR-AUC=0.876
#   seed=42 fold=7  BA=0.312  F1=0.314  AUROC=0.219  PR-AUC=0.550
#   seed=42 fold=8  BA=0.562  F1=0.556  AUROC=0.406  PR-AUC=0.614
#   seed=42 fold=9  BA=0.500  F1=0.496  AUROC=0.594  PR-AUC=0.809
#   seed=123 fold=1  BA=0.375  F1=0.333  AUROC=0.344  PR-AUC=0.612
#   seed=123 fold=2  BA=0.562  F1=0.556  AUROC=0.375  PR-AUC=0.602
#   seed=123 fold=3  BA=0.438  F1=0.438  AUROC=0.562  PR-AUC=0.807
#   seed=123 fold=4  BA=0.500  F1=0.496  AUROC=0.531  PR-AUC=0.687
#   seed=123 fold=5  BA=0.375  F1=0.378  AUROC=0.500  PR-AUC=0.679
#   seed=123 fold=6  BA=0.375  F1=0.333  AUROC=0.438  PR-AUC=0.692
#   seed=123 fold=7  BA=0.688  F1=0.657  AUROC=0.625  PR-AUC=0.778
#   seed=123 fold=8  BA=0.562  F1=0.500  AUROC=0.625  PR-AUC=0.818
#   seed=123 fold=9  BA=0.562  F1=0.556  AUROC=0.531  PR-AUC=0.728
#   seed=256 fold=1  BA=0.438  F1=0.413  AUROC=0.562  PR-AUC=0.772
#   seed=256 fold=2  BA=0.562  F1=0.556  AUROC=0.531  PR-AUC=0.736
#   seed=256 fold=3  BA=0.625  F1=0.625  AUROC=0.594  PR-AUC=0.766
#   seed=256 fold=4  BA=0.250  F1=0.245  AUROC=0.250  PR-AUC=0.562
#   seed=256 fold=5  BA=0.375  F1=0.200  AUROC=0.625  PR-AUC=0.720
#   seed=256 fold=6  BA=0.438  F1=0.314  AUROC=0.562  PR-AUC=0.705
#   seed=256 fold=7  BA=0.438  F1=0.413  AUROC=0.375  PR-AUC=0.683
#   seed=256 fold=8  BA=0.438  F1=0.413  AUROC=0.469  PR-AUC=0.700
#   seed=256 fold=9  BA=0.500  F1=0.250  AUROC=0.219  PR-AUC=0.570
#
# --- mSVM-Linear ---
#   seed=42 fold=1  BA=0.500  F1=0.486  AUROC=0.406  PR-AUC=0.623
#   seed=42 fold=2  BA=0.500  F1=0.486  AUROC=0.500  PR-AUC=0.771
#   seed=42 fold=3  BA=0.500  F1=0.250  AUROC=0.625  PR-AUC=0.805
#   seed=42 fold=4  BA=0.438  F1=0.438  AUROC=0.438  PR-AUC=0.710
#   seed=42 fold=5  BA=0.750  F1=0.733  AUROC=0.781  PR-AUC=0.834
#   seed=42 fold=6  BA=0.688  F1=0.580  AUROC=0.750  PR-AUC=0.890
#   seed=42 fold=7  BA=0.250  F1=0.143  AUROC=0.219  PR-AUC=0.554
#   seed=42 fold=8  BA=0.500  F1=0.486  AUROC=0.438  PR-AUC=0.624
#   seed=42 fold=9  BA=0.500  F1=0.250  AUROC=0.719  PR-AUC=0.867
#   seed=123 fold=1  BA=0.438  F1=0.314  AUROC=0.344  PR-AUC=0.604
#   seed=123 fold=2  BA=0.375  F1=0.333  AUROC=0.469  PR-AUC=0.710
#   seed=123 fold=3  BA=0.438  F1=0.368  AUROC=0.531  PR-AUC=0.802
#   seed=123 fold=4  BA=0.500  F1=0.250  AUROC=0.594  PR-AUC=0.795
#   seed=123 fold=5  BA=0.500  F1=0.486  AUROC=0.500  PR-AUC=0.683
#   seed=123 fold=6  BA=0.438  F1=0.314  AUROC=0.688  PR-AUC=0.751
#   seed=123 fold=7  BA=0.500  F1=0.250  AUROC=0.844  PR-AUC=0.921
#   seed=123 fold=8  BA=0.562  F1=0.500  AUROC=0.656  PR-AUC=0.849
#   seed=123 fold=9  BA=0.312  F1=0.314  AUROC=0.438  PR-AUC=0.651
#   seed=256 fold=1  BA=0.562  F1=0.500  AUROC=0.625  PR-AUC=0.820
#   seed=256 fold=2  BA=0.500  F1=0.250  AUROC=0.719  PR-AUC=0.855
#   seed=256 fold=3  BA=0.500  F1=0.250  AUROC=0.406  PR-AUC=0.616
#   seed=256 fold=4  BA=0.312  F1=0.314  AUROC=0.250  PR-AUC=0.562
#   seed=256 fold=5  BA=0.438  F1=0.314  AUROC=0.625  PR-AUC=0.720
#   seed=256 fold=6  BA=0.562  F1=0.500  AUROC=0.562  PR-AUC=0.760
#   seed=256 fold=7  BA=0.562  F1=0.556  AUROC=0.500  PR-AUC=0.785
#   seed=256 fold=8  BA=0.562  F1=0.556  AUROC=0.562  PR-AUC=0.749
#   seed=256 fold=9  BA=0.625  F1=0.580  AUROC=0.750  PR-AUC=0.892
#
# --- mSVM-RFE ---
#   seed=42 fold=1  BA=0.500  F1=0.400  AUROC=0.500  PR-AUC=0.643
#   seed=42 fold=2  BA=0.438  F1=0.368  AUROC=0.562  PR-AUC=0.763
#   seed=42 fold=3  BA=0.500  F1=0.400  AUROC=0.562  PR-AUC=0.749
#   seed=42 fold=4  BA=0.625  F1=0.621  AUROC=0.531  PR-AUC=0.691
#   seed=42 fold=5  BA=0.500  F1=0.400  AUROC=0.375  PR-AUC=0.596
#   seed=42 fold=6  BA=0.500  F1=0.400  AUROC=0.562  PR-AUC=0.680
#   seed=42 fold=7  BA=0.500  F1=0.400  AUROC=0.531  PR-AUC=0.675
#   seed=42 fold=8  BA=0.500  F1=0.400  AUROC=0.438  PR-AUC=0.624
#   seed=42 fold=9  BA=0.500  F1=0.400  AUROC=0.250  PR-AUC=0.571
#   seed=123 fold=1  BA=0.500  F1=0.400  AUROC=0.469  PR-AUC=0.655
#   seed=123 fold=2  BA=0.438  F1=0.368  AUROC=0.531  PR-AUC=0.730
#   seed=123 fold=3  BA=0.500  F1=0.400  AUROC=0.453  PR-AUC=0.706
#   seed=123 fold=4  BA=0.500  F1=0.400  AUROC=0.312  PR-AUC=0.583
#   seed=123 fold=5  BA=0.500  F1=0.496  AUROC=0.531  PR-AUC=0.691
#   seed=123 fold=6  BA=0.500  F1=0.400  AUROC=0.500  PR-AUC=0.754
#   seed=123 fold=7  BA=0.500  F1=0.400  AUROC=0.250  PR-AUC=0.573
#   seed=123 fold=8  BA=0.500  F1=0.400  AUROC=0.312  PR-AUC=0.662
#   seed=123 fold=9  BA=0.500  F1=0.400  AUROC=0.500  PR-AUC=0.674
#   seed=256 fold=1  BA=0.500  F1=0.400  AUROC=0.406  PR-AUC=0.637
#   seed=256 fold=2  BA=0.500  F1=0.400  AUROC=0.094  PR-AUC=0.514
#   seed=256 fold=3  BA=0.500  F1=0.400  AUROC=0.344  PR-AUC=0.608
#   seed=256 fold=4  BA=0.312  F1=0.294  AUROC=0.281  PR-AUC=0.579
#   seed=256 fold=5  BA=0.500  F1=0.400  AUROC=0.250  PR-AUC=0.641
#   seed=256 fold=6  BA=0.500  F1=0.400  AUROC=0.500  PR-AUC=0.729
#   seed=256 fold=7  BA=0.438  F1=0.368  AUROC=0.312  PR-AUC=0.590
#   seed=256 fold=8  BA=0.500  F1=0.400  AUROC=0.469  PR-AUC=0.658
#   seed=256 fold=9  BA=0.500  F1=0.400  AUROC=0.250  PR-AUC=0.558
#
# --- kNN ---
#   seed=42 fold=1  BA=0.500  F1=0.496  AUROC=0.406  PR-AUC=0.625
#   seed=42 fold=2  BA=0.625  F1=0.625  AUROC=0.469  PR-AUC=0.677
#   seed=42 fold=3  BA=0.562  F1=0.556  AUROC=0.578  PR-AUC=0.710
#   seed=42 fold=4  BA=0.438  F1=0.368  AUROC=0.359  PR-AUC=0.608
#   seed=42 fold=5  BA=0.562  F1=0.556  AUROC=0.688  PR-AUC=0.836
#   seed=42 fold=6  BA=0.562  F1=0.556  AUROC=0.625  PR-AUC=0.757
#   seed=42 fold=7  BA=0.500  F1=0.496  AUROC=0.484  PR-AUC=0.663
#   seed=42 fold=8  BA=0.500  F1=0.496  AUROC=0.469  PR-AUC=0.640
#   seed=42 fold=9  BA=0.625  F1=0.621  AUROC=0.719  PR-AUC=0.887
#   seed=123 fold=1  BA=0.562  F1=0.556  AUROC=0.453  PR-AUC=0.646
#   seed=123 fold=2  BA=0.562  F1=0.556  AUROC=0.547  PR-AUC=0.687
#   seed=123 fold=3  BA=0.562  F1=0.556  AUROC=0.406  PR-AUC=0.632
#   seed=123 fold=4  BA=0.625  F1=0.621  AUROC=0.734  PR-AUC=0.794
#   seed=123 fold=5  BA=0.562  F1=0.556  AUROC=0.391  PR-AUC=0.665
#   seed=123 fold=6  BA=0.438  F1=0.368  AUROC=0.375  PR-AUC=0.641
#   seed=123 fold=7  BA=0.625  F1=0.580  AUROC=0.594  PR-AUC=0.700
#   seed=123 fold=8  BA=0.562  F1=0.556  AUROC=0.656  PR-AUC=0.822
#   seed=123 fold=9  BA=0.562  F1=0.556  AUROC=0.469  PR-AUC=0.676
#   seed=256 fold=1  BA=0.688  F1=0.657  AUROC=0.656  PR-AUC=0.740
#   seed=256 fold=2  BA=0.625  F1=0.621  AUROC=0.625  PR-AUC=0.765
#   seed=256 fold=3  BA=0.625  F1=0.625  AUROC=0.750  PR-AUC=0.854
#   seed=256 fold=4  BA=0.375  F1=0.333  AUROC=0.250  PR-AUC=0.563
#   seed=256 fold=5  BA=0.688  F1=0.697  AUROC=0.594  PR-AUC=0.731
#   seed=256 fold=6  BA=0.562  F1=0.556  AUROC=0.531  PR-AUC=0.678
#   seed=256 fold=7  BA=0.438  F1=0.368  AUROC=0.391  PR-AUC=0.623
#   seed=256 fold=8  BA=0.500  F1=0.486  AUROC=0.469  PR-AUC=0.642
#   seed=256 fold=9  BA=0.688  F1=0.697  AUROC=0.797  PR-AUC=0.855
#
# --- GaussianNB ---
#   seed=42 fold=1  BA=0.438  F1=0.413  AUROC=0.438  PR-AUC=0.624
#   seed=42 fold=2  BA=0.625  F1=0.580  AUROC=0.562  PR-AUC=0.763
#   seed=42 fold=3  BA=0.500  F1=0.486  AUROC=0.531  PR-AUC=0.739
#   seed=42 fold=4  BA=0.375  F1=0.378  AUROC=0.312  PR-AUC=0.646
#   seed=42 fold=5  BA=0.750  F1=0.733  AUROC=0.750  PR-AUC=0.823
#   seed=42 fold=6  BA=0.562  F1=0.500  AUROC=0.625  PR-AUC=0.812
#   seed=42 fold=7  BA=0.375  F1=0.333  AUROC=0.375  PR-AUC=0.606
#   seed=42 fold=8  BA=0.625  F1=0.625  AUROC=0.656  PR-AUC=0.735
#   seed=42 fold=9  BA=0.562  F1=0.500  AUROC=0.719  PR-AUC=0.865
#   seed=123 fold=1  BA=0.438  F1=0.413  AUROC=0.562  PR-AUC=0.772
#   seed=123 fold=2  BA=0.562  F1=0.556  AUROC=0.469  PR-AUC=0.700
#   seed=123 fold=3  BA=0.562  F1=0.556  AUROC=0.656  PR-AUC=0.822
#   seed=123 fold=4  BA=0.688  F1=0.657  AUROC=0.656  PR-AUC=0.844
#   seed=123 fold=5  BA=0.438  F1=0.438  AUROC=0.469  PR-AUC=0.655
#   seed=123 fold=6  BA=0.688  F1=0.580  AUROC=0.688  PR-AUC=0.839
#   seed=123 fold=7  BA=0.750  F1=0.667  AUROC=0.750  PR-AUC=0.886
#   seed=123 fold=8  BA=0.562  F1=0.500  AUROC=0.656  PR-AUC=0.849
#   seed=123 fold=9  BA=0.438  F1=0.438  AUROC=0.594  PR-AUC=0.795
#   seed=256 fold=1  BA=0.688  F1=0.657  AUROC=0.688  PR-AUC=0.853
#   seed=256 fold=2  BA=0.688  F1=0.657  AUROC=0.812  PR-AUC=0.876
#   seed=256 fold=3  BA=0.500  F1=0.486  AUROC=0.688  PR-AUC=0.839
#   seed=256 fold=4  BA=0.500  F1=0.486  AUROC=0.406  PR-AUC=0.724
#   seed=256 fold=5  BA=0.625  F1=0.580  AUROC=0.594  PR-AUC=0.718
#   seed=256 fold=6  BA=0.375  F1=0.333  AUROC=0.469  PR-AUC=0.710
#   seed=256 fold=7  BA=0.500  F1=0.486  AUROC=0.344  PR-AUC=0.662
#   seed=256 fold=8  BA=0.562  F1=0.556  AUROC=0.562  PR-AUC=0.738
#   seed=256 fold=9  BA=0.688  F1=0.657  AUROC=0.812  PR-AUC=0.916
#
# --- ElasticNet ---
#   seed=42 fold=1  BA=0.375  F1=0.333  AUROC=0.500  PR-AUC=0.707
#   seed=42 fold=2  BA=0.500  F1=0.250  AUROC=0.375  PR-AUC=0.673
#   seed=42 fold=3  BA=0.562  F1=0.556  AUROC=0.562  PR-AUC=0.753
#   seed=42 fold=4  BA=0.500  F1=0.486  AUROC=0.500  PR-AUC=0.768
#   seed=42 fold=5  BA=0.750  F1=0.733  AUROC=0.781  PR-AUC=0.834
#   seed=42 fold=6  BA=0.562  F1=0.378  AUROC=0.719  PR-AUC=0.865
#   seed=42 fold=7  BA=0.250  F1=0.143  AUROC=0.281  PR-AUC=0.575
#   seed=42 fold=8  BA=0.625  F1=0.625  AUROC=0.500  PR-AUC=0.643
#   seed=42 fold=9  BA=0.625  F1=0.486  AUROC=0.719  PR-AUC=0.865
#   seed=123 fold=1  BA=0.312  F1=0.245  AUROC=0.344  PR-AUC=0.595
#   seed=123 fold=2  BA=0.438  F1=0.413  AUROC=0.500  PR-AUC=0.721
#   seed=123 fold=3  BA=0.562  F1=0.556  AUROC=0.562  PR-AUC=0.817
#   seed=123 fold=4  BA=0.500  F1=0.250  AUROC=0.500  PR-AUC=0.667
#   seed=123 fold=5  BA=0.500  F1=0.486  AUROC=0.469  PR-AUC=0.672
#   seed=123 fold=6  BA=0.500  F1=0.250  AUROC=0.719  PR-AUC=0.760
#   seed=123 fold=7  BA=0.500  F1=0.250  AUROC=0.500  PR-AUC=0.667
#   seed=123 fold=8  BA=0.562  F1=0.500  AUROC=0.625  PR-AUC=0.818
#   seed=123 fold=9  BA=0.312  F1=0.314  AUROC=0.438  PR-AUC=0.651
#   seed=256 fold=1  BA=0.562  F1=0.500  AUROC=0.750  PR-AUC=0.879
#   seed=256 fold=2  BA=0.625  F1=0.580  AUROC=0.625  PR-AUC=0.810
#   seed=256 fold=3  BA=0.438  F1=0.413  AUROC=0.625  PR-AUC=0.766
#   seed=256 fold=4  BA=0.438  F1=0.413  AUROC=0.312  PR-AUC=0.590
#   seed=256 fold=5  BA=0.500  F1=0.413  AUROC=0.656  PR-AUC=0.739
#   seed=256 fold=6  BA=0.500  F1=0.413  AUROC=0.594  PR-AUC=0.771
#   seed=256 fold=7  BA=0.562  F1=0.556  AUROC=0.469  PR-AUC=0.754
#   seed=256 fold=8  BA=0.500  F1=0.486  AUROC=0.531  PR-AUC=0.730
#   seed=256 fold=9  BA=0.812  F1=0.748  AUROC=0.781  PR-AUC=0.907
#
# Final metrics (mean across 27 folds):
#              balanced_accuracy_mean  macro_f1_mean  auroc_mean  pr_auc_mean
# classifier
# ElasticNet                    0.514          0.436       0.553        0.741
# GaussianNB                    0.558          0.528       0.587        0.771
# kNN                           0.560          0.545       0.536        0.708
# mSVM-Linear                   0.493          0.400       0.553        0.748
# mSVM-RBF                      0.479          0.440       0.483        0.706
# mSVM-RFE                      0.491          0.404       0.410        0.649
#
# Consensus hyperparameters (mode across 27 folds):
#             clf__C  clf__C__support_pct clf__l1_ratio  clf__l1_ratio__support_pct clf__var_smoothing  clf__var_smoothing__support_pct clf__n_neighbors  clf__n_neighbors__support_pct clf__weights  clf__weights__support_pct clf__gamma  clf__gamma__support_pct rfe__estimator__C  rfe__estimator__C__support_pct rfe__n_features_to_select  rfe__n_features_to_select__support_pct
# classifier
# ElasticNet       1                 51.9           0.1                        70.4                NaN                              NaN              NaN                            NaN          NaN                        NaN        NaN                      NaN               NaN                             NaN                       NaN                                     NaN
# GaussianNB     NaN                  NaN           NaN                         NaN              1e-11                            100.0              NaN                            NaN          NaN                        NaN        NaN                      NaN               NaN                             NaN                       NaN                                     NaN
# kNN            NaN                  NaN           NaN                         NaN                NaN                              NaN                3                           51.9      uniform                       81.5        NaN                      NaN               NaN                             NaN                       NaN                                     NaN
# mSVM-Linear      1                 33.3           NaN                         NaN                NaN                              NaN              NaN                            NaN          NaN                        NaN        NaN                      NaN               NaN                             NaN                       NaN                                     NaN
# mSVM-RBF        10                 59.3           NaN                         NaN                NaN                              NaN              NaN                            NaN          NaN                        NaN      scale                     29.6               NaN                             NaN                       NaN                                     NaN
# mSVM-RFE       NaN                  NaN           NaN                         NaN                NaN                              NaN              NaN                            NaN          NaN                        NaN        NaN                      NaN                10                            48.1                         2                                    48.1
#
# Outputs in: C:\Users\hafsa\Python PD Project\MI_BaggedLASSO Pipeline\PDHC new\PDHC-class-aware\Outputs\stage4_HP_nosmote\stage4_classifiers_PDHC_top5
#
# ========================================================================
# PANEL SIZE: top 10 consensus genes - output: stage4_classifiers_PDHC_top10
# ========================================================================
# Top genes loaded: 10
# Saved postfeature CSVs (train: (10, 108), test: (10, 47))
# Class balance (PD=1, HC=0): {np.str_('HC'): 36, np.str_('PD'): 72}
# RFE n_features_to_select grid: [2, 5, 9, 10]
#
# --- mSVM-RBF ---
#   seed=42 fold=1  BA=0.562  F1=0.556  AUROC=0.375  PR-AUC=0.675
#   seed=42 fold=2  BA=0.438  F1=0.368  AUROC=0.375  PR-AUC=0.666
#   seed=42 fold=3  BA=0.438  F1=0.413  AUROC=0.438  PR-AUC=0.689
#   seed=42 fold=4  BA=0.312  F1=0.294  AUROC=0.281  PR-AUC=0.587
#   seed=42 fold=5  BA=0.375  F1=0.378  AUROC=0.594  PR-AUC=0.832
#   seed=42 fold=6  BA=0.500  F1=0.496  AUROC=0.625  PR-AUC=0.850
#   seed=42 fold=7  BA=0.062  F1=0.077  AUROC=0.094  PR-AUC=0.528
#   seed=42 fold=8  BA=0.375  F1=0.378  AUROC=0.594  PR-AUC=0.711
#   seed=42 fold=9  BA=0.625  F1=0.621  AUROC=0.594  PR-AUC=0.716
#   seed=123 fold=1  BA=0.625  F1=0.625  AUROC=0.406  PR-AUC=0.623
#   seed=123 fold=2  BA=0.562  F1=0.556  AUROC=0.406  PR-AUC=0.629
#   seed=123 fold=3  BA=0.375  F1=0.333  AUROC=0.438  PR-AUC=0.702
#   seed=123 fold=4  BA=0.438  F1=0.368  AUROC=0.531  PR-AUC=0.776
#   seed=123 fold=5  BA=0.562  F1=0.556  AUROC=0.531  PR-AUC=0.786
#   seed=123 fold=6  BA=0.562  F1=0.556  AUROC=0.406  PR-AUC=0.647
#   seed=123 fold=7  BA=0.438  F1=0.368  AUROC=0.625  PR-AUC=0.731
#   seed=123 fold=8  BA=0.625  F1=0.625  AUROC=0.344  PR-AUC=0.610
#   seed=123 fold=9  BA=0.688  F1=0.697  AUROC=0.656  PR-AUC=0.788
#   seed=256 fold=1  BA=0.375  F1=0.333  AUROC=0.406  PR-AUC=0.629
#   seed=256 fold=2  BA=0.500  F1=0.496  AUROC=0.562  PR-AUC=0.705
#   seed=256 fold=3  BA=0.625  F1=0.625  AUROC=0.562  PR-AUC=0.708
#   seed=256 fold=4  BA=0.188  F1=0.200  AUROC=0.219  PR-AUC=0.578
#   seed=256 fold=5  BA=0.375  F1=0.333  AUROC=0.656  PR-AUC=0.841
#   seed=256 fold=6  BA=0.375  F1=0.333  AUROC=0.438  PR-AUC=0.626
#   seed=256 fold=7  BA=0.562  F1=0.556  AUROC=0.438  PR-AUC=0.650
#   seed=256 fold=8  BA=0.562  F1=0.556  AUROC=0.531  PR-AUC=0.687
#   seed=256 fold=9  BA=0.500  F1=0.250  AUROC=0.188  PR-AUC=0.569
#
# --- mSVM-Linear ---
#   seed=42 fold=1  BA=0.562  F1=0.556  AUROC=0.562  PR-AUC=0.684
#   seed=42 fold=2  BA=0.500  F1=0.250  AUROC=0.500  PR-AUC=0.783
#   seed=42 fold=3  BA=0.375  F1=0.333  AUROC=0.438  PR-AUC=0.689
#   seed=42 fold=4  BA=0.375  F1=0.378  AUROC=0.219  PR-AUC=0.558
#   seed=42 fold=5  BA=0.500  F1=0.250  AUROC=0.250  PR-AUC=0.555
#   seed=42 fold=6  BA=0.500  F1=0.250  AUROC=0.281  PR-AUC=0.609
#   seed=42 fold=7  BA=0.250  F1=0.143  AUROC=0.094  PR-AUC=0.515
#   seed=42 fold=8  BA=0.500  F1=0.486  AUROC=0.406  PR-AUC=0.614
#   seed=42 fold=9  BA=0.625  F1=0.580  AUROC=0.250  PR-AUC=0.571
#   seed=123 fold=1  BA=0.500  F1=0.486  AUROC=0.500  PR-AUC=0.748
#   seed=123 fold=2  BA=0.438  F1=0.438  AUROC=0.594  PR-AUC=0.711
#   seed=123 fold=3  BA=0.312  F1=0.314  AUROC=0.312  PR-AUC=0.650
#   seed=123 fold=4  BA=0.500  F1=0.250  AUROC=0.406  PR-AUC=0.721
#   seed=123 fold=5  BA=0.500  F1=0.250  AUROC=0.562  PR-AUC=0.753
#   seed=123 fold=6  BA=0.500  F1=0.250  AUROC=0.219  PR-AUC=0.547
#   seed=123 fold=7  BA=0.500  F1=0.250  AUROC=0.344  PR-AUC=0.590
#   seed=123 fold=8  BA=0.562  F1=0.500  AUROC=0.594  PR-AUC=0.776
#   seed=123 fold=9  BA=0.375  F1=0.378  AUROC=0.500  PR-AUC=0.748
#   seed=256 fold=1  BA=0.438  F1=0.413  AUROC=0.500  PR-AUC=0.725
#   seed=256 fold=2  BA=0.500  F1=0.250  AUROC=0.219  PR-AUC=0.558
#   seed=256 fold=3  BA=0.688  F1=0.657  AUROC=0.344  PR-AUC=0.590
#   seed=256 fold=4  BA=0.375  F1=0.333  AUROC=0.312  PR-AUC=0.650
#   seed=256 fold=5  BA=0.500  F1=0.413  AUROC=0.500  PR-AUC=0.734
#   seed=256 fold=6  BA=0.500  F1=0.413  AUROC=0.688  PR-AUC=0.806
#   seed=256 fold=7  BA=0.500  F1=0.486  AUROC=0.469  PR-AUC=0.700
#   seed=256 fold=8  BA=0.562  F1=0.556  AUROC=0.562  PR-AUC=0.772
#   seed=256 fold=9  BA=0.500  F1=0.250  AUROC=0.656  PR-AUC=0.820
#
# --- mSVM-RFE ---
#   seed=42 fold=1  BA=0.500  F1=0.400  AUROC=0.281  PR-AUC=0.579
#   seed=42 fold=2  BA=0.438  F1=0.368  AUROC=0.562  PR-AUC=0.763
#   seed=42 fold=3  BA=0.750  F1=0.778  AUROC=0.500  PR-AUC=0.643
#   seed=42 fold=4  BA=0.562  F1=0.556  AUROC=0.656  PR-AUC=0.794
#   seed=42 fold=5  BA=0.500  F1=0.400  AUROC=0.281  PR-AUC=0.565
#   seed=42 fold=6  BA=0.500  F1=0.400  AUROC=0.469  PR-AUC=0.752
#   seed=42 fold=7  BA=0.312  F1=0.294  AUROC=0.281  PR-AUC=0.600
#   seed=42 fold=8  BA=0.500  F1=0.400  AUROC=0.500  PR-AUC=0.655
#   seed=42 fold=9  BA=0.500  F1=0.400  AUROC=0.219  PR-AUC=0.550
#   seed=123 fold=1  BA=0.562  F1=0.556  AUROC=0.406  PR-AUC=0.650
#   seed=123 fold=2  BA=0.438  F1=0.368  AUROC=0.500  PR-AUC=0.721
#   seed=123 fold=3  BA=0.375  F1=0.333  AUROC=0.438  PR-AUC=0.692
#   seed=123 fold=4  BA=0.500  F1=0.400  AUROC=0.219  PR-AUC=0.554
#   seed=123 fold=5  BA=0.562  F1=0.556  AUROC=0.562  PR-AUC=0.701
#   seed=123 fold=6  BA=0.562  F1=0.556  AUROC=0.406  PR-AUC=0.623
#   seed=123 fold=7  BA=0.500  F1=0.400  AUROC=0.281  PR-AUC=0.565
#   seed=123 fold=8  BA=0.750  F1=0.733  AUROC=0.312  PR-AUC=0.658
#   seed=123 fold=9  BA=0.500  F1=0.400  AUROC=0.625  PR-AUC=0.729
#   seed=256 fold=1  BA=0.500  F1=0.400  AUROC=0.250  PR-AUC=0.571
#   seed=256 fold=2  BA=0.500  F1=0.400  AUROC=0.406  PR-AUC=0.640
#   seed=256 fold=3  BA=0.500  F1=0.400  AUROC=0.188  PR-AUC=0.542
#   seed=256 fold=4  BA=0.438  F1=0.438  AUROC=0.281  PR-AUC=0.579
#   seed=256 fold=5  BA=0.438  F1=0.368  AUROC=0.500  PR-AUC=0.752
#   seed=256 fold=6  BA=0.688  F1=0.697  AUROC=0.375  PR-AUC=0.661
#   seed=256 fold=7  BA=0.500  F1=0.400  AUROC=0.375  PR-AUC=0.606
#   seed=256 fold=8  BA=0.750  F1=0.778  AUROC=0.406  PR-AUC=0.616
#   seed=256 fold=9  BA=0.500  F1=0.400  AUROC=0.156  PR-AUC=0.531
#
# --- kNN ---
#   seed=42 fold=1  BA=0.562  F1=0.556  AUROC=0.734  PR-AUC=0.828
#   seed=42 fold=2  BA=0.438  F1=0.368  AUROC=0.578  PR-AUC=0.718
#   seed=42 fold=3  BA=0.688  F1=0.697  AUROC=0.609  PR-AUC=0.719
#   seed=42 fold=4  BA=0.500  F1=0.400  AUROC=0.312  PR-AUC=0.581
#   seed=42 fold=5  BA=0.438  F1=0.368  AUROC=0.297  PR-AUC=0.589
#   seed=42 fold=6  BA=0.562  F1=0.556  AUROC=0.672  PR-AUC=0.766
#   seed=42 fold=7  BA=0.438  F1=0.368  AUROC=0.234  PR-AUC=0.575
#   seed=42 fold=8  BA=0.500  F1=0.496  AUROC=0.359  PR-AUC=0.637
#   seed=42 fold=9  BA=0.500  F1=0.400  AUROC=0.719  PR-AUC=0.876
#   seed=123 fold=1  BA=0.500  F1=0.496  AUROC=0.438  PR-AUC=0.642
#   seed=123 fold=2  BA=0.500  F1=0.496  AUROC=0.500  PR-AUC=0.667
#   seed=123 fold=3  BA=0.250  F1=0.250  AUROC=0.375  PR-AUC=0.677
#   seed=123 fold=4  BA=0.625  F1=0.621  AUROC=0.531  PR-AUC=0.691
#   seed=123 fold=5  BA=0.625  F1=0.621  AUROC=0.469  PR-AUC=0.736
#   seed=123 fold=6  BA=0.625  F1=0.621  AUROC=0.562  PR-AUC=0.697
#   seed=123 fold=7  BA=0.625  F1=0.621  AUROC=0.531  PR-AUC=0.670
#   seed=123 fold=8  BA=0.562  F1=0.556  AUROC=0.688  PR-AUC=0.864
#   seed=123 fold=9  BA=0.562  F1=0.556  AUROC=0.406  PR-AUC=0.651
#   seed=256 fold=1  BA=0.625  F1=0.621  AUROC=0.562  PR-AUC=0.697
#   seed=256 fold=2  BA=0.562  F1=0.556  AUROC=0.406  PR-AUC=0.658
#   seed=256 fold=3  BA=0.625  F1=0.621  AUROC=0.562  PR-AUC=0.697
#   seed=256 fold=4  BA=0.438  F1=0.368  AUROC=0.562  PR-AUC=0.780
#   seed=256 fold=5  BA=0.625  F1=0.621  AUROC=0.750  PR-AUC=0.886
#   seed=256 fold=6  BA=0.438  F1=0.368  AUROC=0.438  PR-AUC=0.626
#   seed=256 fold=7  BA=0.500  F1=0.400  AUROC=0.391  PR-AUC=0.650
#   seed=256 fold=8  BA=0.750  F1=0.778  AUROC=0.578  PR-AUC=0.691
#   seed=256 fold=9  BA=0.625  F1=0.621  AUROC=0.734  PR-AUC=0.813
#
# --- GaussianNB ---
#   seed=42 fold=1  BA=0.562  F1=0.500  AUROC=0.469  PR-AUC=0.713
#   seed=42 fold=2  BA=0.562  F1=0.500  AUROC=0.531  PR-AUC=0.739
#   seed=42 fold=3  BA=0.500  F1=0.486  AUROC=0.469  PR-AUC=0.647
#   seed=42 fold=4  BA=0.312  F1=0.314  AUROC=0.469  PR-AUC=0.736
#   seed=42 fold=5  BA=0.750  F1=0.733  AUROC=0.719  PR-AUC=0.760
#   seed=42 fold=6  BA=0.688  F1=0.580  AUROC=0.594  PR-AUC=0.809
#   seed=42 fold=7  BA=0.438  F1=0.413  AUROC=0.250  PR-AUC=0.570
#   seed=42 fold=8  BA=0.750  F1=0.733  AUROC=0.812  PR-AUC=0.909
#   seed=42 fold=9  BA=0.625  F1=0.580  AUROC=0.719  PR-AUC=0.839
#   seed=123 fold=1  BA=0.562  F1=0.556  AUROC=0.531  PR-AUC=0.717
#   seed=123 fold=2  BA=0.562  F1=0.556  AUROC=0.469  PR-AUC=0.700
#   seed=123 fold=3  BA=0.562  F1=0.500  AUROC=0.469  PR-AUC=0.751
#   seed=123 fold=4  BA=0.625  F1=0.580  AUROC=0.656  PR-AUC=0.841
#   seed=123 fold=5  BA=0.562  F1=0.556  AUROC=0.500  PR-AUC=0.666
#   seed=123 fold=6  BA=0.438  F1=0.413  AUROC=0.656  PR-AUC=0.830
#   seed=123 fold=7  BA=0.688  F1=0.657  AUROC=0.750  PR-AUC=0.890
#   seed=123 fold=8  BA=0.562  F1=0.500  AUROC=0.656  PR-AUC=0.849
#   seed=123 fold=9  BA=0.500  F1=0.496  AUROC=0.469  PR-AUC=0.707
#   seed=256 fold=1  BA=0.750  F1=0.733  AUROC=0.812  PR-AUC=0.909
#   seed=256 fold=2  BA=0.625  F1=0.580  AUROC=0.562  PR-AUC=0.753
#   seed=256 fold=3  BA=0.625  F1=0.625  AUROC=0.625  PR-AUC=0.798
#   seed=256 fold=4  BA=0.500  F1=0.486  AUROC=0.531  PR-AUC=0.802
#   seed=256 fold=5  BA=0.562  F1=0.500  AUROC=0.562  PR-AUC=0.753
#   seed=256 fold=6  BA=0.562  F1=0.500  AUROC=0.594  PR-AUC=0.718
#   seed=256 fold=7  BA=0.312  F1=0.314  AUROC=0.219  PR-AUC=0.558
#   seed=256 fold=8  BA=0.500  F1=0.486  AUROC=0.625  PR-AUC=0.789
#   seed=256 fold=9  BA=0.688  F1=0.657  AUROC=0.750  PR-AUC=0.870
#
# --- ElasticNet ---
#   seed=42 fold=1  BA=0.438  F1=0.413  AUROC=0.531  PR-AUC=0.728
#   seed=42 fold=2  BA=0.500  F1=0.250  AUROC=0.375  PR-AUC=0.673
#   seed=42 fold=3  BA=0.562  F1=0.556  AUROC=0.438  PR-AUC=0.624
#   seed=42 fold=4  BA=0.375  F1=0.378  AUROC=0.375  PR-AUC=0.670
#   seed=42 fold=5  BA=0.500  F1=0.250  AUROC=0.500  PR-AUC=0.667
#   seed=42 fold=6  BA=0.500  F1=0.250  AUROC=0.500  PR-AUC=0.667
#   seed=42 fold=7  BA=0.188  F1=0.167  AUROC=0.125  PR-AUC=0.524
#   seed=42 fold=8  BA=0.500  F1=0.486  AUROC=0.406  PR-AUC=0.614
#   seed=42 fold=9  BA=0.500  F1=0.250  AUROC=0.500  PR-AUC=0.667
#   seed=123 fold=1  BA=0.375  F1=0.333  AUROC=0.406  PR-AUC=0.614
#   seed=123 fold=2  BA=0.438  F1=0.314  AUROC=0.500  PR-AUC=0.721
#   seed=123 fold=3  BA=0.375  F1=0.333  AUROC=0.406  PR-AUC=0.681
#   seed=123 fold=4  BA=0.500  F1=0.486  AUROC=0.438  PR-AUC=0.733
#   seed=123 fold=5  BA=0.562  F1=0.500  AUROC=0.531  PR-AUC=0.691
#   seed=123 fold=6  BA=0.500  F1=0.250  AUROC=0.781  PR-AUC=0.895
#   seed=123 fold=7  BA=0.500  F1=0.250  AUROC=0.500  PR-AUC=0.667
#   seed=123 fold=8  BA=0.562  F1=0.500  AUROC=0.625  PR-AUC=0.818
#   seed=123 fold=9  BA=0.375  F1=0.378  AUROC=0.438  PR-AUC=0.724
#   seed=256 fold=1  BA=0.625  F1=0.580  AUROC=0.594  PR-AUC=0.764
#   seed=256 fold=2  BA=0.500  F1=0.250  AUROC=0.500  PR-AUC=0.667
#   seed=256 fold=3  BA=0.500  F1=0.413  AUROC=0.688  PR-AUC=0.797
#   seed=256 fold=4  BA=0.438  F1=0.413  AUROC=0.281  PR-AUC=0.600
#   seed=256 fold=5  BA=0.438  F1=0.413  AUROC=0.406  PR-AUC=0.701
#   seed=256 fold=6  BA=0.500  F1=0.413  AUROC=0.656  PR-AUC=0.794
#   seed=256 fold=7  BA=0.312  F1=0.245  AUROC=0.375  PR-AUC=0.606
#   seed=256 fold=8  BA=0.562  F1=0.556  AUROC=0.594  PR-AUC=0.780
#   seed=256 fold=9  BA=0.500  F1=0.250  AUROC=0.500  PR-AUC=0.667
#
# Final metrics (mean across 27 folds):
#              balanced_accuracy_mean  macro_f1_mean  auroc_mean  pr_auc_mean
# classifier
# ElasticNet                    0.468          0.366       0.480        0.694
# GaussianNB                    0.569          0.538       0.573        0.764
# kNN                           0.544          0.519       0.519        0.707
# mSVM-Linear                   0.479          0.374       0.418        0.673
# mSVM-RBF                      0.468          0.442       0.456        0.687
# mSVM-RFE                      0.523          0.466       0.387        0.640
#
# Consensus hyperparameters (mode across 27 folds):
#             clf__C  clf__C__support_pct clf__l1_ratio  clf__l1_ratio__support_pct clf__var_smoothing  clf__var_smoothing__support_pct clf__n_neighbors  clf__n_neighbors__support_pct clf__weights  clf__weights__support_pct clf__gamma  clf__gamma__support_pct rfe__estimator__C  rfe__estimator__C__support_pct rfe__n_features_to_select  rfe__n_features_to_select__support_pct
# classifier
# ElasticNet       1                 40.7           0.1                        55.6                NaN                              NaN              NaN                            NaN          NaN                        NaN        NaN                      NaN               NaN                             NaN                       NaN                                     NaN
# GaussianNB     NaN                  NaN           NaN                         NaN              1e-11                            100.0              NaN                            NaN          NaN                        NaN        NaN                      NaN               NaN                             NaN                       NaN                                     NaN
# kNN            NaN                  NaN           NaN                         NaN                NaN                              NaN               15                           25.9      uniform                       74.1        NaN                      NaN               NaN                             NaN                       NaN                                     NaN
# mSVM-Linear    0.1                 33.3           NaN                         NaN                NaN                              NaN              NaN                            NaN          NaN                        NaN        NaN                      NaN               NaN                             NaN                       NaN                                     NaN
# mSVM-RBF         1                 55.6           NaN                         NaN                NaN                              NaN              NaN                            NaN          NaN                        NaN        1.0                     59.3               NaN                             NaN                       NaN                                     NaN
# mSVM-RFE       NaN                  NaN           NaN                         NaN                NaN                              NaN              NaN                            NaN          NaN                        NaN        NaN                      NaN                10                            59.3                         9                                    44.4
#
# Outputs in: C:\Users\hafsa\Python PD Project\MI_BaggedLASSO Pipeline\PDHC new\PDHC-class-aware\Outputs\stage4_HP_nosmote\stage4_classifiers_PDHC_top10
#
# ========================================================================
# PANEL SIZE: top 15 consensus genes - output: stage4_classifiers_PDHC_top15
# ========================================================================
# Top genes loaded: 15
# Saved postfeature CSVs (train: (15, 108), test: (15, 47))
# Class balance (PD=1, HC=0): {np.str_('HC'): 36, np.str_('PD'): 72}
# RFE n_features_to_select grid: [3, 7, 14, 15]
#
# --- mSVM-RBF ---
#   seed=42 fold=1  BA=0.500  F1=0.496  AUROC=0.594  PR-AUC=0.716
#   seed=42 fold=2  BA=0.688  F1=0.657  AUROC=0.656  PR-AUC=0.849
#   seed=42 fold=3  BA=0.500  F1=0.486  AUROC=0.469  PR-AUC=0.726
#   seed=42 fold=4  BA=0.312  F1=0.314  AUROC=0.406  PR-AUC=0.682
#   seed=42 fold=5  BA=0.750  F1=0.733  AUROC=0.719  PR-AUC=0.814
#   seed=42 fold=6  BA=0.500  F1=0.250  AUROC=0.281  PR-AUC=0.682
#   seed=42 fold=7  BA=0.125  F1=0.143  AUROC=0.156  PR-AUC=0.598
#   seed=42 fold=8  BA=0.562  F1=0.556  AUROC=0.438  PR-AUC=0.686
#   seed=42 fold=9  BA=0.750  F1=0.733  AUROC=0.719  PR-AUC=0.760
#   seed=123 fold=1  BA=0.375  F1=0.378  AUROC=0.312  PR-AUC=0.586
#   seed=123 fold=2  BA=0.562  F1=0.556  AUROC=0.562  PR-AUC=0.738
#   seed=123 fold=3  BA=0.125  F1=0.143  AUROC=0.125  PR-AUC=0.536
#   seed=123 fold=4  BA=0.500  F1=0.496  AUROC=0.500  PR-AUC=0.755
#   seed=123 fold=5  BA=0.500  F1=0.250  AUROC=0.625  PR-AUC=0.798
#   seed=123 fold=6  BA=0.812  F1=0.748  AUROC=0.094  PR-AUC=0.515
#   seed=123 fold=7  BA=0.688  F1=0.697  AUROC=0.594  PR-AUC=0.711
#   seed=123 fold=8  BA=0.562  F1=0.500  AUROC=0.594  PR-AUC=0.776
#   seed=123 fold=9  BA=0.500  F1=0.486  AUROC=0.594  PR-AUC=0.815
#   seed=256 fold=1  BA=0.688  F1=0.697  AUROC=0.625  PR-AUC=0.731
#   seed=256 fold=2  BA=0.500  F1=0.496  AUROC=0.344  PR-AUC=0.604
#   seed=256 fold=3  BA=0.438  F1=0.413  AUROC=0.625  PR-AUC=0.766
#   seed=256 fold=4  BA=0.312  F1=0.294  AUROC=0.406  PR-AUC=0.650
#   seed=256 fold=5  BA=0.438  F1=0.413  AUROC=0.594  PR-AUC=0.809
#   seed=256 fold=6  BA=0.562  F1=0.500  AUROC=0.688  PR-AUC=0.751
#   seed=256 fold=7  BA=0.688  F1=0.657  AUROC=0.375  PR-AUC=0.675
#   seed=256 fold=8  BA=0.438  F1=0.438  AUROC=0.219  PR-AUC=0.562
#   seed=256 fold=9  BA=0.500  F1=0.486  AUROC=0.531  PR-AUC=0.767
#
# --- mSVM-Linear ---
#   seed=42 fold=1  BA=0.500  F1=0.250  AUROC=0.531  PR-AUC=0.675
#   seed=42 fold=2  BA=0.500  F1=0.250  AUROC=0.688  PR-AUC=0.869
#   seed=42 fold=3  BA=0.500  F1=0.486  AUROC=0.438  PR-AUC=0.686
#   seed=42 fold=4  BA=0.312  F1=0.314  AUROC=0.406  PR-AUC=0.674
#   seed=42 fold=5  BA=0.500  F1=0.486  AUROC=0.625  PR-AUC=0.766
#   seed=42 fold=6  BA=0.500  F1=0.250  AUROC=0.312  PR-AUC=0.695
#   seed=42 fold=7  BA=0.312  F1=0.314  AUROC=0.375  PR-AUC=0.723
#   seed=42 fold=8  BA=0.625  F1=0.625  AUROC=0.625  PR-AUC=0.729
#   seed=42 fold=9  BA=0.625  F1=0.625  AUROC=0.688  PR-AUC=0.851
#   seed=123 fold=1  BA=0.312  F1=0.314  AUROC=0.312  PR-AUC=0.662
#   seed=123 fold=2  BA=0.375  F1=0.378  AUROC=0.438  PR-AUC=0.740
#   seed=123 fold=3  BA=0.312  F1=0.314  AUROC=0.312  PR-AUC=0.662
#   seed=123 fold=4  BA=0.500  F1=0.250  AUROC=0.625  PR-AUC=0.810
#   seed=123 fold=5  BA=0.562  F1=0.556  AUROC=0.188  PR-AUC=0.557
#   seed=123 fold=6  BA=0.500  F1=0.486  AUROC=0.656  PR-AUC=0.836
#   seed=123 fold=7  BA=0.500  F1=0.250  AUROC=0.625  PR-AUC=0.766
#   seed=123 fold=8  BA=0.562  F1=0.500  AUROC=0.812  PR-AUC=0.896
#   seed=123 fold=9  BA=0.562  F1=0.556  AUROC=0.719  PR-AUC=0.871
#   seed=256 fold=1  BA=0.500  F1=0.250  AUROC=0.156  PR-AUC=0.531
#   seed=256 fold=2  BA=0.625  F1=0.580  AUROC=0.656  PR-AUC=0.788
#   seed=256 fold=3  BA=0.688  F1=0.580  AUROC=0.312  PR-AUC=0.599
#   seed=256 fold=4  BA=0.438  F1=0.413  AUROC=0.375  PR-AUC=0.619
#   seed=256 fold=5  BA=0.688  F1=0.580  AUROC=0.625  PR-AUC=0.820
#   seed=256 fold=6  BA=0.500  F1=0.413  AUROC=0.656  PR-AUC=0.788
#   seed=256 fold=7  BA=0.500  F1=0.250  AUROC=0.406  PR-AUC=0.614
#   seed=256 fold=8  BA=0.312  F1=0.314  AUROC=0.375  PR-AUC=0.666
#   seed=256 fold=9  BA=0.500  F1=0.250  AUROC=0.625  PR-AUC=0.840
#
# --- mSVM-RFE ---
#   seed=42 fold=1  BA=0.625  F1=0.621  AUROC=0.688  PR-AUC=0.833
#   seed=42 fold=2  BA=0.500  F1=0.496  AUROC=0.750  PR-AUC=0.913
#   seed=42 fold=3  BA=0.500  F1=0.496  AUROC=0.406  PR-AUC=0.682
#   seed=42 fold=4  BA=0.500  F1=0.400  AUROC=0.531  PR-AUC=0.786
#   seed=42 fold=5  BA=0.562  F1=0.556  AUROC=0.531  PR-AUC=0.786
#   seed=42 fold=6  BA=0.562  F1=0.556  AUROC=0.719  PR-AUC=0.865
#   seed=42 fold=7  BA=0.312  F1=0.294  AUROC=0.406  PR-AUC=0.724
#   seed=42 fold=8  BA=0.625  F1=0.621  AUROC=0.625  PR-AUC=0.773
#   seed=42 fold=9  BA=0.562  F1=0.556  AUROC=0.688  PR-AUC=0.833
#   seed=123 fold=1  BA=0.375  F1=0.333  AUROC=0.219  PR-AUC=0.620
#   seed=123 fold=2  BA=0.375  F1=0.333  AUROC=0.281  PR-AUC=0.575
#   seed=123 fold=3  BA=0.250  F1=0.250  AUROC=0.188  PR-AUC=0.545
#   seed=123 fold=4  BA=0.625  F1=0.621  AUROC=0.688  PR-AUC=0.833
#   seed=123 fold=5  BA=0.500  F1=0.400  AUROC=0.312  PR-AUC=0.587
#   seed=123 fold=6  BA=0.562  F1=0.556  AUROC=0.500  PR-AUC=0.721
#   seed=123 fold=7  BA=0.625  F1=0.621  AUROC=0.656  PR-AUC=0.841
#   seed=123 fold=8  BA=0.750  F1=0.733  AUROC=0.812  PR-AUC=0.876
#   seed=123 fold=9  BA=0.562  F1=0.556  AUROC=0.750  PR-AUC=0.886
#   seed=256 fold=1  BA=0.688  F1=0.697  AUROC=0.844  PR-AUC=0.938
#   seed=256 fold=2  BA=0.562  F1=0.556  AUROC=0.531  PR-AUC=0.786
#   seed=256 fold=3  BA=0.562  F1=0.556  AUROC=0.688  PR-AUC=0.866
#   seed=256 fold=4  BA=0.375  F1=0.333  AUROC=0.312  PR-AUC=0.599
#   seed=256 fold=5  BA=0.625  F1=0.621  AUROC=0.781  PR-AUC=0.895
#   seed=256 fold=6  BA=0.625  F1=0.625  AUROC=0.672  PR-AUC=0.735
#   seed=256 fold=7  BA=0.500  F1=0.400  AUROC=0.594  PR-AUC=0.711
#   seed=256 fold=8  BA=0.375  F1=0.333  AUROC=0.344  PR-AUC=0.700
#   seed=256 fold=9  BA=0.562  F1=0.556  AUROC=0.656  PR-AUC=0.820
#
# --- kNN ---
#   seed=42 fold=1  BA=0.625  F1=0.621  AUROC=0.781  PR-AUC=0.825
#   seed=42 fold=2  BA=0.500  F1=0.400  AUROC=0.688  PR-AUC=0.857
#   seed=42 fold=3  BA=0.625  F1=0.625  AUROC=0.594  PR-AUC=0.754
#   seed=42 fold=4  BA=0.438  F1=0.368  AUROC=0.453  PR-AUC=0.715
#   seed=42 fold=5  BA=0.625  F1=0.621  AUROC=0.656  PR-AUC=0.744
#   seed=42 fold=6  BA=0.562  F1=0.556  AUROC=0.672  PR-AUC=0.802
#   seed=42 fold=7  BA=0.500  F1=0.400  AUROC=0.250  PR-AUC=0.600
#   seed=42 fold=8  BA=0.625  F1=0.621  AUROC=0.391  PR-AUC=0.642
#   seed=42 fold=9  BA=0.562  F1=0.556  AUROC=0.531  PR-AUC=0.679
#   seed=123 fold=1  BA=0.500  F1=0.496  AUROC=0.344  PR-AUC=0.593
#   seed=123 fold=2  BA=0.688  F1=0.697  AUROC=0.562  PR-AUC=0.712
#   seed=123 fold=3  BA=0.625  F1=0.621  AUROC=0.547  PR-AUC=0.699
#   seed=123 fold=4  BA=0.688  F1=0.697  AUROC=0.562  PR-AUC=0.697
#   seed=123 fold=5  BA=0.562  F1=0.556  AUROC=0.594  PR-AUC=0.715
#   seed=123 fold=6  BA=0.688  F1=0.697  AUROC=0.703  PR-AUC=0.775
#   seed=123 fold=7  BA=0.625  F1=0.621  AUROC=0.453  PR-AUC=0.666
#   seed=123 fold=8  BA=0.500  F1=0.496  AUROC=0.672  PR-AUC=0.786
#   seed=123 fold=9  BA=0.562  F1=0.556  AUROC=0.578  PR-AUC=0.705
#   seed=256 fold=1  BA=0.625  F1=0.621  AUROC=0.688  PR-AUC=0.752
#   seed=256 fold=2  BA=0.625  F1=0.621  AUROC=0.359  PR-AUC=0.620
#   seed=256 fold=3  BA=0.750  F1=0.778  AUROC=0.750  PR-AUC=0.825
#   seed=256 fold=4  BA=0.375  F1=0.333  AUROC=0.594  PR-AUC=0.757
#   seed=256 fold=5  BA=0.500  F1=0.496  AUROC=0.625  PR-AUC=0.788
#   seed=256 fold=6  BA=0.688  F1=0.697  AUROC=0.547  PR-AUC=0.702
#   seed=256 fold=7  BA=0.562  F1=0.556  AUROC=0.594  PR-AUC=0.708
#   seed=256 fold=8  BA=0.625  F1=0.625  AUROC=0.469  PR-AUC=0.677
#   seed=256 fold=9  BA=0.625  F1=0.621  AUROC=0.812  PR-AUC=0.896
#
# --- GaussianNB ---
#   seed=42 fold=1  BA=0.375  F1=0.378  AUROC=0.469  PR-AUC=0.713
#   seed=42 fold=2  BA=0.625  F1=0.580  AUROC=0.656  PR-AUC=0.844
#   seed=42 fold=3  BA=0.438  F1=0.413  AUROC=0.531  PR-AUC=0.736
#   seed=42 fold=4  BA=0.375  F1=0.378  AUROC=0.531  PR-AUC=0.786
#   seed=42 fold=5  BA=0.750  F1=0.733  AUROC=0.750  PR-AUC=0.771
#   seed=42 fold=6  BA=0.562  F1=0.500  AUROC=0.719  PR-AUC=0.865
#   seed=42 fold=7  BA=0.438  F1=0.438  AUROC=0.531  PR-AUC=0.771
#   seed=42 fold=8  BA=0.812  F1=0.812  AUROC=0.750  PR-AUC=0.855
#   seed=42 fold=9  BA=0.625  F1=0.625  AUROC=0.625  PR-AUC=0.784
#   seed=123 fold=1  BA=0.625  F1=0.625  AUROC=0.531  PR-AUC=0.739
#   seed=123 fold=2  BA=0.562  F1=0.556  AUROC=0.531  PR-AUC=0.693
#   seed=123 fold=3  BA=0.312  F1=0.314  AUROC=0.406  PR-AUC=0.721
#   seed=123 fold=4  BA=0.500  F1=0.486  AUROC=0.625  PR-AUC=0.826
#   seed=123 fold=5  BA=0.562  F1=0.556  AUROC=0.625  PR-AUC=0.766
#   seed=123 fold=6  BA=0.688  F1=0.657  AUROC=0.844  PR-AUC=0.932
#   seed=123 fold=7  BA=0.812  F1=0.812  AUROC=0.688  PR-AUC=0.751
#   seed=123 fold=8  BA=0.562  F1=0.500  AUROC=0.781  PR-AUC=0.884
#   seed=123 fold=9  BA=0.688  F1=0.697  AUROC=0.750  PR-AUC=0.874
#   seed=256 fold=1  BA=0.750  F1=0.733  AUROC=0.906  PR-AUC=0.953
#   seed=256 fold=2  BA=0.375  F1=0.378  AUROC=0.531  PR-AUC=0.786
#   seed=256 fold=3  BA=0.625  F1=0.625  AUROC=0.688  PR-AUC=0.846
#   seed=256 fold=4  BA=0.438  F1=0.438  AUROC=0.562  PR-AUC=0.810
#   seed=256 fold=5  BA=0.688  F1=0.657  AUROC=0.781  PR-AUC=0.895
#   seed=256 fold=6  BA=0.500  F1=0.413  AUROC=0.656  PR-AUC=0.735
#   seed=256 fold=7  BA=0.500  F1=0.486  AUROC=0.438  PR-AUC=0.624
#   seed=256 fold=8  BA=0.438  F1=0.413  AUROC=0.312  PR-AUC=0.618
#   seed=256 fold=9  BA=0.625  F1=0.625  AUROC=0.750  PR-AUC=0.886
#
# --- ElasticNet ---
#   seed=42 fold=1  BA=0.625  F1=0.625  AUROC=0.625  PR-AUC=0.820
#   seed=42 fold=2  BA=0.625  F1=0.486  AUROC=0.656  PR-AUC=0.854
#   seed=42 fold=3  BA=0.375  F1=0.378  AUROC=0.406  PR-AUC=0.682
#   seed=42 fold=4  BA=0.500  F1=0.486  AUROC=0.531  PR-AUC=0.742
#   seed=42 fold=5  BA=0.500  F1=0.413  AUROC=0.594  PR-AUC=0.711
#   seed=42 fold=6  BA=0.625  F1=0.486  AUROC=0.750  PR-AUC=0.874
#   seed=42 fold=7  BA=0.312  F1=0.314  AUROC=0.312  PR-AUC=0.695
#   seed=42 fold=8  BA=0.688  F1=0.657  AUROC=0.594  PR-AUC=0.768
#   seed=42 fold=9  BA=0.625  F1=0.625  AUROC=0.719  PR-AUC=0.865
#   seed=123 fold=1  BA=0.500  F1=0.486  AUROC=0.312  PR-AUC=0.611
#   seed=123 fold=2  BA=0.562  F1=0.500  AUROC=0.469  PR-AUC=0.672
#   seed=123 fold=3  BA=0.312  F1=0.314  AUROC=0.438  PR-AUC=0.724
#   seed=123 fold=4  BA=0.688  F1=0.657  AUROC=0.656  PR-AUC=0.841
#   seed=123 fold=5  BA=0.438  F1=0.413  AUROC=0.594  PR-AUC=0.747
#   seed=123 fold=6  BA=0.500  F1=0.486  AUROC=0.688  PR-AUC=0.846
#   seed=123 fold=7  BA=0.500  F1=0.250  AUROC=0.500  PR-AUC=0.667
#   seed=123 fold=8  BA=0.562  F1=0.500  AUROC=0.750  PR-AUC=0.852
#   seed=123 fold=9  BA=0.500  F1=0.486  AUROC=0.719  PR-AUC=0.871
#   seed=256 fold=1  BA=0.625  F1=0.580  AUROC=0.844  PR-AUC=0.907
#   seed=256 fold=2  BA=0.750  F1=0.667  AUROC=0.625  PR-AUC=0.840
#   seed=256 fold=3  BA=0.562  F1=0.500  AUROC=0.656  PR-AUC=0.792
#   seed=256 fold=4  BA=0.438  F1=0.413  AUROC=0.438  PR-AUC=0.713
#   seed=256 fold=5  BA=0.562  F1=0.556  AUROC=0.625  PR-AUC=0.820
#   seed=256 fold=6  BA=0.625  F1=0.580  AUROC=0.688  PR-AUC=0.833
#   seed=256 fold=7  BA=0.375  F1=0.200  AUROC=0.500  PR-AUC=0.643
#   seed=256 fold=8  BA=0.312  F1=0.314  AUROC=0.375  PR-AUC=0.666
#   seed=256 fold=9  BA=0.625  F1=0.580  AUROC=0.688  PR-AUC=0.861
#
# Final metrics (mean across 27 folds):
#              balanced_accuracy_mean  macro_f1_mean  auroc_mean  pr_auc_mean
# classifier
# ElasticNet                    0.530          0.480       0.583        0.775
# GaussianNB                    0.565          0.549       0.628        0.795
# kNN                           0.588          0.576       0.573        0.729
# mSVM-Linear                   0.493          0.401       0.502        0.731
# mSVM-RBF                      0.514          0.482       0.476        0.706
# mSVM-RFE                      0.528          0.506       0.562        0.768
#
# Consensus hyperparameters (mode across 27 folds):
#             clf__C  clf__C__support_pct clf__l1_ratio  clf__l1_ratio__support_pct clf__var_smoothing  clf__var_smoothing__support_pct clf__n_neighbors  clf__n_neighbors__support_pct clf__weights  clf__weights__support_pct clf__gamma  clf__gamma__support_pct rfe__estimator__C  rfe__estimator__C__support_pct rfe__n_features_to_select  rfe__n_features_to_select__support_pct
# classifier
# ElasticNet     0.1                 44.4           0.1                        55.6                NaN                              NaN              NaN                            NaN          NaN                        NaN        NaN                      NaN               NaN                             NaN                       NaN                                     NaN
# GaussianNB     NaN                  NaN           NaN                         NaN              1e-11                            100.0              NaN                            NaN          NaN                        NaN        NaN                      NaN               NaN                             NaN                       NaN                                     NaN
# kNN            NaN                  NaN           NaN                         NaN                NaN                              NaN                5                           40.7      uniform                       92.6        NaN                      NaN               NaN                             NaN                       NaN                                     NaN
# mSVM-Linear     10                 33.3           NaN                         NaN                NaN                              NaN              NaN                            NaN          NaN                        NaN        NaN                      NaN               NaN                             NaN                       NaN                                     NaN
# mSVM-RBF         1                 51.9           NaN                         NaN                NaN                              NaN              NaN                            NaN          NaN                        NaN      scale                     44.4               NaN                             NaN                       NaN                                     NaN
# mSVM-RFE       NaN                  NaN           NaN                         NaN                NaN                              NaN              NaN                            NaN          NaN                        NaN        NaN                      NaN                 1                            51.9                         7                                    37.0
#
# Outputs in: C:\Users\hafsa\Python PD Project\MI_BaggedLASSO Pipeline\PDHC new\PDHC-class-aware\Outputs\stage4_HP_nosmote\stage4_classifiers_PDHC_top15
#
# ========================================================================
# PANEL SIZE: top 25 consensus genes - output: stage4_classifiers_PDHC_top25
# ========================================================================
# Top genes loaded: 25
# Saved postfeature CSVs (train: (25, 108), test: (25, 47))
# Class balance (PD=1, HC=0): {np.str_('HC'): 36, np.str_('PD'): 72}
# RFE n_features_to_select grid: [6, 12, 24, 25]
#
# --- mSVM-RBF ---
#   seed=42 fold=1  BA=0.500  F1=0.496  AUROC=0.688  PR-AUC=0.861
#   seed=42 fold=2  BA=0.500  F1=0.486  AUROC=0.531  PR-AUC=0.802
#   seed=42 fold=3  BA=0.562  F1=0.500  AUROC=0.531  PR-AUC=0.684
#   seed=42 fold=4  BA=0.375  F1=0.333  AUROC=0.406  PR-AUC=0.731
#   seed=42 fold=5  BA=0.750  F1=0.733  AUROC=0.812  PR-AUC=0.876
#   seed=42 fold=6  BA=0.625  F1=0.625  AUROC=0.781  PR-AUC=0.911
#   seed=42 fold=7  BA=0.562  F1=0.556  AUROC=0.406  PR-AUC=0.681
#   seed=42 fold=8  BA=0.500  F1=0.496  AUROC=0.531  PR-AUC=0.759
#   seed=42 fold=9  BA=0.750  F1=0.733  AUROC=0.688  PR-AUC=0.748
#   seed=123 fold=1  BA=0.438  F1=0.438  AUROC=0.406  PR-AUC=0.674
#   seed=123 fold=2  BA=0.500  F1=0.496  AUROC=0.594  PR-AUC=0.821
#   seed=123 fold=3  BA=0.562  F1=0.556  AUROC=0.562  PR-AUC=0.817
#   seed=123 fold=4  BA=0.562  F1=0.556  AUROC=0.594  PR-AUC=0.795
#   seed=123 fold=5  BA=0.562  F1=0.556  AUROC=0.750  PR-AUC=0.880
#   seed=123 fold=6  BA=0.812  F1=0.812  AUROC=0.969  PR-AUC=0.986
#   seed=123 fold=7  BA=0.625  F1=0.580  AUROC=0.781  PR-AUC=0.884
#   seed=123 fold=8  BA=0.750  F1=0.733  AUROC=0.656  PR-AUC=0.794
#   seed=123 fold=9  BA=0.562  F1=0.556  AUROC=0.594  PR-AUC=0.795
#   seed=256 fold=1  BA=0.750  F1=0.733  AUROC=0.844  PR-AUC=0.907
#   seed=256 fold=2  BA=0.500  F1=0.496  AUROC=0.562  PR-AUC=0.747
#   seed=256 fold=3  BA=0.562  F1=0.556  AUROC=0.750  PR-AUC=0.870
#   seed=256 fold=4  BA=0.312  F1=0.314  AUROC=0.312  PR-AUC=0.586
#   seed=256 fold=5  BA=0.625  F1=0.625  AUROC=0.812  PR-AUC=0.928
#   seed=256 fold=6  BA=0.562  F1=0.500  AUROC=0.656  PR-AUC=0.735
#   seed=256 fold=7  BA=0.812  F1=0.812  AUROC=0.719  PR-AUC=0.848
#   seed=256 fold=8  BA=0.562  F1=0.556  AUROC=0.531  PR-AUC=0.684
#   seed=256 fold=9  BA=0.562  F1=0.556  AUROC=0.750  PR-AUC=0.886
#
# --- mSVM-Linear ---
#   seed=42 fold=1  BA=0.875  F1=0.899  AUROC=0.781  PR-AUC=0.834
#   seed=42 fold=2  BA=0.562  F1=0.500  AUROC=0.562  PR-AUC=0.760
#   seed=42 fold=3  BA=0.500  F1=0.486  AUROC=0.531  PR-AUC=0.742
#   seed=42 fold=4  BA=0.688  F1=0.580  AUROC=0.531  PR-AUC=0.786
#   seed=42 fold=5  BA=0.625  F1=0.625  AUROC=0.656  PR-AUC=0.788
#   seed=42 fold=6  BA=0.625  F1=0.580  AUROC=0.438  PR-AUC=0.667
#   seed=42 fold=7  BA=0.438  F1=0.413  AUROC=0.406  PR-AUC=0.691
#   seed=42 fold=8  BA=0.562  F1=0.556  AUROC=0.688  PR-AUC=0.751
#   seed=42 fold=9  BA=0.625  F1=0.625  AUROC=0.719  PR-AUC=0.867
#   seed=123 fold=1  BA=0.438  F1=0.438  AUROC=0.344  PR-AUC=0.620
#   seed=123 fold=2  BA=0.562  F1=0.556  AUROC=0.469  PR-AUC=0.682
#   seed=123 fold=3  BA=0.500  F1=0.486  AUROC=0.469  PR-AUC=0.710
#   seed=123 fold=4  BA=0.688  F1=0.657  AUROC=0.688  PR-AUC=0.797
#   seed=123 fold=5  BA=0.562  F1=0.556  AUROC=0.719  PR-AUC=0.878
#   seed=123 fold=6  BA=0.688  F1=0.697  AUROC=0.938  PR-AUC=0.975
# ...
# mSVM-RBF        10                 51.9           NaN                         NaN                NaN                              NaN              NaN                            NaN          NaN                        NaN      scale                     55.6               NaN                             NaN                       NaN                                     NaN
# mSVM-RFE       NaN                  NaN           NaN                         NaN                NaN                              NaN              NaN                            NaN          NaN                        NaN        NaN                      NaN                 1                            51.9                        24                                    51.9
#
# Outputs in: C:\Users\hafsa\Python PD Project\MI_BaggedLASSO Pipeline\PDHC new\PDHC-class-aware\Outputs\stage4_HP_nosmote\stage4_classifiers_PDHC_top25
#
# ========================================================================
# PANEL SIZE: top 41 consensus genes - output: stage4_classifiers_PDHC_top41
# ========================================================================
# Top genes loaded: 41
# Saved postfeature CSVs (train: (41, 108), test: (41, 47))
# Class balance (PD=1, HC=0): {np.str_('HC'): 36, np.str_('PD'): 72}
# RFE n_features_to_select grid: [10, 20, 40, 41]
#
# --- mSVM-RBF ---
#   seed=42 fold=1  BA=0.562  F1=0.556  AUROC=0.594  PR-AUC=0.716
#   seed=42 fold=2  BA=0.625  F1=0.621  AUROC=0.750  PR-AUC=0.886
#   seed=42 fold=3  BA=0.562  F1=0.556  AUROC=0.578  PR-AUC=0.753
#   seed=42 fold=4  BA=0.500  F1=0.486  AUROC=0.656  PR-AUC=0.836
#   seed=42 fold=5  BA=0.562  F1=0.556  AUROC=0.750  PR-AUC=0.897
#   seed=42 fold=6  BA=0.562  F1=0.556  AUROC=0.844  PR-AUC=0.943
#   seed=42 fold=7  BA=0.625  F1=0.621  AUROC=0.688  PR-AUC=0.802
#   seed=42 fold=8  BA=0.688  F1=0.697  AUROC=0.562  PR-AUC=0.703
#   seed=42 fold=9  BA=0.625  F1=0.625  AUROC=0.625  PR-AUC=0.720
#   seed=123 fold=1  BA=0.625  F1=0.625  AUROC=0.438  PR-AUC=0.637
#   seed=123 fold=2  BA=0.500  F1=0.496  AUROC=0.594  PR-AUC=0.825
#   seed=123 fold=3  BA=0.625  F1=0.625  AUROC=0.562  PR-AUC=0.747
#   seed=123 fold=4  BA=0.625  F1=0.621  AUROC=0.625  PR-AUC=0.720
#   seed=123 fold=5  BA=0.875  F1=0.899  AUROC=0.875  PR-AUC=0.932
#   seed=123 fold=6  BA=0.812  F1=0.812  AUROC=0.969  PR-AUC=0.986
#   seed=123 fold=7  BA=0.750  F1=0.733  AUROC=0.719  PR-AUC=0.814
#   seed=123 fold=8  BA=0.750  F1=0.733  AUROC=0.781  PR-AUC=0.884
#   seed=123 fold=9  BA=0.688  F1=0.697  AUROC=0.719  PR-AUC=0.871
#   seed=256 fold=1  BA=0.562  F1=0.556  AUROC=0.812  PR-AUC=0.931
#   seed=256 fold=2  BA=0.750  F1=0.733  AUROC=0.750  PR-AUC=0.852
#   seed=256 fold=3  BA=0.688  F1=0.697  AUROC=0.812  PR-AUC=0.909
#   seed=256 fold=4  BA=0.625  F1=0.625  AUROC=0.562  PR-AUC=0.684
#   seed=256 fold=5  BA=0.500  F1=0.496  AUROC=0.625  PR-AUC=0.818
#   seed=256 fold=6  BA=0.562  F1=0.500  AUROC=0.656  PR-AUC=0.739
#   seed=256 fold=7  BA=0.562  F1=0.556  AUROC=0.656  PR-AUC=0.735
#   seed=256 fold=8  BA=0.562  F1=0.500  AUROC=0.594  PR-AUC=0.768
#   seed=256 fold=9  BA=0.688  F1=0.657  AUROC=0.750  PR-AUC=0.899
#
# --- mSVM-Linear ---
#   seed=42 fold=1  BA=0.625  F1=0.625  AUROC=0.688  PR-AUC=0.802
#   seed=42 fold=2  BA=0.562  F1=0.500  AUROC=0.750  PR-AUC=0.879
#   seed=42 fold=3  BA=0.375  F1=0.378  AUROC=0.406  PR-AUC=0.674
#   seed=42 fold=4  BA=0.875  F1=0.829  AUROC=0.938  PR-AUC=0.975
#   seed=42 fold=5  BA=0.438  F1=0.438  AUROC=0.531  PR-AUC=0.786
#   seed=42 fold=6  BA=0.562  F1=0.500  AUROC=0.500  PR-AUC=0.679
#   seed=42 fold=7  BA=0.625  F1=0.580  AUROC=0.625  PR-AUC=0.731
#   seed=42 fold=8  BA=0.625  F1=0.625  AUROC=0.500  PR-AUC=0.685
#   seed=42 fold=9  BA=0.562  F1=0.556  AUROC=0.688  PR-AUC=0.869
#   seed=123 fold=1  BA=0.500  F1=0.486  AUROC=0.344  PR-AUC=0.598
#   seed=123 fold=2  BA=0.312  F1=0.294  AUROC=0.406  PR-AUC=0.731
#   seed=123 fold=3  BA=0.750  F1=0.733  AUROC=0.625  PR-AUC=0.784
#   seed=123 fold=4  BA=0.750  F1=0.733  AUROC=0.750  PR-AUC=0.823
#   seed=123 fold=5  BA=0.625  F1=0.580  AUROC=0.688  PR-AUC=0.824
#   seed=123 fold=6  BA=0.688  F1=0.697  AUROC=0.938  PR-AUC=0.975
#   seed=123 fold=7  BA=0.688  F1=0.697  AUROC=0.750  PR-AUC=0.886
#   seed=123 fold=8  BA=0.438  F1=0.314  AUROC=0.656  PR-AUC=0.794
#   seed=123 fold=9  BA=0.688  F1=0.657  AUROC=0.656  PR-AUC=0.826
#   seed=256 fold=1  BA=0.688  F1=0.657  AUROC=0.750  PR-AUC=0.886
#   seed=256 fold=2  BA=0.812  F1=0.748  AUROC=0.875  PR-AUC=0.947
#   seed=256 fold=3  BA=0.875  F1=0.829  AUROC=0.938  PR-AUC=0.970
#   seed=256 fold=4  BA=0.562  F1=0.556  AUROC=0.500  PR-AUC=0.668
#   seed=256 fold=5  BA=0.500  F1=0.496  AUROC=0.719  PR-AUC=0.865
#   seed=256 fold=6  BA=0.375  F1=0.333  AUROC=0.375  PR-AUC=0.673
#   seed=256 fold=7  BA=0.625  F1=0.625  AUROC=0.688  PR-AUC=0.748
#   seed=256 fold=8  BA=0.438  F1=0.413  AUROC=0.312  PR-AUC=0.672
#   seed=256 fold=9  BA=0.625  F1=0.625  AUROC=0.812  PR-AUC=0.909
#
# --- mSVM-RFE ---
#   seed=42 fold=1  BA=0.625  F1=0.625  AUROC=0.719  PR-AUC=0.811
#   seed=42 fold=2  BA=0.625  F1=0.580  AUROC=0.781  PR-AUC=0.884
#   seed=42 fold=3  BA=0.438  F1=0.438  AUROC=0.406  PR-AUC=0.716
#   seed=42 fold=4  BA=0.938  F1=0.911  AUROC=0.875  PR-AUC=0.958
#   seed=42 fold=5  BA=0.562  F1=0.556  AUROC=0.719  PR-AUC=0.861
#   seed=42 fold=6  BA=0.750  F1=0.733  AUROC=0.719  PR-AUC=0.865
#   seed=42 fold=7  BA=0.500  F1=0.400  AUROC=0.844  PR-AUC=0.938
#   seed=42 fold=8  BA=0.500  F1=0.496  AUROC=0.531  PR-AUC=0.693
#   seed=42 fold=9  BA=0.500  F1=0.496  AUROC=0.625  PR-AUC=0.829
#   seed=123 fold=1  BA=0.500  F1=0.400  AUROC=0.562  PR-AUC=0.708
#   seed=123 fold=2  BA=0.438  F1=0.368  AUROC=0.438  PR-AUC=0.762
#   seed=123 fold=3  BA=0.625  F1=0.625  AUROC=0.625  PR-AUC=0.720
#   seed=123 fold=4  BA=0.875  F1=0.899  AUROC=0.781  PR-AUC=0.834
#   seed=123 fold=5  BA=0.750  F1=0.733  AUROC=0.844  PR-AUC=0.907
#   seed=123 fold=6  BA=0.625  F1=0.621  AUROC=0.844  PR-AUC=0.932
#   seed=123 fold=7  BA=0.562  F1=0.556  AUROC=0.750  PR-AUC=0.886
#   seed=123 fold=8  BA=0.812  F1=0.748  AUROC=1.000  PR-AUC=1.000
#   seed=123 fold=9  BA=0.688  F1=0.657  AUROC=0.688  PR-AUC=0.857
#   seed=256 fold=1  BA=0.625  F1=0.625  AUROC=0.844  PR-AUC=0.929
#   seed=256 fold=2  BA=0.688  F1=0.657  AUROC=0.719  PR-AUC=0.839
#   seed=256 fold=3  BA=0.750  F1=0.778  AUROC=0.969  PR-AUC=0.986
#   seed=256 fold=4  BA=0.688  F1=0.697  AUROC=0.625  PR-AUC=0.822
#   seed=256 fold=5  BA=0.500  F1=0.400  AUROC=0.906  PR-AUC=0.953
#   seed=256 fold=6  BA=0.500  F1=0.413  AUROC=0.594  PR-AUC=0.716
#   seed=256 fold=7  BA=0.500  F1=0.496  AUROC=0.656  PR-AUC=0.792
#   seed=256 fold=8  BA=0.438  F1=0.368  AUROC=0.344  PR-AUC=0.671
#   seed=256 fold=9  BA=0.750  F1=0.733  AUROC=0.812  PR-AUC=0.896
#
# --- kNN ---
#   seed=42 fold=1  BA=0.562  F1=0.556  AUROC=0.641  PR-AUC=0.746
#   seed=42 fold=2  BA=0.438  F1=0.438  AUROC=0.516  PR-AUC=0.715
#   seed=42 fold=3  BA=0.438  F1=0.438  AUROC=0.578  PR-AUC=0.731
#   seed=42 fold=4  BA=0.625  F1=0.625  AUROC=0.766  PR-AUC=0.866
#   seed=42 fold=5  BA=0.750  F1=0.778  AUROC=0.906  PR-AUC=0.917
#   seed=42 fold=6  BA=0.750  F1=0.733  AUROC=0.750  PR-AUC=0.859
#   seed=42 fold=7  BA=0.500  F1=0.400  AUROC=0.562  PR-AUC=0.698
#   seed=42 fold=8  BA=0.500  F1=0.496  AUROC=0.562  PR-AUC=0.784
#   seed=42 fold=9  BA=0.688  F1=0.697  AUROC=0.547  PR-AUC=0.685
#   seed=123 fold=1  BA=0.500  F1=0.496  AUROC=0.406  PR-AUC=0.642
#   seed=123 fold=2  BA=0.562  F1=0.556  AUROC=0.766  PR-AUC=0.849
#   seed=123 fold=3  BA=0.375  F1=0.333  AUROC=0.625  PR-AUC=0.817
#   seed=123 fold=4  BA=0.438  F1=0.368  AUROC=0.219  PR-AUC=0.576
#   seed=123 fold=5  BA=0.688  F1=0.657  AUROC=0.641  PR-AUC=0.737
#   seed=123 fold=6  BA=0.500  F1=0.400  AUROC=0.750  PR-AUC=0.833
#   seed=123 fold=7  BA=0.562  F1=0.556  AUROC=0.625  PR-AUC=0.746
#   seed=123 fold=8  BA=0.750  F1=0.733  AUROC=0.797  PR-AUC=0.843
#   seed=123 fold=9  BA=0.688  F1=0.697  AUROC=0.609  PR-AUC=0.753
#   seed=256 fold=1  BA=0.438  F1=0.368  AUROC=0.750  PR-AUC=0.867
#   seed=256 fold=2  BA=0.500  F1=0.496  AUROC=0.547  PR-AUC=0.698
#   seed=256 fold=3  BA=0.625  F1=0.625  AUROC=0.688  PR-AUC=0.819
#   seed=256 fold=4  BA=0.438  F1=0.438  AUROC=0.531  PR-AUC=0.696
#   seed=256 fold=5  BA=0.750  F1=0.778  AUROC=0.812  PR-AUC=0.864
#   seed=256 fold=6  BA=0.500  F1=0.496  AUROC=0.594  PR-AUC=0.792
#   seed=256 fold=7  BA=0.812  F1=0.812  AUROC=0.734  PR-AUC=0.784
#   seed=256 fold=8  BA=0.438  F1=0.438  AUROC=0.422  PR-AUC=0.643
#   seed=256 fold=9  BA=0.688  F1=0.697  AUROC=0.859  PR-AUC=0.903
#
# --- GaussianNB ---
#   seed=42 fold=1  BA=0.438  F1=0.438  AUROC=0.594  PR-AUC=0.832
#   seed=42 fold=2  BA=0.875  F1=0.829  AUROC=0.750  PR-AUC=0.913
#   seed=42 fold=3  BA=0.500  F1=0.486  AUROC=0.562  PR-AUC=0.738
#   seed=42 fold=4  BA=0.312  F1=0.314  AUROC=0.531  PR-AUC=0.786
#   seed=42 fold=5  BA=0.750  F1=0.733  AUROC=0.875  PR-AUC=0.932
#   seed=42 fold=6  BA=0.438  F1=0.413  AUROC=0.562  PR-AUC=0.770
#   seed=42 fold=7  BA=0.562  F1=0.556  AUROC=0.562  PR-AUC=0.802
#   seed=42 fold=8  BA=0.688  F1=0.657  AUROC=0.688  PR-AUC=0.830
#   seed=42 fold=9  BA=0.750  F1=0.733  AUROC=0.594  PR-AUC=0.776
#   seed=123 fold=1  BA=0.562  F1=0.556  AUROC=0.688  PR-AUC=0.864
#   seed=123 fold=2  BA=0.500  F1=0.486  AUROC=0.625  PR-AUC=0.829
#   seed=123 fold=3  BA=0.312  F1=0.314  AUROC=0.500  PR-AUC=0.779
#   seed=123 fold=4  BA=0.625  F1=0.580  AUROC=0.719  PR-AUC=0.855
#   seed=123 fold=5  BA=0.750  F1=0.733  AUROC=0.812  PR-AUC=0.928
#   seed=123 fold=6  BA=0.875  F1=0.829  AUROC=0.938  PR-AUC=0.970
#   seed=123 fold=7  BA=0.688  F1=0.657  AUROC=0.688  PR-AUC=0.833
#   seed=123 fold=8  BA=0.562  F1=0.500  AUROC=0.656  PR-AUC=0.788
#   seed=123 fold=9  BA=0.625  F1=0.625  AUROC=0.781  PR-AUC=0.907
#   seed=256 fold=1  BA=0.750  F1=0.733  AUROC=0.844  PR-AUC=0.929
#   seed=256 fold=2  BA=0.625  F1=0.580  AUROC=0.719  PR-AUC=0.855
#   seed=256 fold=3  BA=0.625  F1=0.625  AUROC=0.781  PR-AUC=0.907
#   seed=256 fold=4  BA=0.562  F1=0.556  AUROC=0.688  PR-AUC=0.879
#   seed=256 fold=5  BA=0.750  F1=0.733  AUROC=0.875  PR-AUC=0.947
#   seed=256 fold=6  BA=0.500  F1=0.413  AUROC=0.594  PR-AUC=0.780
#   seed=256 fold=7  BA=0.500  F1=0.486  AUROC=0.625  PR-AUC=0.807
#   seed=256 fold=8  BA=0.562  F1=0.500  AUROC=0.469  PR-AUC=0.751
#   seed=256 fold=9  BA=0.562  F1=0.556  AUROC=0.781  PR-AUC=0.895
#
# --- ElasticNet ---
#   seed=42 fold=1  BA=0.500  F1=0.496  AUROC=0.594  PR-AUC=0.716
#   seed=42 fold=2  BA=0.688  F1=0.580  AUROC=0.719  PR-AUC=0.882
#   seed=42 fold=3  BA=0.375  F1=0.378  AUROC=0.406  PR-AUC=0.682
#   seed=42 fold=4  BA=0.562  F1=0.500  AUROC=0.750  PR-AUC=0.855
#   seed=42 fold=5  BA=0.562  F1=0.500  AUROC=0.625  PR-AUC=0.778
#   seed=42 fold=6  BA=0.500  F1=0.413  AUROC=0.688  PR-AUC=0.748
#   seed=42 fold=7  BA=0.750  F1=0.733  AUROC=0.656  PR-AUC=0.849
#   seed=42 fold=8  BA=0.562  F1=0.556  AUROC=0.562  PR-AUC=0.694
#   seed=42 fold=9  BA=0.625  F1=0.580  AUROC=0.625  PR-AUC=0.829
#   seed=123 fold=1  BA=0.500  F1=0.486  AUROC=0.406  PR-AUC=0.629
#   seed=123 fold=2  BA=0.312  F1=0.294  AUROC=0.375  PR-AUC=0.745
#   seed=123 fold=3  BA=0.500  F1=0.486  AUROC=0.562  PR-AUC=0.726
#   seed=123 fold=4  BA=0.688  F1=0.697  AUROC=0.719  PR-AUC=0.839
#   seed=123 fold=5  BA=0.625  F1=0.580  AUROC=0.781  PR-AUC=0.864
#   seed=123 fold=6  BA=0.688  F1=0.697  AUROC=0.938  PR-AUC=0.975
#   seed=123 fold=7  BA=0.625  F1=0.625  AUROC=0.875  PR-AUC=0.947
#   seed=123 fold=8  BA=0.500  F1=0.413  AUROC=0.750  PR-AUC=0.823
#   seed=123 fold=9  BA=0.750  F1=0.733  AUROC=0.844  PR-AUC=0.938
#   seed=256 fold=1  BA=0.750  F1=0.733  AUROC=0.844  PR-AUC=0.929
#   seed=256 fold=2  BA=0.500  F1=0.486  AUROC=0.719  PR-AUC=0.855
#   seed=256 fold=3  BA=0.688  F1=0.657  AUROC=0.812  PR-AUC=0.876
#   seed=256 fold=4  BA=0.625  F1=0.625  AUROC=0.562  PR-AUC=0.726
#   seed=256 fold=5  BA=0.625  F1=0.625  AUROC=0.719  PR-AUC=0.843
#   seed=256 fold=6  BA=0.500  F1=0.413  AUROC=0.594  PR-AUC=0.703
#   seed=256 fold=7  BA=0.625  F1=0.625  AUROC=0.656  PR-AUC=0.788
#   seed=256 fold=8  BA=0.375  F1=0.333  AUROC=0.250  PR-AUC=0.632
#   seed=256 fold=9  BA=0.688  F1=0.657  AUROC=0.781  PR-AUC=0.884
#
# Final metrics (mean across 27 folds):
#              balanced_accuracy_mean  macro_f1_mean  auroc_mean  pr_auc_mean
# classifier
# ElasticNet                    0.581          0.552       0.660        0.806
# GaussianNB                    0.602          0.579       0.685        0.848
# kNN                           0.574          0.559       0.637        0.773
# mSVM-Linear                   0.600          0.574       0.645        0.802
# mSVM-RBF                      0.632          0.624       0.687        0.815
# mSVM-RFE                      0.620          0.593       0.712        0.843
#
# Consensus hyperparameters (mode across 27 folds):
#             clf__C  clf__C__support_pct clf__l1_ratio  clf__l1_ratio__support_pct clf__var_smoothing  clf__var_smoothing__support_pct clf__n_neighbors  clf__n_neighbors__support_pct clf__weights  clf__weights__support_pct clf__gamma  clf__gamma__support_pct rfe__estimator__C  rfe__estimator__C__support_pct rfe__n_features_to_select  rfe__n_features_to_select__support_pct
# classifier
# ElasticNet       1                 33.3           0.1                        59.3                NaN                              NaN              NaN                            NaN          NaN                        NaN        NaN                      NaN               NaN                             NaN                       NaN                                     NaN
# GaussianNB     NaN                  NaN           NaN                         NaN              1e-11                            100.0              NaN                            NaN          NaN                        NaN        NaN                      NaN               NaN                             NaN                       NaN                                     NaN
# kNN            NaN                  NaN           NaN                         NaN                NaN                              NaN                3                           40.7      uniform                      100.0        NaN                      NaN               NaN                             NaN                       NaN                                     NaN
# mSVM-Linear      1                 44.4           NaN                         NaN                NaN                              NaN              NaN                            NaN          NaN                        NaN        NaN                      NaN               NaN                             NaN                       NaN                                     NaN
# mSVM-RBF        10                 63.0           NaN                         NaN                NaN                              NaN              NaN                            NaN          NaN                        NaN      scale                     37.0               NaN                             NaN                       NaN                                     NaN
# mSVM-RFE       NaN                  NaN           NaN                         NaN                NaN                              NaN              NaN                            NaN          NaN                        NaN        NaN                      NaN                10                            37.0                        20                                    48.1
#
# Outputs in: C:\Users\hafsa\Python PD Project\MI_BaggedLASSO Pipeline\PDHC new\PDHC-class-aware\Outputs\stage4_HP_nosmote\stage4_classifiers_PDHC_top41
